head()
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2013-04-04 2013-04-04  209.044998  209.699997  205.744995  206.759995
# 2013-04-05 2013-04-05  206.759995  208.399994  204.199997  205.669998
# 2013-04-08 2013-04-08  205.740005  207.139999  202.869995  203.369995
# 2013-04-09 2013-04-09  204.524994  206.600006  198.000000  198.824997
# 2013-04-10 2013-04-10  199.899994  202.865005  197.610001  202.315002
#
#              Adj Close      Volume    HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE
# Date
# 2013-04-04  138.633301  15062340.0  0.000192      -0.000109        0.004914
# 2013-04-05  137.902481  16152430.0  0.000206      -0.000053        0.004914
# 2013-04-08  136.360321  10811270.0  0.000210      -0.000115        0.004914
# 2013-04-09  133.312881  18252900.0  0.000434      -0.000279        0.004914
# 2013-04-10  135.652924  18994350.0  0.000266       0.000121        0.004914

# %%
df=df1[['Open','High','Low','Adj Close','Volume','HL_PCT','PCT_CHNG_OpCl','PCT_CHNG_CLOSE','Close']]

# %% [markdown]
# ## Prediction for 30th Day

# %%
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
import datetime
# Out:
# C:\Users\Debadri\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df['Close'].plot(figsize=(15,6), color="green")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.tail()
# Out:
#                   Open        High         Low   Adj Close      Volume  \
# Date
# 2018-03-27  250.000000  255.500000  248.000000  254.350006  31205051.0
# 2018-03-28  252.000000  256.200012  248.699997  249.899994  36673566.0
# 2018-04-02  249.899994  252.000000  244.899994  246.149994  14993188.0
# 2018-04-03  249.550003  252.800003  248.250000  250.500000  19883309.0
# 2018-04-04  251.699997  253.000000  245.500000  247.300003  18824449.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close
# Date
# 2018-03-27  0.000302       0.000174             0.0  254.350006
# 2018-03-28  0.000302      -0.000083             0.0  249.899994
# 2018-04-02  0.000290      -0.000150             0.0  246.149994
# 2018-04-03  0.000183       0.000038             0.0  250.500000
# 2018-04-04  0.000305      -0.000175             0.0  247.300003

# %%
forecast_col = 'Close'

forecast_out = int(42)
# We will drop 12 columns because there are 12 holidays

# %%
df['label'] = df[forecast_col].shift(-forecast_out)
print(df.head(2))
# Out:
#                   Open        High         Low   Adj Close      Volume  \
# Date
# 2013-04-04  209.044998  209.699997  205.744995  138.633301  15062340.0
# 2013-04-05  206.759995  208.399994  204.199997  137.902481  16152430.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close       label
# Date
# 2013-04-04  0.000192      -0.000109        0.004914  206.759995  204.880005
# 2013-04-05  0.000206      -0.000053        0.004914  205.669998  202.414993

# %%
X = np.array(df.drop(['label'], 1))

# %%
X = preprocessing.scale(X)

# %%
X_forecast_out = X[-forecast_out:]
X = X[:-forecast_out]

# %%
y = np.array(df['label'])
y = y[:-forecast_out]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
clf = LinearRegression()
clf.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("Accuracy of our prediction model",clf.score(X_test, y_test)*100,"%")
# Out:
# Accuracy of our prediction model 59.09677359197114 %

# %%
# Taking first 30 values since 12 days are holidays

forecast_prediction = clf.predict(X_forecast_out)
print(forecast_prediction[:30])
# Out:
# [296.2407071  291.99440436 288.35914527 284.84572772 280.89744601
#  285.82725166 286.90734122 290.16252205 291.02165817 276.07847211
#  278.28368094 271.29536724 262.67764419 271.89822381 272.87039799
#  277.19480725 276.42510316 274.43333494 267.86261473 268.66411689
#  266.4383552  266.56081914 258.37795794 256.14619359 258.38257371
#  261.5143146  258.32597639 261.94500013 262.47879045 261.28683903]

# %%
df['forecast'] = np.nan
last_date = df.iloc[-1].name
last_unix = last_date.timestamp()
one_day = 86400
next_unix = last_unix + one_day

for i in forecast_prediction:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += 86400
    df.loc[next_date] = [np.nan for _ in range(len(df.columns)-1)]+[i]

# %%
df
# Out:
#                            
# 2013-05-10 00:00:00  229.360001  189.464996         NaN
# 2013-05-13 00:00:00  227.770004  187.630005         NaN
# 2013-05-14 00:00:00  229.304993  191.134995         NaN
# 2013-05-15 00:00:00  238.274994  189.339996         NaN
# 2013-05-16 00:00:00  241.934998  191.229996         NaN
# 2013-05-17 00:00:00  242.485001  182.764999         NaN
# 2013-05-20 00:00:00  241.179993  180.669998         NaN
# ...                         ...         ...         ...
# 2018-04-17 05:30:00         NaN         NaN  262.677644
# 2018-04-18 05:30:00         NaN         NaN  271.898224
# 2018-04-19 05:30:00         NaN         NaN  272.870398
# 2018-04-20 05:30:00         NaN         NaN  277.194807
# 2018-04-21 05:30:00         NaN         NaN  276.425103
# 2018-04-22 05:30:00         NaN         NaN  274.433335
# 2018-04-23 05:30:00         NaN         NaN  267.862615
# 2018-04-24 05:30:00         NaN         NaN  268.664117
# 2018-04-25 05:30:00         NaN         NaN  266.438355
# 2018-04-26 05:30:00         NaN         NaN  266.560819
# 2018-04-27 05:30:00         NaN         NaN  258.377958
# 2018-04-28 05:30:00         NaN         NaN  256.146194
# 2018-04-29 05:30:00         NaN         NaN  258.382574
# 2018-04-30 05:30:00         NaN         NaN  261.514315
# 2018-05-01 05:30:00         NaN         NaN  258.325976
# 2018-05-02 05:30:00         NaN         NaN  261.945000
# 2018-05-03 05:30:00         NaN         NaN  262.478790
# 2018-05-04 05:30:00         NaN         NaN  261.286839
# 2018-05-05 05:30:00         NaN         NaN  263.749613
# 2018-05-06 05:30:00         NaN         NaN  255.283719
# 2018-05-07 05:30:00         NaN         NaN  258.547010
# 2018-05-08 05:30:00         NaN         NaN  257.145079
# 2018-05-09 05:30:00         NaN         NaN  254.099049
# 2018-05-10 05:30:00         NaN         NaN  248.986417
# 2018-05-11 05:30:00         NaN         NaN  252.882414
# 2018-05-12 05:30:00         NaN         NaN  262.884514
# 2018-05-13 05:30:00         NaN         NaN  262.835948
# 2018-05-14 05:30:00         NaN         NaN  254.548758
# 2018-05-15 05:30:00         NaN         NaN  261.464118
# 2018-05-16 05:30:00         NaN         NaN  255.265523
#
# [1274 rows x 11 columns]

# %%
pred=df[-42:]

# %%
df=df[:-42]

# %%
pred
# Out:
#                      Open  High  Low  Adj Close  Volume  HL_PCT  \
# Date
# 2018-04-05 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-06 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-07 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-08 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-09 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-10 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-11 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-12 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-13 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-14 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-15 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-16 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-17 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-18 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-19 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-20 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-21 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-22 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-23 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-24 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-25 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-26 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-27 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-28 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-29 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-30 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-01 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-02 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-03 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-04 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-05 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-06 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-07 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-08 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-09 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-10 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-11 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-12 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-13 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-14 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-15 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-05-16 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
#
#                      PCT_CHNG_OpCl  PCT_CHNG_CLOSE  Close  label    forecast
# Date
# 2018-04-05 05:30:00            NaN             NaN    NaN    NaN  296.240707
# 2018-04-06 05:30:00            NaN             NaN    NaN    NaN  291.994404
# 2018-04-07 05:30:00            NaN             NaN    NaN    NaN  288.359145
# 2018-04-08 05:30:00            NaN             NaN    NaN    NaN  284.845728
# 2018-04-09 05:30:00            NaN             NaN    NaN    NaN  280.897446
# 2018-04-10 05:30:00            NaN             NaN    NaN    NaN  285.827252
# 2018-04-11 05:30:00            NaN             NaN    NaN    NaN  286.907341
# 2018-04-12 05:30:00            NaN             NaN    NaN    NaN  290.162522
# 2018-04-13 05:30:00            NaN             NaN    NaN    NaN  291.021658
# 2018-04-14 05:30:00            NaN             NaN    NaN    NaN  276.078472
# 2018-04-15 05:30:00            NaN             NaN    NaN    NaN  278.283681
# 2018-04-16 05:30:00            NaN             NaN    NaN    NaN  271.295367
# 2018-04-17 05:30:00            NaN             NaN    NaN    NaN  262.677644
# 2018-04-18 05:30:00            NaN             NaN    NaN    NaN  271.898224
# 2018-04-19 05:30:00            NaN             NaN    NaN    NaN  272.870398
# 2018-04-20 05:30:00            NaN             NaN    NaN    NaN  277.194807
# 2018-04-21 05:30:00            NaN             NaN    NaN    NaN  276.425103
# 2018-04-22 05:30:00            NaN             NaN    NaN    NaN  274.433335
# 2018-04-23 05:30:00            NaN             NaN    NaN    NaN  267.862615
# 2018-04-24 05:30:00            NaN             NaN    NaN    NaN  268.664117
# 2018-04-25 05:30:00            NaN             NaN    NaN    NaN  266.438355
# 2018-04-26 05:30:00            NaN             NaN    NaN    NaN  266.560819
# 2018-04-27 05:30:00            NaN             NaN    NaN    NaN  258.377958
# 2018-04-28 05:30:00            NaN             NaN    NaN    NaN  256.146194
# 2018-04-29 05:30:00            NaN             NaN    NaN    NaN  258.382574
# 2018-04-30 05:30:00            NaN             NaN    NaN    NaN  261.514315
# 2018-05-01 05:30:00            NaN             NaN    NaN    NaN  258.325976
# 2018-05-02 05:30:00            NaN             NaN    NaN    NaN  261.945000
# 2018-05-03 05:30:00            NaN             NaN    NaN    NaN  262.478790
# 2018-05-04 05:30:00            NaN             NaN    NaN    NaN  261.286839
# 2018-05-05 05:30:00            NaN             NaN    NaN    NaN  263.749613
# 2018-05-06 05:30:00            NaN             NaN    NaN    NaN  255.283719
# 2018-05-07 05:30:00            NaN             NaN    NaN    NaN  258.547010
# 2018-05-08 05:30:00            NaN             NaN    NaN    NaN  257.145079
# 2018-05-09 05:30:00            NaN             NaN    NaN    NaN  254.099049
# 2018-05-10 05:30:00            NaN             NaN    NaN    NaN  248.986417
# 2018-05-11 05:30:00            NaN             NaN    NaN    NaN  252.882414
# 2018-05-12 05:30:00            NaN             NaN    NaN    NaN  262.884514
# 2018-05-13 05:30:00            NaN             NaN    NaN    NaN  262.835948
# 2018-05-14 05:30:00            NaN             NaN    NaN    NaN  254.548758
# 2018-05-15 05:30:00            NaN             NaN    NaN    NaN  261.464118
# 2018-05-16 05:30:00            NaN             NaN    NaN    NaN  255.265523

# %%
pred=pred.reset_index()

# %%
pred['Date']=pred['Date'].dt.date

# %%
pred.head(1)
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#    PCT_CHNG_CLOSE  Close  label    forecast
# 0             NaN    NaN    NaN  296.240707

# %%
holidays=['2018-04-07','2018-04-08','2018-04-14','2018-04-15','2018-04-21','2018-04-22','2018-04-28','2018-04-29','2018-05-01','2018-05-05','2018-05-06','2018-05-12','2018-05-13']

# %%
pred['Date']=pred['Date'].apply(str)

# %%
for i in holidays:
    pred = pred.drop(pred[pred.Date==i].index)

# %%
pred['Date']=pd.to_datetime(pred['Date'])

# %%
pred.drop('forecast',axis=1,inplace=True)

# %%
pred.shape
# Out:
# (29, 11)

# %%
pred['forecast']=forecast_prediction[:29]

# %%
pred
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 1  2018-04-06   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 4  2018-04-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 5  2018-04-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 6  2018-04-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 7  2018-04-12   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 8  2018-04-13   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 11 2018-04-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 12 2018-04-17   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 13 2018-04-18   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 14 2018-04-19   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 15 2018-04-20   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 18 2018-04-23   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 19 2018-04-24   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 20 2018-04-25   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 21 2018-04-26   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 22 2018-04-27   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 25 2018-04-30   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 27 2018-05-02   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 28 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 29 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 32 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 33 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 34 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 35 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 36 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 39 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 40 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 41 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#     PCT_CHNG_CLOSE  Close  label    forecast
# 0              NaN    NaN    NaN  296.240707
# 1              NaN    NaN    NaN  291.994404
# 4              NaN    NaN    NaN  288.359145
# 5              NaN    NaN    NaN  284.845728
# 6              NaN    NaN    NaN  280.897446
# 7              NaN    NaN    NaN  285.827252
# 8              NaN    NaN    NaN  286.907341
# 11             NaN    NaN    NaN  290.162522
# 12             NaN    NaN    NaN  291.021658
# 13             NaN    NaN    NaN  276.078472
# 14             NaN    NaN    NaN  278.283681
# 15             NaN    NaN    NaN  271.295367
# 18             NaN    NaN    NaN  262.677644
# 19             NaN    NaN    NaN  271.898224
# 20             NaN    NaN    NaN  272.870398
# 21             NaN    NaN    NaN  277.194807
# 22             NaN    NaN    NaN  276.425103
# 25             NaN    NaN    NaN  274.433335
# 27             NaN    NaN    NaN  267.862615
# 28             NaN    NaN    NaN  268.664117
# 29             NaN    NaN    NaN  266.438355
# 32             NaN    NaN    NaN  266.560819
# 33             NaN    NaN    NaN  258.377958
# 34             NaN    NaN    NaN  256.146194
# 35             NaN    NaN    NaN  258.382574
# 36             NaN    NaN    NaN  261.514315
# 39             NaN    NaN    NaN  258.325976
# 40             NaN    NaN    NaN  261.945000
# 41             NaN    NaN    NaN  262.478790

# %%
pred.index=pred['Date']
pred.drop('Date',axis=1,inplace=True)

# %%
df=df.append(pred)

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.xlim(xmin=datetime.date(2018, 4, 4))
plt.ylim(ymin=-100)
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.iloc[-1]
# Out:
# Open                    NaN
# High                    NaN
# Low                     NaN
# Adj Close               NaN
# Volume                  NaN
# HL_PCT                  NaN
# PCT_CHNG_OpCl           NaN
# PCT_CHNG_CLOSE          NaN
# Close                   NaN
# label                   NaN
# forecast          262.47879
# Name: 2018-05-16 00:00:00, dtype: float64

# %%
close_last=df.iloc[-1].forecast

# %%
pred_return=close_last-close_zero
print("Predicted Return: Rs.",pred_return)
# Out:
# Predicted Return: Rs. 15.178787449613282

# %% [markdown]
# ## Simple Moving Average (30,40,50)

# %%
# For 30 days
short_rolling = df.rolling(window=30).mean()
short_rolling.head(30)
# Out:
#                   Open        High         Low   Adj Close      Volume  \
# Date
# 2013-04-04         NaN         NaN         NaN         NaN         NaN
# 2013-04-05         NaN         NaN         NaN         NaN         NaN
# 2013-04-08         NaN         NaN         NaN         NaN         NaN
# 2013-04-09         NaN         NaN         NaN         NaN         NaN
# 2013-04-10         NaN         NaN         NaN         NaN         NaN
# 2013-04-11         NaN         NaN         NaN         NaN         NaN
# 2013-04-12         NaN         NaN         NaN         NaN         NaN
# 2013-04-15         NaN         NaN         NaN         NaN         NaN
# 2013-04-16         NaN         NaN         NaN         NaN         NaN
# 2013-04-17         NaN         NaN         NaN         NaN         NaN
# 2013-04-18         NaN         NaN         NaN         NaN         NaN
# 2013-04-22         NaN         NaN         NaN         NaN         NaN
# 2013-04-23         NaN         NaN         NaN         NaN         NaN
# 2013-04-25         NaN         NaN         NaN         NaN         NaN
# 2013-04-26         NaN         NaN         NaN         NaN         NaN
# 2013-04-29         NaN         NaN         NaN         NaN         NaN
# 2013-04-30         NaN         NaN         NaN         NaN         NaN
# 2013-05-02         NaN         NaN         NaN         NaN         NaN
# 2013-05-03         NaN         NaN         NaN         NaN         NaN
# 2013-05-06         NaN         NaN         NaN         NaN         NaN
# 2013-05-07         NaN         NaN         NaN         NaN         NaN
# 2013-05-08         NaN         NaN         NaN         NaN         NaN
# 2013-05-09         NaN         NaN         NaN         NaN         NaN
# 2013-05-10         NaN         NaN         NaN         NaN         NaN
# 2013-05-13         NaN         NaN         NaN         NaN         NaN
# 2013-05-14         NaN         NaN         NaN         NaN         NaN
# 2013-05-15         NaN         NaN         NaN         NaN         NaN
# 2013-05-16         NaN         NaN         NaN         NaN         NaN
# 2013-05-17         NaN         NaN         NaN         NaN         NaN
# 2013-05-20  222.429665  226.090667  219.986666  149.718081  18486802.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close       label  \
# Date
# 2013-04-04       NaN            NaN             NaN         NaN         NaN
# 2013-04-05       NaN            NaN             NaN         NaN         NaN
# 2013-04-08       NaN            NaN             NaN         NaN         NaN
# 2013-04-09       NaN            NaN             NaN         NaN         NaN
# 2013-04-10       NaN            NaN             NaN         NaN         NaN
# 2013-04-11       NaN            NaN             NaN         NaN         NaN
# 2013-04-12       NaN            NaN             NaN         NaN         NaN
# 2013-04-15       NaN            NaN             NaN         NaN         NaN
# 2013-04-16       NaN            NaN             NaN         NaN         NaN
# 2013-04-17       NaN            NaN             NaN         NaN         NaN
# 2013-04-18       NaN            NaN             NaN         NaN         NaN
# 2013-04-22       NaN            NaN             NaN         NaN         NaN
# 2013-04-23       NaN            NaN             NaN         NaN         NaN
# 2013-04-25       NaN            NaN             NaN         NaN         NaN
# 2013-04-26       NaN            NaN             NaN         NaN         NaN
# 2013-04-29       NaN            NaN             NaN         NaN         NaN
# 2013-04-30       NaN            NaN             NaN         NaN         NaN
# 2013-05-02       NaN            NaN             NaN         NaN         NaN
# 2013-05-03       NaN            NaN             NaN         NaN         NaN
# 2013-05-06       NaN            NaN             NaN         NaN         NaN
# 2013-05-07       NaN            NaN             NaN         NaN         NaN
# 2013-05-08       NaN            NaN             NaN         NaN         NaN
# 2013-05-09       NaN            NaN             NaN         NaN         NaN
# 2013-05-10       NaN            NaN             NaN         NaN         NaN
# 2013-05-13       NaN            NaN             NaN         NaN         NaN
# 2013-05-14       NaN            NaN             NaN         NaN         NaN
# 2013-05-15       NaN            NaN             NaN         NaN         NaN
# 2013-05-16       NaN            NaN             NaN         NaN         NaN
# 2013-05-17       NaN            NaN             NaN         NaN         NaN
# 2013-05-20  0.000278        0.00004        0.004914  223.291999  195.371168
#
#             forecast
# Date
# 2013-04-04       NaN
# 2013-04-05       NaN
# 2013-04-08       NaN
# 2013-04-09       NaN
# 2013-04-10       NaN
# 2013-04-11       NaN
# 2013-04-12       NaN
# 2013-04-15       NaN
# 2013-04-16       NaN
# 2013-04-17       NaN
# 2013-04-18       NaN
# 2013-04-22       NaN
# 2013-04-23       NaN
# 2013-04-25       NaN
# 2013-04-26       NaN
# 2013-04-29       NaN
# 2013-04-30       NaN
# 2013-05-02       NaN
# 2013-05-03       NaN
# 2013-05-06       NaN
# 2013-05-07       NaN
# 2013-05-08       NaN
# 2013-05-09       NaN
# 2013-05-10       NaN
# 2013-05-13       NaN
# 2013-05-14       NaN
# 2013-05-15       NaN
# 2013-05-16       NaN
# 2013-05-17       NaN
# 2013-05-20       NaN

# %%
# For 40 days
med_rolling = df.rolling(window=40).mean()
med_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
# For 50 days
long_rolling = df.rolling(window=50).mean()
long_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
start_date = '2013-04-29'
end_date = '2018-04-04'

fig, ax = plt.subplots(figsize=(16,9))

ax.plot(long_rolling.loc[start_date:end_date, :].index, long_rolling.loc[start_date:end_date, 'Close'], label = '50-days SMA')
ax.plot(med_rolling.loc[start_date:end_date, :].index, med_rolling.loc[start_date:end_date, 'Close'], label = '40-days SMA')
ax.plot(short_rolling.loc[start_date:end_date, :].index, short_rolling.loc[start_date:end_date, 'Close'], label = '30-days SMA')


ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Exponential Moving Average (30,40,50)

# %%
ema_short = df.ewm(span=30, adjust=False).mean()
ema_med = df.ewm(span=40, adjust=False).mean()
ema_long = df.ewm(span=50, adjust=False).mean()

fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ema_short.loc[start_date:end_date, :].index, ema_short.loc[start_date:end_date, 'Close'], label = 'Span 30-days EMA')
ax.plot(ema_med.loc[start_date:end_date, :].index, ema_med.loc[start_date:end_date, 'Close'], label = 'Span 40-days EMA')
ax.plot(ema_long.loc[start_date:end_date, :].index, ema_long.loc[start_date:end_date, 'Close'], label = 'Span 50-days EMA')

ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Aroon Oscillator (30,40,50)

# %%
from pandas.stats import moments
from pandas import DataFrame

# %%
def aroon(s, n):
    up = 100 * moments.rolling_apply(s.High, n + 1, lambda x: x.argmax()) / n
    dn = 100 * moments.rolling_apply(s.Low, n + 1, lambda x: x.argmin()) / n

    return DataFrame(dict(up=up, down=dn))

# %%
ao30=aroon(df,30)
ao40=aroon(df,40)
ao50=aroon(df,50)

# %%
ao30
# Out:
#             down   up
# Date
# 2013-04-04   NaN  NaN
# 2013-04-05   NaN  NaN
# 2013-04-08   NaN  NaN
# 2013-04-09   NaN  NaN
# 2013-04-10   NaN  NaN
# 2013-04-11   NaN  NaN
# 2013-04-12   NaN  NaN
# 2013-04-15   NaN  NaN
# 2013-04-16   NaN  NaN
# 2013-04-17   NaN  NaN
# 2013-04-18   NaN  NaN
# 2013-04-22   NaN  NaN
# 2013-04-23   NaN  NaN
# 2013-04-25   NaN  NaN
# 2013-04-26   NaN  NaN
# 2013-04-29   NaN  NaN
# 2013-04-30   NaN  NaN
# 2013-05-02   NaN  NaN
# 2013-05-03   NaN  NaN
# 2013-05-06   NaN  NaN
# 2013-05-07   NaN  NaN
# 2013-05-08   NaN  NaN
# 2013-05-09   NaN  NaN
# 2013-05-10   NaN  NaN
# 2013-05-13   NaN  NaN
# 2013-05-14   NaN  NaN
# 2013-05-15   NaN  NaN
# 2013-05-16   NaN  NaN
# 2013-05-17   NaN  NaN
# 2013-05-20   NaN  NaN
# ...          ...  ...
# 2018-04-04  80.0  0.0
# 2018-04-05   NaN  NaN
# 2018-04-06   NaN  NaN
# 2018-04-09   NaN  NaN
# 2018-04-10   NaN  NaN
# 2018-04-11   NaN  NaN
# 2018-04-12   NaN  NaN
# 2018-04-13   NaN  NaN
# 2018-04-16   NaN  NaN
# 2018-04-17   NaN  NaN
# 2018-04-18   NaN  NaN
# 2018-04-19   NaN  NaN
# 2018-04-20   NaN  NaN
# 2018-04-23   NaN  NaN
# 2018-04-24   NaN  NaN
# 2018-04-25   NaN  NaN
# 2018-04-26   NaN  NaN
# 2018-04-27   NaN  NaN
# 2018-04-30   NaN  NaN
# 2018-05-02   NaN  NaN
# 2018-05-03   NaN  NaN
# 2018-05-04   NaN  NaN
# 2018-05-07   NaN  NaN
# 2018-05-08   NaN  NaN
# 2018-05-09   NaN  NaN
# 2018-05-10   NaN  NaN
# 2018-05-11   NaN  NaN
# 2018-05-14   NaN  NaN
# 2018-05-15   NaN  NaN
# 2018-05-16   NaN  NaN
#
# [1261 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 30-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 30-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 40-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 40-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'down'], label = ' Down 50-days Aroon Oscillator')
ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'up'], label = 'Up 50-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %% [markdown]
# ## MACD Signal

# %%
def ema(s, n, wilder=False):
    span = n if not wilder else 2*n - 1
    return moments.ewma(s, span=span)


def macd(s, nfast=12, nslow=26, nsig=9, percent=True):
    fast, slow = ema(s, nfast), ema(s, nslow)

    if percent:
        macd = 100*(fast / slow - 1)
    else:
        macd = fast - slow

    sig = ema(macd, nsig)
    hist = macd - sig

    return DataFrame(dict(macd=macd, signal=sig, hist=hist,
                          fast=fast, slow=slow))

# %%
m=macd(df['Close'])

# %%
m.head(1)
# Out:
#                   fast  hist  macd  signal        slow
# Date
# 2013-04-04  206.759995   0.0   0.0     0.0  206.759995

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(m.loc[start_date:end_date, :].index, m.loc[start_date:end_date, 'macd'], label = 'MACD')

ax.legend(loc='best')
ax.set_ylabel('Change ')
# Out:
# Text(0,0.5,'Change ')

# %% [markdown]
# ## Relative Strength Index (RSI)

# %%
def rsi(s, n=14):
    diff = s.diff()
    which_dn = diff < 0

    up, dn = diff, diff*0
    up[which_dn], dn[which_dn] = 0, -up[which_dn]

    emaup = ema(up, n, wilder=True)
    emadn = ema(dn, n, wilder=True)

    return 100 * emaup/(emaup + emadn)

# %%
sf=rsi(df['Close'],50)

# %%
sfd=pd.DataFrame({'Date':sf.index, 'RSI':sf.values})

# %%
sfd.index=sfd['Date']

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(sfd.loc[start_date:end_date, :].index, sfd.loc[start_date:end_date, 'RSI'], label = 'RSI')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Bollinger Bands (30,40,50)

# %%
price=df["Close"]

def bbands(price, length=30, numsd=2):
    """ returns average, upper band, and lower band"""
    ave = pd.stats.moments.rolling_mean(price,length)
    sd = pd.stats.moments.rolling_std(price,length)
    upband = ave + (sd*numsd)
    dnband = ave - (sd*numsd)
    return np.round(ave,3), np.round(upband,3), np.round(dnband,3)

df['ave30'], df['upper30'], df['lower30'] = bbands(df.Close, length=30, numsd=1)
df['ave40'], df['upper40'], df['lower40'] = bbands(df.Close, length=40, numsd=1)
df['ave50'], df['upper50'], df['lower50'] = bbands(df.Close, length=50, numsd=1)

# %%
# For 30 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave30'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower30'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper30'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 40 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave40'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower40'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper40'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 50 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave50'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower50'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper50'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Stochastic Oscillator

# %%
def STOK(close, low, high, n): 
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 return STOK

def STOD(close, low, high, n):
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 STOD = pd.rolling_mean(STOK, 3)
 return STOD

# %%
df['%K'] = STOK(df['Close'], df['Low'], df['High'], 14)
df['%D'] = STOD(df['Close'], df['Low'], df['High'], 14)

# %%
df.plot(y=['Close'], figsize = (20, 5))
df.plot(y=['%K', '%D'], figsize = (20, 5))

# %% [markdown]
# ## Chande Oscillator

# %%
def avg_true_range(df): 
  ind = range(0,len(df))
  indexlist = list(ind)
  df.index = indexlist

  for index, row in df.iterrows():
    if index != 0:
      tr1 = row["High"] - row["Low"]
      tr2 = abs(row["High"] - df.iloc[index-1]["Close"])
      tr3 = abs(row["Low"] - df.iloc[index-1]["Close"])

      true_range = max(tr1, tr2, tr3)
      df.set_value(index,"True Range", true_range)

  df["Avg TR"] = df["True Range"].rolling(min_periods=14, window=14, center=False).mean()
  return df

# %%
def chandelier_exit(df):

  df_tr = avg_true_range(df)

  df_tr['rolling_high']= df_tr["High"]
  df_tr['rolling_low'] = df_tr["Low"]

  df_tr['chandelier_long'] = df_tr['rolling_high'] - df_tr["Avg TR"] * 3
  df_tr['chandelier_short'] = df_tr['rolling_low'] - df_tr["Avg TR"] * 3
  fig, ax = plt.subplots(figsize=(15,9))

  ax.plot(df_tr['Date'], df_tr['chandelier_long'], label = 'Chand Long')

# %%
ch=chandelier_exit(df1)

# %% [markdown]
# ## Commodity Channel Index (30,40,50)

# %%
def CCI(data, ndays): 
 TP = (data['High'] + data['Low'] + data['Close']) / 3 
 CCI = pd.Series((TP - pd.rolling_mean(TP, ndays)) / (0.015 * pd.rolling_std(TP, ndays)),
 name = 'CCI')
 data=data.join(CCI)
 return data

# %%
cci30=CCI(df,30)
cci40=CCI(df,40)
cci50=CCI(df,50)

# %%
cci30
# Out:
#                   Open        High         Low   Adj Close      Volume  \
# Date
# 2013-04-04  209.044998  209.699997  205.744995  138.633301  15062340.0
# 2013-04-05  206.759995  208.399994  204.199997  137.902481  16152430.0
# 2013-04-08  205.740005  207.139999  202.869995  136.360321  10811270.0
# 2013-04-09  204.524994  206.600006  198.000000  133.312881  18252900.0
# 2013-04-10  199.899994  202.865005  197.610001  135.652924  18994350.0
# 2013-04-11  203.479996  205.000000  200.800003  136.940308  18848870.0
# 2013-04-12  204.000000  209.699997  202.000000  139.585403  20632180.0
# 2013-04-15  206.300003  215.839996  206.259995  143.910187  18089020.0
# 2013-04-16  214.800003  219.395004  214.000000  146.377640  14838250.0
# 2013-04-17  219.500000  226.985001  219.500000  150.538101  24644810.0
# 2013-04-18  225.339996  231.255005  223.500000  154.192352  21382190.0
# 2013-04-22  229.964996  236.000000  229.964996  156.032883  14450260.0
# 2013-04-23  234.000000  234.330002  226.600006  153.377686  18770200.0
# 2013-04-25  228.750000  234.300003  228.750000  156.532410  20535590.0
# 2013-04-26  232.500000  233.455002  227.714996  153.407867  11550470.0
# 2013-04-29  230.199997  230.945007  226.210007  152.442322  13964420.0
# 2013-04-30  228.199997  229.250000  222.535004  151.822113  14814500.0
# 2013-05-02  226.429993  232.684998  226.429993  154.178955  20143690.0
# 2013-05-03  228.500000  229.339996  220.600006  148.436096  36583570.0
# 2013-05-06  220.554993  223.255005  218.300003  149.260803  19604120.0
# 2013-05-07  222.000000  226.399994  221.854996  151.319244  12903980.0
# 2013-05-08  226.000000  227.300003  223.154999  151.178421  14795230.0
# 2013-05-09  226.000000  232.679993  224.399994  153.609024  22585460.0
# 2013-05-10  228.990005  232.300003  228.375000  153.786682  18603240.0
...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-11     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-12     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-13     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-16     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-17     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-18     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-19     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-20     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-23     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-24     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-25     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-26     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-27     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-04-30     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-02     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-03     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-04     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-07     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-08     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-09     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-10     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-11     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-14     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-15     ...          NaN     NaN      NaN      NaN      NaN      NaN
# 2018-05-16     ...          NaN     NaN      NaN      NaN      NaN      NaN
#
#             lower50         %K         %D         CCI
# Date
# 2013-04-04      NaN        NaN        NaN         NaN
# 2013-04-05      NaN        NaN        NaN         NaN
# 2013-04-08      NaN        NaN        NaN         NaN
# 2013-04-09      NaN        NaN        NaN         NaN
# 2013-04-10      NaN        NaN        NaN         NaN
# 2013-04-11      NaN        NaN        NaN         NaN
# 2013-04-12      NaN        NaN        NaN         NaN
# 2013-04-15      NaN        NaN        NaN         NaN
# 2013-04-16      NaN        NaN        NaN         NaN
# 2013-04-17      NaN        NaN        NaN         NaN
# 2013-04-18      NaN        NaN        NaN         NaN
# 2013-04-22      NaN        NaN        NaN         NaN
# 2013-04-23      NaN        NaN        NaN         NaN
# 2013-04-25      NaN  93.370674        NaN         NaN
# 2013-04-26      NaN  81.232086        NaN         NaN
# 2013-04-29      NaN  77.481104  84.027955         NaN
# 2013-04-30      NaN  75.071614  77.928268         NaN
# 2013-05-02      NaN  84.227681  78.926800         NaN
# 2013-05-03      NaN  58.465920  72.588405         NaN
# 2013-05-06      NaN  60.617650  67.770417         NaN
# 2013-05-07      NaN  65.299243  61.460937         NaN
# 2013-05-08      NaN  52.136368  59.351087         NaN
# 2013-05-09      NaN  60.988700  59.474770         NaN
# 2013-05-10      NaN  62.485875  58.536981         NaN
# 2013-05-13      NaN  53.502840  58.992471         NaN
# 2013-05-14      NaN  68.652468  61.547061         NaN
# 2013-05-15      NaN  95.209699  72.455002         NaN
# 2013-05-16      NaN  92.288146  85.383438         NaN
# 2013-05-17      NaN  94.435756  93.977867         NaN
# 2013-05-20      NaN  79.169532  88.631144  106.562877
# ...             ...        ...        ...         ...
# 2018-04-04   249.08  56.521766  54.281515  -51.737997
# 2018-04-05      NaN        NaN        NaN         NaN
# 2018-04-06      NaN        NaN        NaN         NaN
# 2018-04-09      NaN        NaN        NaN         NaN
# 2018-04-10      NaN        NaN        NaN         NaN
# 2018-04-11      NaN        NaN        NaN         NaN
# 2018-04-12      NaN        NaN        NaN         NaN
# 2018-04-13      NaN        NaN        NaN         NaN
# 2018-04-16      NaN        NaN        NaN         NaN
# 2018-04-17      NaN        NaN        NaN         NaN
# 2018-04-18      NaN        NaN        NaN         NaN
# 2018-04-19      NaN        NaN        NaN         NaN
# 2018-04-20      NaN        NaN        NaN         NaN
# 2018-04-23      NaN        NaN        NaN         NaN
# 2018-04-24      NaN        NaN        NaN         NaN
# 2018-04-25      NaN        NaN        NaN         NaN
# 2018-04-26      NaN        NaN        NaN         NaN
# 2018-04-27      NaN        NaN        NaN         NaN
# 2018-04-30      NaN        NaN        NaN         NaN
# 2018-05-02      NaN        NaN        NaN         NaN
# 2018-05-03      NaN        NaN        NaN         NaN
# 2018-05-04      NaN        NaN        NaN         NaN
# 2018-05-07      NaN        NaN        NaN         NaN
# 2018-05-08      NaN        NaN        NaN         NaN
# 2018-05-09      NaN        NaN        NaN         NaN
# 2018-05-10      NaN        NaN        NaN         NaN
# 2018-05-11      NaN        NaN        NaN         NaN
# 2018-05-14      NaN        NaN        NaN         NaN
# 2018-05-15      NaN        NaN        NaN         NaN
# 2018-05-16      NaN        NaN        NaN         NaN
#
# [1261 rows x 23 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(cci30.loc[start_date:end_date, :].index, cci30.loc[start_date:end_date, 'CCI'], label = 'For 30 days')
ax.plot(cci40.loc[start_date:end_date, :].index, cci40.loc[start_date:end_date, 'CCI'], label = 'For 40 days')
ax.plot(cci50.loc[start_date:end_date, :].index, cci50.loc[start_date:end_date, 'CCI'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Chakin Volatility Indicator (30,40,50)

# %%
def chaikin_oscillator(data, periods_short=3, periods_long=30, high_col='High',
                       low_col='Low', close_col='Close', vol_col='Volume'):
    ac = pd.Series([])

    for index, row in data.iterrows():
        if row[high_col] != row[low_col]:
            val = ((row[close_col] - row[low_col]) - (row[high_col] - row[close_col])) / (row[high_col] - row[low_col]) * row[vol_col]
        else:
            val = 0
        ac.set_value(index, val)

    ema_long = ac.ewm(ignore_na=False, min_periods=0, com=periods_long, adjust=True).mean()
    ema_short = ac.ewm(ignore_na=False, min_periods=0, com=periods_short, adjust=True).mean()
    data['ch_osc'] = ema_short - ema_long

    return data

# %%
ch30=chaikin_oscillator(df,3,30)
ch40=chaikin_oscillator(df,3,40)
ch50=chaikin_oscillator(df,3,50)

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ch30.loc[start_date:end_date, :].index, ch30.loc[start_date:end_date, 'ch_osc'], label = 'For 30 days')
ax.plot(ch40.loc[start_date:end_date, :].index, ch40.loc[start_date:end_date, 'ch_osc'], label = 'For 40 days')
ax.plot(ch50.loc[start_date:end_date, :].index, ch50.loc[start_date:end_date, 'ch_osc'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')

#overlapped each other
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Rate of Price Change (30,40,50)

# %%
def ROC(data,n):
 N = data['Close'].diff(n)
 D = data['Close'].shift(n)
 ROC = pd.Series(N/D,name='ROC')
 data = data.join(ROC)
 return data

# %%
roc30=ROC(df,30)
roc40=ROC(df,40)
roc50=ROC(df,50)

# %%
roc30
# Out:
#                   Open        High         Low   Adj Close      Volume  \
# Date
# 2013-04-04  209.044998  209.699997  205.744995  138.633301  15062340.0
# 2013-04-05  206.759995  208.399994  204.199997  137.902481  16152430.0
# 2013-04-08  205.740005  207.139999  202.869995  136.360321  10811270.0
# 2013-04-09  204.524994  206.600006  198.000000  133.312881  18252900.0
# 2013-04-10  199.899994  202.865005  197.610001  135.652924  18994350.0
# 2013-04-11  203.479996  205.000000  200.800003  136.940308  18848870.0
# 2013-04-12  204.000000  209.699997  202.000000  139.585403  20632180.0
# 2013-04-15  206.300003  215.839996  206.259995  143.910187  18089020.0
# 2013-04-16  214.800003  219.395004  214.000000  146.377640  14838250.0
# 2013-04-17  219.500000  226.985001  219.500000  150.538101  24644810.0
# 2013-04-18  225.339996  231.255005  223.500000  154.192352  21382190.0
# 2013-04-22  229.964996  236.000000  229.964996  156.032883  14450260.0
# 2013-04-23  234.000000  234.330002  226.600006  153.377686  18770200.0
# 2013-04-25  228.750000  234.300003  228.750000  156.532410  20535590.0
# 2013-04-26  232.500000  233.455002  227.714996  153.407867  11550470.0
# 2013-04-29  230.199997  230.945007  226.210007  152.442322  13964420.0
# 2013-04-30  228.199997  229.250000  222.535004  151.822113  14814500.0
# 2013-05-02  226.429993  232.684998  226.429993  154.178955  20143690.0
...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-06    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-07    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-08    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-09    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-10    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-13    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-14    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-15    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-16    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-17    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-20    ...        NaN      NaN      NaN      NaN      NaN      NaN
# ...           ...        ...      ...      ...      ...      ...      ...
# 2018-04-04    ...     264.72  282.501  246.939  274.278  299.476   249.08
# 2018-04-05    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-06    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-09    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-10    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-11    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-12    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-13    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-16    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-17    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-18    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-19    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-20    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-23    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-24    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-25    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-26    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-27    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-30    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-02    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-03    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-04    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-07    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-08    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-09    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-10    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-11    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-14    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-15    ...        NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-16    ...        NaN      NaN      NaN      NaN      NaN      NaN
#
#                    %K         %D        ch_osc       ROC
# Date
# 2013-04-04        NaN        NaN  0.000000e+00       NaN
# 2013-04-05        NaN        NaN  1.652325e+05       NaN
# 2013-04-08        NaN        NaN -1.099636e+05       NaN
# 2013-04-09        NaN        NaN -9.276317e+05       NaN
# 2013-04-10        NaN        NaN  2.237434e+06       NaN
# 2013-04-11        NaN        NaN  3.607182e+06       NaN
# 2013-04-12        NaN        NaN  4.430744e+06       NaN
# 2013-04-15        NaN        NaN  5.010681e+06       NaN
# 2013-04-16        NaN        NaN  4.594091e+06       NaN
# 2013-04-17        NaN        NaN  4.156508e+06       NaN
# 2013-04-18        NaN        NaN  4.735825e+06       NaN
# 2013-04-22        NaN        NaN  2.476748e+06       NaN
# 2013-04-23        NaN        NaN -3.137176e+05       NaN
# 2013-04-25  93.370674        NaN  1.675644e+06       NaN
# 2013-04-26  81.232086        NaN -7.632835e+05       NaN
# 2013-04-29  77.481104  84.027955 -2.466448e+06       NaN
# 2013-04-30  75.071614  77.928268 -1.876744e+06       NaN
# 2013-05-02  84.227681  78.926800 -1.411628e+06       NaN
# 2013-05-03  58.465920  72.588405 -7.200200e+06       NaN
# 2013-05-06  60.617650  67.770417 -2.721154e+06       NaN
# 2013-05-07  65.299243  61.460937 -5.952038e+05       NaN
# 2013-05-08  52.136368  59.351087 -4.524201e+05       NaN
# 2013-05-09  60.988700  59.474770 -9.005432e+04       NaN
# 2013-05-10  62.485875  58.536981 -2.269059e+06       NaN
# 2013-05-13  53.502840  58.992471 -3.542490e+06       NaN
# 2013-05-14  68.652468  61.547061 -2.731767e+06       NaN
# 2013-05-15  95.209699  72.455002  2.048773e+06       NaN
# 2013-05-16  92.288146  85.383438  3.086891e+06       NaN
# 2013-05-17  94.435756  93.977867  3.886203e+06       NaN
# 2013-05-20  79.169532  88.631144 -3.273838e+05       NaN
# ...               ...        ...           ...       ...
# 2018-04-04  56.521766  54.281515 -2.792143e+06 -0.089637
# 2018-04-05        NaN        NaN -2.792143e+06       NaN
# 2018-04-06        NaN        NaN -2.792143e+06       NaN
# 2018-04-09        NaN        NaN -2.792143e+06       NaN
# 2018-04-10        NaN        NaN -2.792143e+06       NaN
# 2018-04-11        NaN        NaN -2.792143e+06       NaN
# 2018-04-12        NaN        NaN -2.792143e+06       NaN
# 2018-04-13        NaN        NaN -2.792143e+06       NaN
# 2018-04-16        NaN        NaN -2.792143e+06       NaN
# 2018-04-17        NaN        NaN -2.792143e+06       NaN
# 2018-04-18        NaN        NaN -2.792143e+06       NaN
# 2018-04-19        NaN        NaN -2.792143e+06       NaN
# 2018-04-20        NaN        NaN -2.792143e+06       NaN
# 2018-04-23        NaN        NaN -2.792143e+06       NaN
# 2018-04-24        NaN        NaN -2.792143e+06       NaN
# 2013-04-16        NaN        NaN  4.594091e+06       NaN
# 2013-04-17        NaN        NaN  4.156508e+06       NaN
# 2013-04-18        NaN        NaN  4.735825e+06       NaN
# 2013-04-22        NaN        NaN  2.476748e+06       NaN
# 2013-04-23        NaN        NaN -3.137176e+05       NaN
# 2013-04-25  93.370674        NaN  1.675644e+06       NaN
# 2013-04-26  81.232086        NaN -7.632835e+05       NaN
# 2013-04-29  77.481104  84.027955 -2.466448e+06       NaN
# 2013-04-30  75.071614  77.928268 -1.876744e+06       NaN
# 2013-05-02  84.227681  78.926800 -1.411628e+06       NaN
# 2013-05-03  58.465920  72.588405 -7.200200e+06       NaN
# 2013-05-06  60.617650  67.770417 -2.721154e+06       NaN
# 2013-05-07  65.299243  61.460937 -5.952038e+05       NaN
# 2013-05-08  52.136368  59.351087 -4.524201e+05       NaN
# 2013-05-09  60.988700  59.474770 -9.005432e+04       NaN
# 2013-05-10  62.485875  58.536981 -2.269059e+06       NaN
# 2013-05-13  53.502840  58.992471 -3.542490e+06       NaN
# 2013-05-14  68.652468  61.547061 -2.731767e+06       NaN
# 2013-05-15  95.209699  72.455002  2.048773e+06       NaN
# 2013-05-16  92.288146  85.383438  3.086891e+06       NaN
# 2013-05-17  94.435756  93.977867  3.886203e+06       NaN
# 2013-05-20  79.169532  88.631144 -3.273838e+05       NaN
# ...               ...        ...           ...       ...
# 2018-04-04  56.521766  54.281515 -2.792143e+06 -0.379512
# 2018-04-05        NaN        NaN -2.792143e+06       NaN
# 2018-04-06        NaN        NaN -2.792143e+06       NaN
# 2018-04-09        NaN        NaN -2.792143e+06       NaN
# 2018-04-10        NaN        NaN -2.792143e+06       NaN
# 2018-04-11        NaN        NaN -2.792143e+06       NaN
# 2018-04-12        NaN        NaN -2.792143e+06       NaN
# 2018-04-13        NaN        NaN -2.792143e+06       NaN
# 2018-04-16        NaN        NaN -2.792143e+06       NaN
# 2018-04-17        NaN        NaN -2.792143e+06       NaN
# 2018-04-18        NaN        NaN -2.792143e+06       NaN
# 2018-04-19        NaN        NaN -2.792143e+06       NaN
# 2018-04-20        NaN        NaN -2.792143e+06       NaN
# 2018-04-23        NaN        NaN -2.792143e+06       NaN
# 2018-04-24        NaN        NaN -2.792143e+06       NaN
# 2018-04-25        NaN        NaN -2.792143e+06       NaN
# 2018-04-26        NaN        NaN -2.792143e+06       NaN
# 2018-04-27        NaN        NaN -2.792143e+06       NaN
# 2018-04-30        NaN        NaN -2.792143e+06       NaN
# 2018-05-02        NaN        NaN -2.792143e+06       NaN
# 2018-05-03        NaN        NaN -2.792143e+06       NaN
# 2018-05-04        NaN        NaN -2.792143e+06       NaN
# 2018-05-07        NaN        NaN -2.792143e+06       NaN
# 2018-05-08        NaN        NaN -2.792143e+06       NaN
# 2018-05-09        NaN        NaN -2.792143e+06       NaN
# 2018-05-10        NaN        NaN -2.792143e+06       NaN
# 2018-05-11        NaN        NaN -2.792143e+06       NaN
# 2018-05-14        NaN        NaN -2.792143e+06       NaN
# 2018-05-15        NaN        NaN -2.792143e+06       NaN
# 2018-05-16        NaN        NaN -2.792143e+06       NaN
#
# [1261 rows x 24 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(roc30.loc[start_date:end_date, :].index, roc30.loc[start_date:end_date, 'ROC'], label = 'For 30 days')
ax.plot(roc40.loc[start_date:end_date, :].index, roc40.loc[start_date:end_date, 'ROC'], label = 'For 40 days')
ax.plot(roc50.loc[start_date:end_date, :].index, roc50.loc[start_date:end_date, 'ROC'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')
