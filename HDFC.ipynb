dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
df1['Date']=pd.to_datetime(df1['Date'])

# %%
df1.isnull().sum()
# Out:
# Date         0
# Open         2
# High         2
# Low          2
# Close        2
# Adj Close    2
# Volume       2
# dtype: int64

# %%
df1.fillna(df1.mean(),inplace=True)

# %%
close_zero=df1.iloc[-1].Close

# %%
df1['HL_PCT'] = (df1['High'] - df1['Low'])/(df1['Low']*100)

# %%
df1['PCT_CHNG_OpCl'] = (df1['Close'] - df1['Open'])/(df1['Open']*100)

# %%
df1['PCT_CHNG_CLOSE'] = (df1['Close'] - df1['Adj Close'])/(df1['Adj Close']*100)

# %%
df1.index=df1['Date']

# %%
df1.head()
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2013-04-04 2013-04-04  618.799988  623.400024  613.450012  616.150024
# 2013-04-05 2013-04-05  614.950012  626.400024  613.400024  620.950012
# 2013-04-08 2013-04-08  618.950012  628.950012  617.750000  624.450012
# 2013-04-09 2013-04-09  628.099976  628.099976  617.400024  620.599976
# 2013-04-10 2013-04-10  626.799988  633.650024  618.950012  632.000000
#
#              Adj Close     Volume    HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE
# Date
# 2013-04-04  592.567261  2045496.0  0.000162      -0.000043        0.000398
# 2013-04-05  597.183472  3239980.0  0.000212       0.000098        0.000398
# 2013-04-08  600.549622  2163032.0  0.000181       0.000089        0.000398
# 2013-04-09  596.846863  3690102.0  0.000173      -0.000119        0.000398
# 2013-04-10  607.810608  3786126.0  0.000237       0.000083        0.000398

# %%
df=df1[['Open','High','Low','Adj Close','Volume','HL_PCT','PCT_CHNG_OpCl','PCT_CHNG_CLOSE','Close']]

# %% [markdown]
# ## Prediction for 30th Day

# %%
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
import datetime
# Out:
# C:\Users\Debadri\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df['Close'].plot(figsize=(15,6), color="green")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.tail()
# Out:
#                    Open         High          Low    Adj Close     Volume  \
# Date
# 2018-03-27  1893.800049  1899.000000  1876.000000  1892.599976  1534209.0
# 2018-03-28  1882.949951  1899.699951  1876.050049  1886.099976  2209377.0
# 2018-04-02  1886.099976  1935.750000  1886.099976  1931.199951  1149092.0
# 2018-04-03  1923.949951  1925.699951  1911.000000  1915.900024  1019971.0
# 2018-04-04  1912.949951  1924.949951  1878.449951  1883.250000   928527.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE        Close
# Date
# 2018-03-27  0.000123      -0.000006             0.0  1892.599976
# 2018-03-28  0.000126       0.000017             0.0  1886.099976
# 2018-04-02  0.000263       0.000239             0.0  1931.199951
# 2018-04-03  0.000077      -0.000042             0.0  1915.900024
# 2018-04-04  0.000248      -0.000155             0.0  1883.250000

# %%
forecast_col = 'Close'

forecast_out = int(42)
# We will drop 12 columns because there are 12 holidays

# %%
df['label'] = df[forecast_col].shift(-forecast_out)
print(df.head(2))
# Out:
#                   Open        High         Low   Adj Close     Volume  \
# Date
# 2013-04-04  618.799988  623.400024  613.450012  592.567261  2045496.0
# 2013-04-05  614.950012  626.400024  613.400024  597.183472  3239980.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close       label
# Date
# 2013-04-04  0.000162      -0.000043        0.000398  616.150024  682.200012
# 2013-04-05  0.000212       0.000098        0.000398  620.950012  676.150024

# %%
X = np.array(df.drop(['label'], 1))

# %%
X = preprocessing.scale(X)

# %%
X_forecast_out = X[-forecast_out:]
X = X[:-forecast_out]

# %%
y = np.array(df['label'])
y = y[:-forecast_out]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
clf = LinearRegression()
clf.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("Accurac
# 2013-04-22 00:00:00  698.299988  635.250000          NaN
# 2013-04-23 00:00:00  689.000000  625.349976          NaN
# 2013-04-25 00:00:00  689.549988  634.000000          NaN
# 2013-04-26 00:00:00  689.099976  622.849976          NaN
# 2013-04-29 00:00:00  695.150024  646.500000          NaN
# 2013-04-30 00:00:00  682.299988  669.500000          NaN
# 2013-05-02 00:00:00  692.500000  668.750000          NaN
# 2013-05-03 00:00:00  680.950012  656.549988          NaN
# 2013-05-06 00:00:00  675.500000  650.650024          NaN
# 2013-05-07 00:00:00  688.049988  655.150024          NaN
# 2013-05-08 00:00:00  697.150024  667.750000          NaN
# 2013-05-09 00:00:00  690.049988  660.450012          NaN
# 2013-05-10 00:00:00  703.349976  670.299988          NaN
# 2013-05-13 00:00:00  692.750000  659.299988          NaN
# 2013-05-14 00:00:00  689.049988  683.250000          NaN
# 2013-05-15 00:00:00  714.849976  695.750000          NaN
# 2013-05-16 00:00:00  722.799988  695.450012          NaN
# 2013-05-17 00:00:00  718.900024  678.700012          NaN
# 2013-05-20 00:00:00  714.500000  662.900024          NaN
# ...                         ...         ...          ...
# 2018-04-17 05:30:00         NaN         NaN  1913.214408
# 2018-04-18 05:30:00         NaN         NaN  1902.736582
# 2018-04-19 05:30:00         NaN         NaN  1908.679754
# 2018-04-20 05:30:00         NaN         NaN  1908.149015
# 2018-04-21 05:30:00         NaN         NaN  1915.068773
# 2018-04-22 05:30:00         NaN         NaN  1948.160510
# 2018-04-23 05:30:00         NaN         NaN  1948.691987
# 2018-04-24 05:30:00         NaN         NaN  1934.918531
# 2018-04-25 05:30:00         NaN         NaN  1919.638266
# 2018-04-26 05:30:00         NaN         NaN  1916.687801
# 2018-04-27 05:30:00         NaN         NaN  1874.686635
# 2018-04-28 05:30:00         NaN         NaN  1881.758106
# 2018-04-29 05:30:00         NaN         NaN  1897.146108
# 2018-04-30 05:30:00         NaN         NaN  1900.862997
# 2018-05-01 05:30:00         NaN         NaN  1920.972398
# 2018-05-02 05:30:00         NaN         NaN  1903.240778
# 2018-05-03 05:30:00         NaN         NaN  1913.380435
# 2018-05-04 05:30:00         NaN         NaN  1930.907040
# 2018-05-05 05:30:00         NaN         NaN  1885.528173
# 2018-05-06 05:30:00         NaN         NaN  1903.020991
# 2018-05-07 05:30:00         NaN         NaN  1891.335860
# 2018-05-08 05:30:00         NaN         NaN  1910.332140
# 2018-05-09 05:30:00         NaN         NaN  1916.146363
# 2018-05-10 05:30:00         NaN         NaN  1898.302017
# 2018-05-11 05:30:00         NaN         NaN  1898.572992
# 2018-05-12 05:30:00         NaN         NaN  1934.622961
# 2018-05-13 05:30:00         NaN         NaN  1934.554473
# 2018-05-14 05:30:00         NaN         NaN  1950.349711
# 2018-05-15 05:30:00         NaN         NaN  1966.668787
# 2018-05-16 05:30:00         NaN         NaN  1903.049530
#
# [1274 rows x 11 columns]

# %%
pred=df[-42:]

# %%
df=df[:-42]

# %%
pred
# Out:
#                      Open  High  Low  Adj Close  Volume  HL_PCT  \
# Date
# 2018-04-05 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-06 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-07 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-08 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-09 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-10 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-11 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-12 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-13 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-14 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-15 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-16 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-17 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-18 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-19 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-20 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-21 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#    PCT_CHNG_CLOSE  Close  label     forecast
# 0             NaN    NaN    NaN  2044.206238

# %%
holidays=['2018-04-07','2018-04-08','2018-04-14','2018-04-15','2018-04-21','2018-04-22','2018-04-28','2018-04-29','2018-05-01','2018-05-05','2018-05-06','2018-05-12','2018-05-13']

# %%
pred['Date']=pred['Date'].apply(str)

# %%
for i in holidays:
    pred = pred.drop(pred[pred.Date==i].index)

# %%
pred['Date']=pd.to_datetime(pred['Date'])

# %%
pred.drop('forecast',axis=1,inplace=True)

# %%
pred.shape
# Out:
# (29, 11)

# %%
pred['forecast']=forecast_prediction[:29]

# %%
pred
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 1  2018-04-06   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 4  2018-04-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 5  2018-04-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 6  2018-04-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 7  2018-04-12   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 8  2018-04-13   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 11 2018-04-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 12 2018-04-17   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 13 2018-04-18   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 14 2018-04-19   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 15 2018-04-20   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 18 2018-04-23   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 19 2018-04-24   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 20 2018-04-25   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 21 2018-04-26   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 22 2018-04-27   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 25 2018-04-30   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 27 2018-05-02   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 28 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 29 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 32 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 33 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 34 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 35 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 36 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 39 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 40 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 41 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#     PCT_CHNG_CLOSE  Close  label     forecast
# 0              NaN    NaN    NaN  2044.206238
# 1              NaN    NaN    NaN  2023.231902
# 4              NaN    NaN    NaN  1958.797563
# 5              NaN    NaN    NaN  1954.317631
# 6              NaN    NaN    NaN  1888.335838
# 7              NaN    NaN    NaN  1891.361868
# 8              NaN    NaN    NaN  1916.947711
# 11             NaN    NaN    NaN  1903.770219
# 12             NaN    NaN    NaN  1916.801245
# 13             NaN    NaN    NaN  1932.420554
# 14             NaN    NaN    NaN  1929.930786
# 15             NaN    NaN    NaN  1930.106396
# 18             NaN    NaN    NaN  1913.214408
# 19             NaN    NaN    NaN  1902.736582
# 20             NaN    NaN    NaN  1908.679754
# 21             NaN    NaN    NaN  1908.149015
# 22             NaN    NaN    NaN  1915.068773
# 25             NaN    NaN    NaN  1948.160510
# 27             NaN    NaN    NaN  1948.691987
# 28             NaN    NaN    NaN  1934.918531
# 29             NaN    NaN    NaN  1919.638266
# 32             NaN    NaN    NaN  1916.687801
# 33             NaN    NaN    NaN  1874.686635
# 34             NaN    NaN    NaN  1881.758106
# 35             NaN    NaN    NaN  1897.146108
# 36             NaN    NaN    NaN  1900.862997
# 39             NaN    NaN    NaN  1920.972398
# 40             NaN    NaN    NaN  1903.240778
# 41             NaN    NaN    NaN  1913.380435

# %%
pred.index=pred['Date']
pred.drop('Date',axis=1,inplace=True)

# %%
df=df.append(pred)

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.xlim(xmin=datetime.date(2018, 4, 4))
plt.ylim(ymin=-100)
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.iloc[-1]
# Out:
# Open                      NaN
# High                      NaN
# Low                       NaN
# Adj Close                 NaN
# Volume                    NaN
# HL_PCT                    NaN
# PCT_CHNG_OpCl             NaN
# PCT_CHNG_CLOSE            NaN
# Close                     NaN
# label                     NaN
# forecast          1913.380435
# Name: 2018-05-16 00:00:00, dtype: float64

# %%
close_last=df.iloc[-1].forecast

# %%
pred_return=close_last-close_zero
print("Predicted Return: Rs.",pred_return)
# Out:
# Predicted Return: Rs. 30.130435073577473

# %% [markdown]
# ## Simple Moving Average (30,40,50)

# %%
# For 30 days
short_rolling = df.rolling(window=30).mean()
short_rolling.head(30)
# Out:
#                   Open        High         Low  Adj Close        Volume  \
# Date
# 2013-04-04         NaN         NaN         NaN        NaN           NaN
# 2013-04-05         NaN         NaN         NaN        NaN           NaN
# 2013-04-08         NaN         NaN         NaN        NaN           NaN
# 2013-04-09         NaN         NaN         NaN        NaN           NaN
# 2013-04-10         NaN         NaN         NaN        NaN           NaN
# 2013-04-11         NaN         NaN         NaN        NaN           NaN
# 2013-04-12         NaN         NaN         NaN        NaN           NaN
# 2013-04-15         NaN         NaN         NaN        NaN           NaN
# 2013-04-16         NaN         NaN         NaN        NaN           NaN
# 2013-04-17         NaN         NaN         NaN        NaN           NaN
# 2013-04-18         NaN         NaN         NaN        NaN           NaN
# 2013-04-22         NaN         NaN         NaN        NaN           NaN
# 2013-04-23         NaN         NaN         NaN        NaN           NaN
# 2013-04-25         NaN         NaN         NaN        NaN           NaN
# 2013-04-26         NaN         NaN         NaN        NaN           NaN
# 2013-04-29         NaN         NaN         NaN        NaN           NaN
# 2013-04-30         NaN         NaN         NaN        NaN           NaN
# 2013-05-02         NaN         NaN         NaN        NaN           NaN
# 2013-05-03         NaN         NaN         NaN        NaN           NaN
# 2013-05-06         NaN         NaN         NaN        NaN           NaN
# 2013-05-07         NaN         NaN         NaN        NaN           NaN
# 2013-05-08         NaN         NaN         NaN        NaN           NaN
# 2013-05-09         NaN         NaN         NaN        NaN           NaN
# 2013-05-10         NaN         NaN         NaN        NaN           NaN
# 2013-05-13         NaN         NaN         NaN        NaN           NaN
# 2013-05-14         NaN         NaN         NaN        NaN           NaN
# 2013-05-15         NaN         NaN         NaN        NaN           NaN
# 2013-05-16         NaN         NaN         NaN        NaN           NaN
# 2013-05-17         NaN         NaN         NaN        NaN           NaN
# 2013-05-20  672.036662  680.696669  666.073334  649.46933  3.228556e+06
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close       label  \
# Date
# 2013-04-04       NaN            NaN             NaN         NaN         NaN
# 2013-04-05       NaN            NaN             NaN         NaN         NaN
# 2013-04-08       NaN            NaN             NaN         NaN         NaN
# 2013-04-09       NaN            NaN             NaN         NaN         NaN
# 2013-04-10       NaN            NaN             NaN         NaN         NaN
# 2013-04-11       NaN            NaN             NaN         NaN         NaN
# 2013-04-12       NaN            NaN             NaN         NaN         NaN
# 2013-04-15       NaN            NaN             NaN         NaN         NaN
# 2013-04-16       NaN            NaN             NaN         NaN         NaN
# 2013-04-17       NaN            NaN             NaN         NaN         NaN
# 2013-04-18       NaN            NaN             NaN         NaN         NaN
# 2013-04-22       NaN            NaN             NaN         NaN         NaN
# 2013-04-23       NaN            NaN             NaN         NaN         NaN
# 2013-04-25       NaN            NaN             NaN         NaN         NaN
# 2013-04-26       NaN            NaN             NaN         NaN         NaN
# 2013-04-29       NaN            NaN             NaN         NaN         NaN
# 2013-04-30       NaN            NaN             NaN         NaN         NaN
# 2013-05-02       NaN            NaN             NaN         NaN         NaN
# 2013-05-03       NaN            NaN             NaN         NaN         NaN
# 2013-05-06       NaN            NaN             NaN         NaN         NaN
# 2013-05-07       NaN            NaN             NaN         NaN         NaN
# 2013-05-08       NaN            NaN             NaN         NaN         NaN
# 2013-05-09       NaN            NaN             NaN         NaN         NaN
# 2013-05-10       NaN            NaN             NaN         NaN         NaN
# 2013-05-13       NaN            NaN             NaN         NaN         NaN
# 2013-05-14       NaN            NaN             NaN         NaN         NaN
# 2013-05-15       NaN            NaN             NaN         NaN         NaN
# 2013-05-16       NaN            NaN             NaN         NaN         NaN
# 2013-05-17       NaN            NaN             NaN         NaN         NaN
# 2013-05-20  0.000219        0.00005        0.000398  675.316663  661.623334
#
#             forecast
# Date
# 2013-04-04       NaN
# 2013-04-05       NaN
# 2013-04-08       NaN
# 2013-04-09       NaN
# 2013-04-10       NaN
# 2013-04-11       NaN
# 2013-04-12       NaN
# 2013-04-15       NaN
# 2013-04-16       NaN
# 2013-04-17       NaN
# 2013-04-18       NaN
# 2013-04-22       NaN
# 2013-04-23       NaN
# 2013-04-25       NaN
# 2013-04-26       NaN
# 2013-04-29       NaN
# 2013-04-30       NaN
# 2013-05-02       NaN
# 2013-05-03       NaN
# 2013-05-06       NaN
# 2013-05-07       NaN
# 2013-05-08       NaN
# 2013-05-09       NaN
# 2013-05-10       NaN
# 2013-05-13       NaN
# 2013-05-14       NaN
# 2013-05-15       NaN
# 2013-05-16       NaN
# 2013-05-17       NaN
# 2013-05-20       NaN

# %%
# For 40 days
med_rolling = df.rolling(window=40).mean()
med_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
# For 50 days
long_rolling = df.rolling(window=50).mean()
long_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
start_date = '2013-04-29'
end_date = '2018-04-04'

fig, ax = plt.subplots(figsize=(16,9))

ax.plot(long_rolling.loc[start_date:end_date, :].index, long_rolling.loc[start_date:end_date, 'Close'], label = '50-days SMA')
ax.plot(med_rolling.loc[start_date:end_date, :].index, med_rolling.loc[start_date:end_date, 'Close'], label = '40-days SMA')
ax.plot(short_rolling.loc[start_date:end_date, :].index, short_rolling.loc[start_date:end_date, 'Close'], label = '30-days SMA')


ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Exponential Moving Average (30,40,50)

# %%
ema_short = df.ewm(span=30, adjust=False).mean()
ema_med = df.ewm(span=40, adjust=False).mean()
ema_long = df.ewm(span=50, adjust=False).mean()

fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ema_short.loc[start_date:end_date, :].index, ema_short.loc[start_date:end_date, 'Close'], label = 'Span 30-days EMA')
ax.plot(ema_med.loc[start_date:end_date, :].index, ema_med.loc[start_date:end_date, 'Close'], label = 'Span 40-days EMA')
ax.plot(ema_long.loc[start_date:end_date, :].index, ema_long.loc[start_date:end_date, 'Close'], label = 'Span 50-days EMA')

ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Aroon Oscillator (30,40,50)

# %%
from pandas.stats import moments
from pandas import DataFrame

# %%
def aroon(s, n):
    up = 100 * moments.rolling_apply(s.High, n + 1, lambda x: x.argmax()) / n
    dn = 100 * moments.rolling_apply(s.Low, n + 1, lambda x: x.argmin()) / n

    return DataFrame(dict(up=up, down=dn))

# %%
ao30=aroon(df,30)
ao40=aroon(df,40)
ao50=aroon(df,50)

# %%
ao30
# Out:
#             down         up
# Date
# 2013-04-04   NaN        NaN
# 2013-04-05   NaN        NaN
# 2013-04-08   NaN        NaN
# 2013-04-09   NaN        NaN
# 2013-04-10   NaN        NaN
# 2013-04-11   NaN        NaN
# 2013-04-12   NaN        NaN
# 2013-04-15   NaN        NaN
# 2013-04-16   NaN        NaN
# 2013-04-17   NaN        NaN
# 2013-04-18   NaN        NaN
# 2013-04-22   NaN        NaN
# 2013-04-23   NaN        NaN
# 2013-04-25   NaN        NaN
# 2013-04-26   NaN        NaN
# 2013-04-29   NaN        NaN
# 2013-04-30   NaN        NaN
# 2013-05-02   NaN        NaN
# 2013-05-03   NaN        NaN
# 2013-05-06   NaN        NaN
# 2013-05-07   NaN        NaN
# 2013-05-08   NaN        NaN
# 2013-05-09   NaN        NaN
# 2013-05-10   NaN        NaN
# 2013-05-13   NaN        NaN
# 2013-05-14   NaN        NaN
# 2013-05-15   NaN        NaN
# 2013-05-16   NaN        NaN
# 2013-05-17   NaN        NaN
# 2013-05-20   NaN        NaN
# ...          ...        ...
# 2018-04-04  40.0  93.333333
# 2018-04-05   NaN        NaN
# 2018-04-06   NaN        NaN
# 2018-04-09   NaN        NaN
# 2018-04-10   NaN        NaN
# 2018-04-11   NaN        NaN
# 2018-04-12   NaN        NaN
# 2018-04-13   NaN        NaN
# 2018-04-16   NaN        NaN
# 2018-04-17   NaN        NaN
# 2018-04-18   NaN        NaN
# 2018-04-19   NaN        NaN
# 2018-04-20   NaN        NaN
# 2018-04-23   NaN        NaN
# 2018-04-24   NaN        NaN
# 2018-04-25   NaN        NaN
# 2018-04-26   NaN        NaN
# 2018-04-27   NaN        NaN
# 2018-04-30   NaN        NaN
# 2018-05-02   NaN        NaN
# 2018-05-03   NaN        NaN
# 2018-05-04   NaN        NaN
# 2018-05-07   NaN        NaN
# 2018-05-08   NaN        NaN
# 2018-05-09   NaN        NaN
# 2018-05-10   NaN        NaN
# 2018-05-11   NaN        NaN
# 2018-05-14   NaN        NaN
# 2018-05-15   NaN        NaN
# 2018-05-16   NaN        NaN
#
# [1261 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 30-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 30-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 40-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 40-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'down'], label = ' Down 50-days Aroon Oscillator')
ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'up'], label = 'Up 50-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %% [markdown]
# ## MACD Signal

# %%
def ema(s, n, wilder=False):
    span = n if not wilder else 2*n - 1
    return moments.ewma(s, span=span)


def macd(s, nfast=12, nslow=26, nsig=9, percent=True):
    fast, slow = ema(s, nfast), ema(s, nslow)

    if percent:
        macd = 100*(fast / slow - 1)
    else:
        macd = fast - slow

    sig = ema(macd, nsig)
    hist = macd - sig

    return DataFrame(dict(macd=macd, signal=sig, hist=hist,
                          fast=fast, slow=slow))

# %%
m=macd(df['Close'])

# %%
m.head(1)
# Out:
#                   fast  hist  macd  signal        slow
# Date
# 2013-04-04  616.150024   0.0   0.0     0.0  616.150024

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(m.loc[start_date:end_date, :].index, m.loc[start_date:end_date, 'macd'], label = 'MACD')

ax.legend(loc='best')
ax.set_ylabel('Change ')
# Out:
# Text(0,0.5,'Change ')

# %% [markdown]
# ## Relative Strength Index (RSI)

# %%
def rsi(s, n=14):
    diff = s.diff()
    which_dn = diff < 0

    up, dn = diff, diff*0
    up[which_dn], dn[which_dn] = 0, -up[which_dn]

    emaup = ema(up, n, wilder=True)
    emadn = ema(dn, n, wilder=True)

    return 100 * emaup/(emaup + emadn)

# %%
sf=rsi(df['Close'],50)

# %%
sfd=pd.DataFrame({'Date':sf.index, 'RSI':sf.values})

# %%
sfd.index=sfd['Date']

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(sfd.loc[start_date:end_date, :].index, sfd.loc[start_date:end_date, 'RSI'], label = 'RSI')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Bollinger Bands (30,40,50)

# %%
price=df["Close"]

def bbands(price, length=30, numsd=2):
    """ returns average, upper band, and lower band"""
    ave = pd.stats.moments.rolling_mean(price,length)
    sd = pd.stats.moments.rolling_std(price,length)
    upband = ave + (sd*numsd)
    dnband = ave - (sd*numsd)
    return np.round(ave,3), np.round(upband,3), np.round(dnband,3)

df['ave30'], df['upper30'], df['lower30'] = bbands(df.Close, length=30, numsd=1)
df['ave40'], df['upper40'], df['lower40'] = bbands(df.Close, length=40, numsd=1)
df['ave50'], df['upper50'], df['lower50'] = bbands(df.Close, length=50, numsd=1)

# %%
# For 30 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave30'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower30'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper30'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 40 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave40'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower40'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper40'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 50 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave50'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower50'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper50'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Stochastic Oscillator

# %%
def STOK(close, low, high, n): 
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 return STOK

def STOD(close, low, high, n):
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 STOD = pd.rolling_mean(STOK, 3)
 return STOD

# %%
df['%K'] = STOK(df['Close'], df['Low'], df['High'], 14)
df['%D'] = STOD(df['Close'], df['Low'], df['High'], 14)

# %%
df.plot(y=['Close'], figsize = (20, 5))
df.plot(y=['%K', '%D'], figsize = (20, 5))

# %% [markdown]
# ## Chande Oscillator

# %%
def avg_true_range(df): 
  ind = range(0,len(df))
  indexlist = list(ind)
  df.index = indexlist

  for index, row in df.iterrows():
    if index != 0:
      tr1 = row["High"] - row["Low"]
      tr2 = abs(row["High"] - df.iloc[index-1]["Close"])
      tr3 = abs(row["Low"] - df.iloc[index-1]["Close"])

      true_range = max(tr1, tr2, tr3)
      df.set_value(index,"True Range", true_range)

  df["Avg TR"] = df["True Range"].rolling(min_periods=14, window=14, center=False).mean()
  return df

# %%
def chandelier_exit(df):

  df_tr = avg_true_range(df)

  df_tr['rolling_high']= df_tr["High"]
  df_tr['rolling_low'] = df_tr["Low"]

  df_tr['chandelier_long'] = df_tr['rolling_high'] - df_tr["Avg TR"] * 3
  df_tr['chandelier_short'] = df_tr['rolling_low'] - df_tr["Avg TR"] * 3
  fig, ax = plt.subplots(figsize=(15,9))

  ax.plot(df_tr['Date'], df_tr['chandelier_long'], label = 'Chand Long')

# %%
ch=chandelier_exit(df1)

# %% [markdown]
# ## Commodity Channel Index (30,40,50)

# %%
def CCI(data, ndays): 
 TP = (data['High'] + data['Low'] + data['Close']) / 3 
 CCI = pd.Series((TP - pd.rolling_mean(TP, ndays)) / (0.015 * pd.rolling_std(TP, ndays)),
 name = 'CCI')
 data=data.join(CCI)
 return data

# %%
cci30=CCI(df,30)
cci40=CCI(df,40)
cci50=CCI(df,50)

# %%
cci30
# Out:
#                    Open         High          Low    Adj Close     Volume  \
# Date
# 2013-04-04   618.799988   623.400024   613.450012   592.567261  2045496.0
# 2013-04-05   614.950012   626.400024   613.400024   597.183472  3239980.0
# 2013-04-08   618.950012   628.950012   617.750000   600.549622  2163032.0
# 2013-04-09   628.099976   628.099976   617.400024   596.846863  3690102.0
# 2013-04-10   626.799988   633.650024   618.950012   607.810608  3786126.0
# 2013-04-11   632.500000   642.000000   631.900024   614.783142  6266517.0
# 2013-05-07  0.000259       0.000174        0.000398   688.049988  655.150024
# 2013-05-08  0.000189       0.000118        0.000398   697.150024  667.750000
# 2013-05-09  0.000164      -0.000129        0.000398   690.049988  660.450012
# 2013-05-10  0.000236       0.000213        0.000398   703.349976  670.299988
# 2013-05-13  0.000299      -0.000174        0.000398   692.750000  659.299988
# 2013-05-14  0.000143      -0.000014        0.000398   689.049988  683.250000
# 2013-05-15  0.000357       0.000308        0.000398   714.849976  695.750000
# 2013-05-16  0.000183       0.000152        0.000398   722.799988  695.450012
# 2013-05-17  0.000188      -0.000050        0.000398   718.900024  678.700012
# 2013-05-20  0.000166      -0.000069        0.000398   714.500000  662.900024
# ...              ...            ...             ...          ...         ...
# 2018-04-04  0.000248      -0.000155        0.000000  1883.250000         NaN
# 2018-04-05       NaN            NaN             NaN          NaN         NaN
# 2018-04-06       NaN            NaN             NaN          NaN         NaN
# 2018-04-09       NaN            NaN             NaN          NaN         NaN
# 2018-04-10       NaN            NaN             NaN          NaN         NaN
# 2018-04-11       NaN            NaN             NaN          NaN         NaN
# 2018-04-12       NaN            NaN             NaN          NaN         NaN
# 2018-04-13       NaN            NaN             NaN          NaN         NaN
# 2018-04-16       NaN            NaN             NaN          NaN         NaN
# 2018-04-17       NaN            NaN             NaN          NaN         NaN
# 2018-04-18       NaN            NaN             NaN          NaN         NaN
# 2018-04-19       NaN            NaN             NaN          NaN         NaN
# 2018-04-20       NaN            NaN             NaN          NaN         NaN
# 2018-04-23       NaN            NaN             NaN          NaN         NaN
# 2018-04-24       NaN            NaN             NaN          NaN         NaN
# 2018-04-25       NaN            NaN             NaN          NaN         NaN
# 2018-04-26       NaN            NaN             NaN          NaN         NaN
# 2018-04-27       NaN            NaN             NaN          NaN         NaN
# 2018-04-30       NaN            NaN             NaN          NaN         NaN
# 2018-05-02       NaN            NaN             NaN          NaN         NaN
# 2018-05-03       NaN            NaN             NaN          NaN         NaN
# 2018-05-04       NaN            NaN             NaN          NaN         NaN
# 2018-05-07       NaN            NaN             NaN          NaN         NaN
# 2018-05-08       NaN            NaN             NaN          NaN         NaN
# 2018-05-09       NaN            NaN             NaN          NaN         NaN
# 2018-05-10       NaN            NaN             NaN          NaN         NaN
# 2018-05-11       NaN            NaN             NaN          NaN         NaN
# 2018-05-14       NaN            NaN             NaN          NaN         NaN
# 2018-05-15       NaN            NaN             NaN          NaN         NaN
# 2018-05-16       NaN            NaN             NaN          NaN         NaN
#
#               ...       lower30     ave40   upper40   lower40     ave50  \
# Date          ...
# 2013-04-04    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-05    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-08    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-09    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-10    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-11    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-12    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-15    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-16    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-17    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-18    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-22    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-23    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-25    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-26    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-29    ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-30    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-02    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-03    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-06    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-07    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-08    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-09    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-10    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-13    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-14    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-15    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-16    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-17    ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-20    ...       643.696       NaN       NaN       NaN       NaN
# ...           ...           ...       ...       ...       ...       ...
# 2018-04-04    ...      1847.516  1875.584  1900.912  1850.256  1894.982
# 2018-04-05    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-06    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-09    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-10    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-11    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-12    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-13    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-16    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-17    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-18    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-19    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-20    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-23    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-24    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-25    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-26    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-27    ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-30    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-02    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-03    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-04    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-07    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-08    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-09    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-10    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-11    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-14    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-15    ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-16    ...           NaN       NaN       NaN       NaN       NaN
#
#             upper50   lower50         %K         %D        CCI
# Date
# 2013-04-04      NaN       NaN        NaN        NaN        NaN
# 2013-04-05      NaN       NaN        NaN        NaN        NaN
# 2013-04-08      NaN       NaN        NaN        NaN        NaN
# 2013-04-09      NaN       NaN        NaN        NaN        NaN
# 2013-04-10      NaN       NaN        NaN        NaN        NaN
# 2013-04-11      NaN       NaN        NaN        NaN        NaN
# 2013-04-12      NaN       NaN        NaN        NaN        NaN
# 2013-04-15      NaN       NaN        NaN        NaN        NaN
# 2013-04-16      NaN       NaN        NaN        NaN        NaN
# 2013-04-17      NaN       NaN        NaN        NaN        NaN
# 2013-04-18      NaN       NaN        NaN        NaN        NaN
# 2013-04-22      NaN       NaN        NaN        NaN        NaN
# 2013-04-23      NaN       NaN        NaN        NaN        NaN
# 2013-04-25      NaN       NaN  85.948064        NaN        NaN
# 2013-04-26      NaN       NaN  85.440150        NaN        NaN
# 2013-04-29      NaN       NaN  91.903099  87.763771        NaN
# 2013-04-30      NaN       NaN  76.713927  84.685725        NaN
# 2013-05-02      NaN       NaN  88.561106  85.726044        NaN
# 2013-05-03      NaN       NaN  69.971476  78.415503        NaN
# 2013-05-06      NaN       NaN  60.447761  72.993448        NaN
# 2013-05-07      NaN       NaN  79.179087  69.866108        NaN
# 2013-05-08      NaN       NaN  91.869281  77.165376        NaN
# 2013-05-09      NaN       NaN  75.104142  82.050836        NaN
# 2013-05-10      NaN       NaN  96.954720  87.976048        NaN
# 2013-05-13      NaN       NaN  54.939730  75.666197        NaN
# 2013-05-14      NaN       NaN  46.024039  65.972830        NaN
# 2013-05-15      NaN       NaN  97.502662  66.155477        NaN
# 2013-05-16      NaN       NaN  97.779811  80.435504        NaN
# 2013-05-17      NaN       NaN  90.564335  95.282269        NaN
# 2013-05-20      NaN       NaN  82.423678  90.255941  91.525841
# ...             ...       ...        ...        ...        ...
# 2018-04-04  1941.41  1848.554  48.655257  74.930717  75.012766
# 2018-04-05      NaN       NaN        NaN        NaN        NaN
# 2018-04-06      NaN       NaN        NaN        NaN        NaN
# 2018-04-09      NaN       NaN        NaN        NaN        NaN
# 2018-04-10      NaN       NaN        NaN        NaN        NaN
# 2018-04-11      NaN       NaN        NaN        NaN        NaN
# 2018-04-12      NaN       NaN        NaN        NaN        NaN
# 2018-04-13      NaN       NaN        NaN        NaN        NaN
# 2018-04-16      NaN       NaN        NaN        NaN        NaN
# 2018-04-17      NaN       NaN        NaN        NaN        NaN
# 2018-04-18      NaN       NaN        NaN        NaN        NaN
# 2018-04-19      NaN       NaN        NaN        NaN        NaN
# 2018-04-20      NaN       NaN        NaN        NaN        NaN
# 2018-04-23      NaN       NaN        NaN        NaN        NaN
# 2018-04-24      NaN       NaN        NaN        NaN        NaN
# 2018-04-25      NaN       NaN        NaN        NaN        NaN
# 2018-04-26      NaN       NaN        NaN        NaN        NaN
# 2018-04-27      NaN       NaN        NaN        NaN        NaN
# 2018-04-30      NaN       NaN        NaN        NaN        NaN
# 2018-05-02      NaN       NaN        NaN        NaN        NaN
# 2018-05-03      NaN       NaN        NaN        NaN        NaN
# 2018-05-04      NaN       NaN        NaN        NaN        NaN
# 2018-05-07      NaN       NaN        NaN        NaN        NaN
# 2018-05-08      NaN       NaN        NaN        NaN        NaN
# 2018-05-09      NaN       NaN        NaN        NaN        NaN
# 2018-05-10      NaN       NaN        NaN        NaN        NaN
# 2018-05-11      NaN       NaN        NaN        NaN        NaN
# 2018-05-14      NaN       NaN        NaN        NaN        NaN
# 2018-05-15      NaN       NaN        NaN        NaN        NaN
# 2018-05-16      NaN       NaN        NaN        NaN        NaN
#
# [1261 rows x 23 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(cci30.loc[start_date:end_date, :].index, cci30.loc[start_date:end_date, 'CCI'], label = 'For 30 days')
ax.plot(cci40.loc[start_date:end_date, :].index, cci40.loc[start_date:end_date, 'CCI'], label = 'For 40 days')
ax.plot(cci50.loc[start_date:end_date, :].index, cci50.loc[start_date:end_date, 'CCI'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Chakin Volatility Indicator (30,40,50)

# %%
def chaikin_oscillator(data, periods_short=3, periods_long=30, high_col='High',
                       low_col='Low', close_col='Close', vol_col='Volume'):
    ac = pd.Series([])

    for index, row in data.iterrows():
        if row[high_col] != row[low_col]:
            val = ((row[close_col] - row[low_col]) - (row[high_col] - row[close_col])) / (row[high_col] - row[low_col]) * row[vol_col]
        else:
            val = 0
        ac.set_value(index, val)

    ema_long = ac.ewm(ignore_na=False, min_periods=0, com=periods_long, adjust=True).mean()
    ema_short = ac.ewm(ignore_na=False, min_periods=0, com=periods_short, adjust=True).mean()
    data['ch_osc'] = ema_short - ema_long

    return data

# %%
ch30=chaikin_oscillator(df,3,30)
ch40=chaikin_oscillator(df,3,40)
ch50=chaikin_oscillator(df,3,50)

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(
# 2013-04-16  0.000366       0.000316        0.000398   663.349976  657.450012
# 2013-04-17  0.000229      -0.000074        0.000398   660.099976  665.200012
# 2013-04-18  0.000327       0.000300        0.000398   673.599976  636.599976
# 2013-04-22  0.000422       0.000367        0.000398   698.299988  635.250000
# 2013-04-23  0.000312      -0.000140        0.000398   689.000000  625.349976
# 2013-04-25  0.000220       0.000008        0.000398   689.549988  634.000000
# 2013-04-26  0.000135       0.000021        0.000398   689.099976  622.849976
# 2013-04-29  0.000151       0.000100        0.000398   695.150024  646.500000
# 2013-04-30  0.000283      -0.000169        0.000398   682.299988  669.500000
# 2013-05-02  0.000171       0.000149        0.000398   692.500000  668.750000
# 2013-05-03  0.000226      -0.000168        0.000398   680.950012  656.549988
# 2013-05-06  0.000140      -0.000052        0.000398   675.500000  650.650024
# 2013-05-07  0.000259       0.000174        0.000398   688.049988  655.150024
# 2013-05-08  0.000189       0.000118        0.000398   697.150024  667.750000
# 2013-05-09  0.000164      -0.000129        0.000398   690.049988  660.450012
# 2013-05-10  0.000236       0.000213        0.000398   703.349976  670.299988
# 2013-05-13  0.000299      -0.000174        0.000398   692.750000  659.299988
# 2013-05-14  0.000143      -0.000014        0.000398   689.049988  683.250000
# 2013-05-15  0.000357       0.000308        0.000398   714.849976  695.750000
# 2013-05-16  0.000183       0.000152        0.000398   722.799988  695.450012
# 2013-05-17  0.000188      -0.000050        0.000398   718.900024  678.700012
# 2013-05-20  0.000166      -0.000069        0.000398   714.500000  662.900024
# ...              ...            ...             ...          ...         ...
# 2018-04-04  0.000248      -0.000155        0.000000  1883.250000         NaN
# 2018-04-05       NaN            NaN             NaN          NaN         NaN
# 2018-04-06       NaN            NaN             NaN          NaN         NaN
# 2018-04-09       NaN            NaN             NaN          NaN         NaN
# 2018-04-10       NaN            NaN             NaN          NaN         NaN
# 2018-04-11       NaN            NaN             NaN          NaN         NaN
# 2018-04-12       NaN            NaN             NaN          NaN         NaN
# 2018-04-13       NaN            NaN             NaN          NaN         NaN
# 2018-04-16       NaN            NaN             NaN          NaN         NaN
# 2018-04-17       NaN            NaN             NaN          NaN         NaN
# 2018-04-18       NaN            NaN             NaN          NaN         NaN
# 2018-04-19       NaN            NaN             NaN          NaN         NaN
# 2018-04-20       NaN            NaN             NaN          NaN         NaN
# 2018-04-23       NaN            NaN             NaN          NaN         NaN
# 2018-04-24       NaN            NaN             NaN          NaN         NaN
# 2018-04-25       NaN            NaN             NaN          NaN         NaN
# 2018-04-26       NaN            NaN             NaN          NaN         NaN
# 2018-04-27       NaN            NaN             NaN          NaN         NaN
# 2018-04-30       NaN            NaN             NaN          NaN         NaN
# 2018-05-02       NaN            NaN             NaN          NaN         NaN
# 2018-05-03       NaN            NaN             NaN          NaN         NaN
# 2018-05-04       NaN            NaN             NaN          NaN         NaN
# 2018-05-07       NaN            NaN             NaN          NaN         NaN
# 2018-05-08       NaN            NaN             NaN          NaN         NaN
# 2018-05-09       NaN            NaN             NaN          NaN         NaN
# 2018-05-10       NaN            NaN             NaN          NaN         NaN
# 2018-05-11       NaN            NaN             NaN          NaN         NaN
# 2018-05-14       NaN            NaN             NaN          NaN         NaN
# 2018-05-15       NaN            NaN             NaN          NaN         NaN
# 2018-05-16       NaN            NaN             NaN          NaN         NaN
#
#               ...        ave40   upper40   lower40     ave50  upper50  \
# Date          ...
# 2013-04-04    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-05    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-08    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-09    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-10    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-11    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-12    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-15    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-16    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-17    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-18    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-22    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-23    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-25    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-26    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-29    ...          NaN       NaN       NaN       NaN      NaN
# 2013-04-30    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-02    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-03    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-06    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-07    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-08    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-09    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-10    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-13    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-14    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-15    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-16    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-17    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-20    ...          NaN       NaN       NaN       NaN      NaN
# ...           ...          ...       ...       ...       ...      ...
# 2018-04-04    ...     1875.584  1900.912  1850.256  1894.982  1941.41
# 2018-04-05    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-06    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-09    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-10    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-11    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-12    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-13    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-16    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-17    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-18    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-19    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-20    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-23    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-24    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-25    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-26    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-27    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-30    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-02    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-03    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-04    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-07    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-08    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-09    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-10    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-11    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-14    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-15    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-16    ...          NaN       NaN       NaN       NaN      NaN
#
#              lower50         %K         %D         ch_osc       ROC
# Date
# 2013-04-04       NaN        NaN        NaN       0.000000       NaN
# 2013-04-05       NaN        NaN        NaN   96974.852431       NaN
# 2013-04-08       NaN        NaN        NaN  112713.989870       NaN
# 2013-04-09       NaN        NaN        NaN  -90455.910315       NaN
# 2013-04-10       NaN        NaN        NaN  335467.156109       NaN
# 2013-04-11       NaN        NaN        NaN  561099.137218       NaN
# 2013-04-12       NaN        NaN        NaN  586216.185125       NaN
# 2013-04-15       NaN        NaN        NaN  599538.066150       NaN
# 2013-04-16       NaN        NaN        NaN  673784.637277       NaN
# 2013-04-17       NaN        NaN        NaN  -37342.506665       NaN
# 2013-04-18       NaN        NaN        NaN  128658.537484       NaN
# 2013-04-22       NaN        NaN        NaN  530208.100300       NaN
...          NaN       NaN       NaN       NaN      NaN
# 2013-05-15    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-16    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-17    ...          NaN       NaN       NaN       NaN      NaN
# 2013-05-20    ...          NaN       NaN       NaN       NaN      NaN
# ...           ...          ...       ...       ...       ...      ...
# 2018-04-04    ...     1875.584  1900.912  1850.256  1894.982  1941.41
# 2018-04-05    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-06    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-09    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-10    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-11    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-12    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-13    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-16    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-17    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-18    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-19    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-20    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-23    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-24    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-25    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-26    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-27    ...          NaN       NaN       NaN       NaN      NaN
# 2018-04-30    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-02    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-03    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-04    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-07    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-08    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-09    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-10    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-11    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-14    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-15    ...          NaN       NaN       NaN       NaN      NaN
# 2018-05-16    ...          NaN       NaN       NaN       NaN      NaN
#
#              lower50         %K         %D         ch_osc       ROC
# Date
# 2013-04-04       NaN        NaN        NaN       0.000000       NaN
# 2013-04-05       NaN        NaN        NaN   96974.852431       NaN
# 2013-04-08       NaN        NaN        NaN  112713.989870       NaN
# 2013-04-09       NaN        NaN        NaN  -90455.910315       NaN
# 2013-04-10       NaN        NaN        NaN  335467.156109       NaN
# 2013-04-11       NaN        NaN        NaN  561099.137218       NaN
# 2013-04-12       NaN        NaN        NaN  586216.185125       NaN
# 2013-04-15       NaN        NaN        NaN  599538.066150       NaN
# 2013-04-16       NaN        NaN        NaN  673784.637277       NaN
# 2013-04-17       NaN        NaN        NaN  -37342.506665       NaN
# 2013-04-18       NaN        NaN        NaN  128658.537484       NaN
# 2013-04-22       NaN        NaN        NaN  530208.100300       NaN
# 2013-04-23       NaN        NaN        NaN  137751.034491       NaN
# 2013-04-25       NaN  85.948064        NaN  206291.375499       NaN
# 2013-04-26       NaN  85.440150        NaN   61584.689603       NaN
# 2013-04-29       NaN  91.903099  87.763771  189338.216513       NaN
# 2013-04-30       NaN  76.713927  84.685725 -327267.317462       NaN
# 2013-05-02       NaN  88.561106  85.726044  -14330.944931       NaN
# 2013-05-03       NaN  69.971476  78.415503 -629010.487516       NaN
# 2013-05-06       NaN  60.447761  72.993448 -578924.445880       NaN
# 2013-05-07       NaN  79.179087  69.866108 -183922.522352       NaN
# 2013-05-08       NaN  91.869281  77.165376  -56524.735300       NaN
# 2013-05-09       NaN  75.104142  82.050836 -386232.083405       NaN
# 2013-05-10       NaN  96.954720  87.976048   91620.067366       NaN
# 2013-05-13       NaN  54.939730  75.666197 -518947.151104       NaN
# 2013-05-14       NaN  46.024039  65.972830 -624404.099694       NaN
# 2013-05-15       NaN  97.502662  66.155477   23272.400317       NaN
# 2013-05-16       NaN  97.779811  80.435504  318072.528069       NaN
# 2013-05-17       NaN  90.564335  95.282269  340848.475794       NaN
# 2013-05-20       NaN  82.423678  90.255941 -131106.225393       NaN
# ...              ...        ...        ...            ...       ...
# 2018-04-04  1848.554  48.655257  74.930717  -42389.017374  0.036441
# 2018-04-05       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-06       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-09       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-10       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-11       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-12       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-13       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-16       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-17       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-18       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-19       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-20       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-23       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-24       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-25       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-26       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-27       NaN        NaN        NaN  -42389.017374       NaN
# 2018-04-30       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-02       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-03       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-04       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-07       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-08       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-09       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-10       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-11       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-14       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-15       NaN        NaN        NaN  -42389.017374       NaN
# 2018-05-16       NaN        NaN        NaN  -42389.017374       NaN
#
# [1261 rows x 24 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(roc30.loc[start_date:end_date, :].index, roc30.loc[start_date:end_date, 'ROC'], label = 'For 30 days')
ax.plot(roc40.loc[start_date:end_date, :].index, roc40.loc[start_date:end_date, 'ROC'], label = 'For 40 days')
ax.plot(roc50.loc[start_date:end_date, :].index, roc50.loc[start_date:end_date, 'ROC'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')
