dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
df1['Date']=pd.to_datetime(df1['Date'])

# %%
df1.isnull().sum()
# Out:
# Date         0
# Open         2
# High         2
# Low          2
# Close        2
# Adj Close    2
# Volume       2
# dtype: int64

# %%
df1.fillna(df1.mean(),inplace=True)

# %%
close_zero=df1.iloc[-1].Close

# %%
df1['HL_PCT'] = (df1['High'] - df1['Low'])/(df1['Low']*100)

# %%
df1['PCT_CHNG_OpCl'] = (df1['Close'] - df1['Open'])/(df1['Open']*100)

# %%
df1['PCT_CHNG_CLOSE'] = (df1['Close'] - df1['Adj Close'])/(df1['Adj Close']*100)

# %%
df1.index=df1['Date']

# %%
df1.head()
# Out:
#                  Date     Open        High         Low       Close  \
# Date
# 2013-04-04 2013-04-04  736.250  737.286987  718.013000  720.013000
# 2013-04-05 2013-04-05  719.750  724.750000  712.500000  716.463013
# 2013-04-08 2013-04-08  712.500  718.411987  706.812012  707.974976
# 2013-04-09 2013-04-09  708.388  709.737000  689.062012  691.588013
# 2013-04-10 2013-04-10  700.750  706.950012  694.062012  703.911987
#
#              Adj Close     Volume    HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE
# Date
# 2013-04-04  553.244873  3749980.0  0.000268      -0.000221        0.003014
# 2013-04-05  550.517151  2186480.0  0.000172      -0.000046        0.003014
# 2013-04-08  543.995117  1858180.0  0.000164      -0.000064        0.003014
# 2013-04-09  531.403687  5420328.0  0.000300      -0.000237        0.003014
# 2013-04-10  540.873230  3275808.0  0.000186       0.000045        0.003014

# %%
df=df1[['Open','High','Low','Adj Close','Volume','HL_PCT','PCT_CHNG_OpCl','PCT_CHNG_CLOSE','Close']]

# %% [markdown]
# ## Prediction for 30th Day

# %%
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
import datetime
# Out:
# C:\Users\Debadri\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df['Close'].plot(figsize=(15,6), color="green")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.tail()
# Out:
#                    Open         High          Low    Adj Close     Volume  \
# Date
# 2018-03-27  1160.000000  1161.300049  1150.099976  1154.000000  1901044.0
# 2018-03-28  1150.750000  1150.750000  1126.250000  1131.800049  6279161.0
# 2018-04-02  1131.800049  1149.550049  1121.300049  1137.150024  4036351.0
# 2018-04-03  1134.699951  1143.550049  1128.099976  1140.449951  2038584.0
# 2018-04-04  1144.000000  1144.550049  1120.000000  1124.199951  2406651.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE        Close
# Date
# 2018-03-27  0.000097      -0.000052             0.0  1154.000000
# 2018-03-28  0.000218      -0.000165             0.0  1131.800049
# 2018-04-02  0.000252       0.000047             0.0  1137.150024
# 2018-04-03  0.000137       0.000051             0.0  1140.449951
# 2018-04-04  0.000219      -0.000173             0.0  1124.199951

# %%
forecast_col = 'Close'

forecast_out = int(42)
# We will drop 12 columns because there are 12 holidays

# %%
df['label'] = df[forecast_col].shift(-forecast_out)
print(df.head(2))
# Out:
#               Open        High      Low   Adj Close     Volume    HL_PCT  \
# Date
# 2013-04-04  736.25  737.286987  718.013  553.244873  3749980.0  0.000268
# 2013-04-05  719.75  724.750000  712.500  550.517151  2186480.0  0.000172
#
#             PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close       
# 2018-05-06 05:30:00            NaN             NaN    NaN    NaN  1124.284774
# 2018-05-07 05:30:00            NaN             NaN    NaN    NaN  1119.189763
# 2018-05-08 05:30:00            NaN             NaN    NaN    NaN  1110.856317
# 2018-05-09 05:30:00            NaN             NaN    NaN    NaN  1118.057568
# 2018-05-10 05:30:00            NaN             NaN    NaN    NaN  1125.636010
# 2018-05-11 05:30:00            NaN             NaN    NaN    NaN  1104.669173
# 2018-05-12 05:30:00            NaN             NaN    NaN    NaN  1101.061204
# 2018-05-13 05:30:00            NaN             NaN    NaN    NaN  1097.657624
# 2018-05-14 05:30:00            NaN             NaN    NaN    NaN  1107.863686
# 2018-05-15 05:30:00            NaN             NaN    NaN    NaN  1097.691373
# 2018-05-16 05:30:00            NaN             NaN    NaN    NaN  1094.796585

# %%
pred=pred.reset_index()

# %%
pred['Date']=pred['Date'].dt.date

# %%
pred.head(1)
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#    PCT_CHNG_CLOSE  Close  label     forecast
# 0             NaN    NaN    NaN  1109.706057

# %%
holidays=['2018-04-07','2018-04-08','2018-04-14','2018-04-15','2018-04-21','2018-04-22','2018-04-28','2018-04-29','2018-05-01','2018-05-05','2018-05-06','2018-05-12','2018-05-13']

# %%
pred['Date']=pred['Date'].apply(str)

# %%
for i in holidays:
    pred = pred.drop(pred[pred.Date==i].index)

# %%
pred['Date']=pd.to_datetime(pred['Date'])

# %%
pred.drop('forecast',axis=1,inplace=True)

# %%
pred.shape
# Out:
# (29, 11)

# %%
pred['forecast']=forecast_prediction[:29]

# %%
pred
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 1  2018-04-06   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 4  2018-04-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 5  2018-04-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 6  2018-04-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 7  2018-04-12   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 8  2018-04-13   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 11 2018-04-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 12 2018-04-17   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 13 2018-04-18   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 14 2018-04-19   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 15 2018-04-20   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 18 2018-04-23   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 19 2018-04-24   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 20 2018-04-25   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 21 2018-04-26   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 22 2018-04-27   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 25 2018-04-30   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 27 2018-05-02   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 28 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 29 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 32 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 33 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 34 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 35 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 36 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 39 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 40 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 41 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#     PCT_CHNG_CLOSE  Close  label     forecast
# 0              NaN    NaN    NaN  1109.706057
# 1              NaN    NaN    NaN  1111.664858
# 4              NaN    NaN    NaN  1121.490683
# 5              NaN    NaN    NaN  1108.257022
# 6              NaN    NaN    NaN  1104.577746
# 7              NaN    NaN    NaN  1090.187993
# 8              NaN    NaN    NaN  1109.959759
# 11             NaN    NaN    NaN  1083.180418
# 12             NaN    NaN    NaN  1086.468194
# 13             NaN    NaN    NaN  1090.499810
# 14             NaN    NaN    NaN  1103.509204
# 15             NaN    NaN    NaN  1103.167944
# 18             NaN    NaN    NaN  1093.529866
# 19             NaN    NaN    NaN  1125.108374
# 20             NaN    NaN    NaN  1099.031444
# 21             NaN    NaN    NaN  1114.937291
# 22             NaN    NaN    NaN  1105.414615
# 25             NaN    NaN    NaN  1101.485262
# 27             NaN    NaN    NaN  1103.661720
# 28             NaN    NaN    NaN  1145.140918
# 29             NaN    NaN    NaN  1104.586979
# 32             NaN    NaN    NaN  1113.581487
# 33             NaN    NaN    NaN  1105.685613
# 34             NaN    NaN    NaN  1104.587768
# 35             NaN    NaN    NaN  1113.857279
# 36             NaN    NaN    NaN  1104.430697
# 39             NaN    NaN    NaN  1126.176373
# 40             NaN    NaN    NaN  1129.851181
# 41             NaN    NaN    NaN  1122.403340

# %%
pred.index=pred['Date']
pred.drop('Date',axis=1,inplace=True)

# %%
df=df.append(pred)

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.xlim(xmin=datetime.date(2018, 4, 4))
plt.ylim(ymin=-100)
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.iloc[-1]
# Out:
# Open                     NaN
# High                     NaN
# Low                      NaN
# Adj Close                NaN
# Volume                   NaN
# HL_PCT                   NaN
# PCT_CHNG_OpCl            NaN
# PCT_CHNG_CLOSE           NaN
# Close                    NaN
# label                    NaN
# forecast          1122.40334
# Name: 2018-05-16 00:00:00, dtype: float64

# %%
close_last=df.iloc[-1].forecast

# %%
pred_return=close_last-close_zero
print("Predicted Return: Rs.",pred_return)
# Out:
# Predicted Return: Rs. -1.7966112553438052

# %% [markdown]
# ## Simple Moving Average (30,40,50)

# %%
# For 30 days
short_rolling = df.rolling(window=30).mean()
short_rolling.head(30)
# Out:
#                   Open        High         Low   Adj Close        Volume  \
# Date
# 2013-04-04         NaN         NaN         NaN         NaN           NaN
# 2013-04-05         NaN         NaN         NaN         NaN           NaN
# 2013-04-08         NaN         NaN         NaN         NaN           NaN
# 2013-04-09         NaN         NaN         NaN         NaN           NaN
# 2013-04-10         NaN         NaN         NaN         NaN           NaN
# 2013-04-11         NaN         NaN         NaN         NaN           NaN
# 2013-04-12         NaN         NaN         NaN         NaN           NaN
# 2013-04-15         NaN         NaN         NaN         NaN           NaN
# 2013-04-16         NaN         NaN         NaN         NaN           NaN
# 2013-04-17         NaN         NaN         NaN         NaN           NaN
# 2013-04-18         NaN         NaN         NaN         NaN           NaN
# 2013-04-22         NaN         NaN         NaN         NaN           NaN
# 2013-04-23         NaN         NaN         NaN         NaN           NaN
# 2013-04-25         NaN         NaN         NaN         NaN           NaN
# 2013-04-26         NaN         NaN         NaN         NaN           NaN
# 2013-04-29         NaN         NaN         NaN         NaN           NaN
# 2013-04-30         NaN         NaN         NaN         NaN           NaN
# 2013-05-02         NaN         NaN         NaN         NaN           NaN
# 2013-05-03         NaN         NaN         NaN         NaN           NaN
# 2013-05-06         NaN         NaN         NaN         NaN           NaN
# 2013-05-07         NaN         NaN         NaN         NaN           NaN
# 2013-05-08         NaN         NaN         NaN         NaN           NaN
# 2013-05-09         NaN         NaN         NaN         NaN           NaN
# 2013-05-10         NaN         NaN         NaN         NaN           NaN
# 2013-05-13         NaN         NaN         NaN         NaN           NaN
# 2013-05-14         NaN         NaN         NaN         NaN           NaN
# 2013-05-15         NaN         NaN         NaN         NaN           NaN
# 2013-05-16         NaN         NaN         NaN         NaN           NaN
# 2013-05-17         NaN         NaN         NaN         NaN           NaN
# 2013-05-20  606.862099  612.428668  597.627466  464.063611  6.860959e+06
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE     Close       label  \
# Date
# 2013-04-04       NaN            NaN             NaN       NaN         NaN
# 2013-04-05       NaN            NaN             NaN       NaN         NaN
# 2013-04-08       NaN            NaN             NaN       NaN         NaN
# 2013-04-09       NaN            NaN             NaN       NaN         NaN
# 2013-04-10       NaN            NaN             NaN       NaN         NaN
# 2013-04-11       NaN            NaN             NaN       NaN         NaN
# 2013-04-12       NaN            NaN             NaN       NaN         NaN
# 2013-04-15       NaN            NaN             NaN       NaN         NaN
# 2013-04-16       NaN            NaN             NaN       NaN         NaN
# 2013-04-17       NaN            NaN             NaN       NaN         NaN
# 2013-04-18       NaN            NaN             NaN       NaN         NaN
# 2013-04-22       NaN            NaN             NaN       NaN         NaN
# 2013-04-23       NaN            NaN             NaN       NaN         NaN
# 2013-04-25       NaN            NaN             NaN       NaN         NaN
# 2013-04-26       NaN            NaN             NaN       NaN         NaN
# 2013-04-29       NaN            NaN             NaN       NaN         NaN
# 2013-04-30       NaN            NaN             NaN       NaN         NaN
# 2013-05-02       NaN            NaN             NaN       NaN         NaN
# 2013-05-03       NaN            NaN             NaN       NaN         NaN
# 2013-05-06       NaN            NaN             NaN       NaN         NaN
# 2013-05-07       NaN            NaN             NaN       NaN         NaN
# 2013-05-08       NaN            NaN             NaN       NaN         NaN
# 2013-05-09       NaN            NaN             NaN       NaN         NaN
# 2013-05-10       NaN            NaN             NaN       NaN         NaN
# 2013-05-13       NaN            NaN             NaN       NaN         NaN
# 2013-05-14       NaN            NaN             NaN       NaN         NaN
# 2013-05-15       NaN            NaN             NaN       NaN         NaN
# 2013-05-16       NaN            NaN             NaN       NaN         NaN
# 2013-05-17       NaN            NaN             NaN       NaN         NaN
# 2013-05-20  0.000249      -0.000041        0.003014  603.9492  620.597131
#
#             forecast
# Date
# 2013-04-04       NaN
# 2013-04-05       NaN
# 2013-04-08       NaN
# 2013-04-09       NaN
# 2013-04-10       NaN
# 2013-04-11       NaN
# 2013-04-12       NaN
# 2013-04-15       NaN
# 2013-04-16       NaN
# 2013-04-17       NaN
# 2013-04-18       NaN
# 2013-04-22       NaN
# 2013-04-23       NaN
# 2013-04-25       NaN
# 2013-04-26       NaN
# 2013-04-29       NaN
# 2013-04-30       NaN
# 2013-05-02       NaN
# 2013-05-03       NaN
# 2013-05-06       NaN
# 2013-05-07       NaN
# 2013-05-08       NaN
# 2013-05-09       NaN
# 2013-05-10       NaN
# 2013-05-13       NaN
# 2013-05-14       NaN
# 2013-05-15       NaN
# 2013-05-16       NaN
# 2013-05-17       NaN
# 2013-05-20       NaN

# %%
# For 40 days
med_rolling = df.rolling(window=40).mean()
med_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
# For 50 days
long_rolling = df.rolling(window=50).mean()
long_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
start_date = '2013-04-29'
end_date = '2018-04-04'

fig, ax = plt.subplots(figsize=(16,9))

ax.plot(long_rolling.loc[start_date:end_date, :].index, long_rolling.loc[start_date:end_date, 'Close'], label = '50-days SMA')
ax.plot(med_rolling.loc[start_date:end_date, :].index, med_rolling.loc[start_date:end_date, 'Close'], label = '40-days SMA')
ax.plot(short_rolling.loc[start_date:end_date, :].index, short_rolling.loc[start_date:end_date, 'Close'], label = '30-days SMA')


ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Exponential Moving Average (30,40,50)

# %%
ema_short = df.ewm(span=30, adjust=False).mean()
ema_med = df.ewm(span=40, adjust=False).mean()
ema_long = df.ewm(span=50, adjust=False).mean()

fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ema_short.loc[start_date:end_date, :].index, ema_short.loc[start_date:end_date, 'Close'], label = 'Span 30-days EMA')
ax.plot(ema_med.loc[start_date:end_date, :].index, ema_med.loc[start_date:end_date, 'Close'], label = 'Span 40-days EMA')
ax.plot(ema_long.loc[start_date:end_date, :].index, ema_long.loc[start_date:end_date, 'Close'], label = 'Span 50-days EMA')

ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Aroon Oscillator (30,40,50)

# %%
from pandas.stats import moments
from pandas import DataFrame

# %%
def aroon(s, n):
    up = 100 * moments.rolling_apply(s.High, n + 1, lambda x: x.argmax()) / n
    dn = 100 * moments.rolling_apply(s.Low, n + 1, lambda x: x.argmin()) / n

    return DataFrame(dict(up=up, down=dn))

# %%
ao30=aroon(df,30)
ao40=aroon(df,40)
ao50=aroon(df,50)

# %%
ao30
# Out:
#                 down         up
# Date
# 2013-04-04       NaN        NaN
# 2013-04-05       NaN        NaN
# 2013-04-08       NaN        NaN
# 2013-04-09       NaN        NaN
# 2013-04-10       NaN        NaN
# 2013-04-11       NaN        NaN
# 2013-04-12       NaN        NaN
# 2013-04-15       NaN        NaN
# 2013-04-16       NaN        NaN
# 2013-04-17       NaN        NaN
# 2013-04-18       NaN        NaN
# 2013-04-22       NaN        NaN
# 2013-04-23       NaN        NaN
# 2013-04-25       NaN        NaN
# 2013-04-26       NaN        NaN
# 2013-04-29       NaN        NaN
# 2013-04-30       NaN        NaN
# 2013-05-02       NaN        NaN
# 2013-05-03       NaN        NaN
# 2013-05-06       NaN        NaN
# 2013-05-07       NaN        NaN
# 2013-05-08       NaN        NaN
# 2013-05-09       NaN        NaN
# 2013-05-10       NaN        NaN
# 2013-05-13       NaN        NaN
# 2013-05-14       NaN        NaN
# 2013-05-15       NaN        NaN
# 2013-05-16       NaN        NaN
# 2013-05-17       NaN        NaN
# 2013-05-20       NaN        NaN
# ...              ...        ...
# 2018-04-04  6.666667  53.333333
# 2018-04-05       NaN        NaN
# 2018-04-06       NaN        NaN
# 2018-04-09       NaN        NaN
# 2018-04-10       NaN        NaN
# 2018-04-11       NaN        NaN
# 2018-04-12       NaN        NaN
# 2018-04-13       NaN        NaN
# 2018-04-16       NaN        NaN
# 2018-04-17       NaN        NaN
# 2018-04-18       NaN        NaN
# 2018-04-19       NaN        NaN
# 2018-04-20       NaN        NaN
# 2018-04-23       NaN        NaN
# 2018-04-24       NaN        NaN
# 2018-04-25       NaN        NaN
# 2018-04-26       NaN        NaN
# 2018-04-27       NaN        NaN
# 2018-04-30       NaN        NaN
# 2018-05-02       NaN        NaN
# 2018-05-03       NaN        NaN
# 2018-05-04       NaN        NaN
# 2018-05-07       NaN        NaN
# 2018-05-08       NaN        NaN
# 2018-05-09       NaN        NaN
# 2018-05-10       NaN        NaN
# 2018-05-11       NaN        NaN
# 2018-05-14       NaN        NaN
# 2018-05-15       NaN        NaN
# 2018-05-16       NaN        NaN
#
# [1261 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 30-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 30-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 40-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 40-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'down'], label = ' Down 50-days Aroon Oscillator')
ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'up'], label = 'Up 50-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %% [markdown]
# ## MACD Signal

# %%
def ema(s, n, wilder=False):
    span = n if not wilder else 2*n - 1
    return moments.ewma(s, span=span)


def macd(s, nfast=12, nslow=26, nsig=9, percent=True):
    fast, slow = ema(s, nfast), ema(s, nslow)

    if percent:
        macd = 100*(fast / slow - 1)
    else:
        macd = fast - slow

    sig = ema(macd, nsig)
    hist = macd - sig

    return DataFrame(dict(macd=macd, signal=sig, hist=hist,
                          fast=fast, slow=slow))

# %%
m=macd(df['Close'])

# %%
m.head(1)
# Out:
#                fast  hist  macd  signal     slow
# Date
# 2013-04-04  720.013   0.0   0.0     0.0  720.013

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(m.loc[start_date:end_date, :].index, m.loc[start_date:end_date, 'macd'], label = 'MACD')

ax.legend(loc='best')
ax.set_ylabel('Change ')
# Out:
# Text(0,0.5,'Change ')

# %% [markdown]
# ## Relative Strength Index (RSI)

# %%
def rsi(s, n=14):
    diff = s.diff()
    which_dn = diff < 0

    up, dn = diff, diff*0
    up[which_dn], dn[which_dn] = 0, -up[which_dn]

    emaup = ema(up, n, wilder=True)
    emadn = ema(dn, n, wilder=True)

    return 100 * emaup/(emaup + emadn)

# %%
sf=rsi(df['Close'],50)

# %%
sfd=pd.DataFrame({'Date':sf.index, 'RSI':sf.values})

# %%
sfd.index=sfd['Date']

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(sfd.loc[start_date:end_date, :].index, sfd.loc[start_date:end_date, 'RSI'], label = 'RSI')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Bollinger Bands (30,40,50)

# %%
price=df["Close"]

def bbands(price, length=30, numsd=2):
    """ returns average, upper band, and lower band"""
    ave = pd.stats.moments.rolling_mean(price,length)
    sd = pd.stats.moments.rolling_std(price,length)
    upband = ave + (sd*numsd)
    dnband = ave - (sd*numsd)
    return np.round(ave,3), np.round(upband,3), np.round(dnband,3)

df['ave30'], df['upper30'], df['lower30'] = bbands(df.Close, length=30, numsd=1)
df['ave40'], df['upper40'], df['lower40'] = bbands(df.Close, length=40, numsd=1)
df['ave50'], df['upper50'], df['lower50'] = bbands(df.Close, length=50, numsd=1)

# %%
# For 30 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave30'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower30'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper30'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 40 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave40'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower40'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper40'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 50 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave50'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower50'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper50'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Stochastic Oscillator

# %%
def STOK(close, low, high, n): 
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 return STOK

def STOD(close, low, high, n):
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 STOD = pd.rolling_mean(STOK, 3)
 return STOD

# %%
df['%K'] = STOK(df['Close'], df['Low'], df['High'], 14)
df['%D'] = STOD(df['Close'], df['Low'], df['High'], 14)

# %%
df.plot(y=['Close'], figsize = (20, 5))
df.plot(y=['%K', '%D'], figsize = (20, 5))

# %% [markdown]
# ## Chande Oscillator

# %%
def avg_true_range(df): 
  ind = range(0,len(df))
  indexlist = list(ind)
  df.index = indexlist

  for index, row in df.iterrows():
    if index != 0:
      tr1 = row["High"] - row["Low"]
      tr2 = abs(row["High"] - df.iloc[index-1]["Close"])
      tr3 = abs(row["Low"] - df.iloc[index-1]["Close"])

      true_range = max(tr1, tr2, tr3)
      df.set_value(index,"True Range", true_range)

  df["Avg TR"] = df["True Range"].rolling(min_periods=14, window=14, center=False).mean()
  return df

# %%
def chandelier_exit(df):

  df_tr = avg_true_range(df)

  df_tr['rolling_high']= df_tr["High"]
  df_tr['rolling_low'] = df_tr["Low"]

  df_tr['chandelier_long'] = df_tr['rolling_high'] - df_tr["Avg TR"] * 3
  df_tr['chandelier_short'] = df_tr['rolling_low'] - df_tr["Avg TR"] * 3
  fig, ax = plt.subplots(figsize=(15,9))

  ax.plot(df_tr['Date'], df_tr['chandelier_long'], label = 'Chand Long')

# %%
ch=chandelier_exit(df1)

# %% [markdown]
# ## Commodity Channel Index (30,40,50)

# %%
def CCI(data, ndays): 
 TP = (data['High'] + data['Low'] + data['Close']) / 3 
 CCI = pd.Series((TP - pd.rolling_mean(TP, ndays)) / (0.015 * pd.rolling_std(TP, ndays)),
 name = 'CCI')
 data=data.join(CCI)
 return data

# %%
cci30=CCI(df,30)
cci40=CCI(df,40)
cci50=CCI(df,50)

# %%
cci30
# Out:
#                    Open         High          Low    Adj Close      Volume  \
# Date
# 2013-04-04   736.250000   737.286987   718.013000   553.244873   3749980.0
# 2013-04-05   719.750000   724.750000   712.500000   550.517151   2186480.0
# 2013-04-08   712.500000   718.411987   706.812012   543.995117   1858180.0
# 2013-04-09   708.388000   709.737000   689.062012   531.403687   5420328.0
# 2013-04-10   700.750000   706.950012   694.062012   540.873230   3275808.0
# 2013-04-11   716.625000   733.900024   708.724976   560.284912   8509336.0
# 2013-04-12   656.263000   656.263000   567.174988   441.175629  49013872.0
# 2013-04-15   572.500000   589.250000   551.000000   449.321259  33279988.0
# 2013-04-16   579.750000   581.500000   571.750000   441.098846   7150868.0
# 2013-04-17   575.000000   577.987000   562.500000   438.717651   7574572.0
# 2013-04-18   571.599976   580.750000   570.325012   440.993561   6612184.0
# 2013-04-22   573.924988   573.924988   555.888000   431.168304   7700644.0
# 2013-04-23   562.500000   567.650024   561.099976   434.567505   3934980.0
# 2013-04-25   565.562012   565.562012   555.786987   427.931030   6881172.0
# 2013-04-26   555.025024   559.450012   550.625000   424.915131   5564792.0
# 2013-04-29   551.500000   562.200012   546.500000   428.238434   4482840.0
# 2013-04-30   558.500000   560.588013   555.549988   429.419434   4420360.0
# 2013-05-02   558.862000   572.862000   558.862000   439.264709   4688092.0
# 2013-05-03   574.187988   581.000000   569.549988   443.346344   4558596.0
# 2013-05-06   578.750000   586.250000   578.750000   449.714691   3000052.0
# 2013-05-07   587.500000   588.750000   581.187988   451.193878   3491552.0
# 2013-05-08   591.250000   595.000000   584.513000   451.548798   3639176.0
# 2013-05-09   587.974976   592.224976   587.500000   453.614227   2280712.0
# 2013-05-10   590.525024   596.250000   589.275024   455.564392   2267020.0
# 2013-05-13   588.750000   590.536987   582.575012   449.426544   2507480.0
# 2013-05-14   584.325012   592.700012   584.325012   451.434357   2242224.0
# 2013-05-15   588.250000   593.174988   586.849976   453.431305   4446588.0
# 2013-05-16   588.375000   589.950012   578.312012   448.081909   3495876.0
# 2013-05-17   584.224976   592.250000   583.750000   451.760956   3215876.0
# 2013-05-20   586.500000   595.750000   586.000000   455.660461   4379144.0
# ...                 ...          ...          ...          ...         ...
# 2018-04-04  1144.000000  1144.550049  1120.000000  1124.199951   2406651.0
# 2018-04-05          NaN          NaN          NaN          NaN         NaN
# 2018-04-06          NaN          NaN          NaN          NaN         NaN
# 2018-04-09          NaN          NaN          NaN          NaN         NaN
# 2013-05-10  0.000118       0.000040        0.003014   592.888000  624.549988
# 2013-05-13  0.000137      -0.000065        0.003014   584.900024  625.286987
# 2013-05-14  0.000143       0.000055        0.003014   587.513000  632.088013
# 2013-05-15  0.000108       0.000032        0.003014   590.112000  701.049988
# 2013-05-16  0.000201      -0.000089        0.003014   583.150024  685.674988
# 2013-05-17  0.000146       0.000064        0.003014   587.937988  682.200012
# 2013-05-20  0.000166       0.000111        0.003014   593.013000  687.713013
# ...              ...            ...             ...          ...         ...
# 2018-04-04  0.000219      -0.000173        0.000000  1124.199951         NaN
# 2018-04-05       NaN            NaN             NaN          NaN         NaN
# 2018-04-06       NaN            NaN             NaN          NaN         NaN
# 2018-04-09       NaN            NaN             NaN          NaN         NaN
# 2018-04-10       NaN            NaN             NaN          NaN         NaN
# 2018-04-11       NaN            NaN             NaN          NaN         NaN
# 2018-04-12       NaN            NaN             NaN          NaN         NaN
# 2018-04-13       NaN            NaN             NaN          NaN         NaN
# 2018-04-16       NaN            NaN             NaN          NaN         NaN
# 2018-04-17       NaN            NaN             NaN          NaN         NaN
# 2018-04-18       NaN            NaN             NaN          NaN         NaN
# 2018-04-19       NaN            NaN             NaN          NaN         NaN
# 2018-04-20       NaN            NaN             NaN          NaN         NaN
# 2018-04-23       NaN            NaN             NaN          NaN         NaN
# 2018-04-24       NaN            NaN             NaN          NaN         NaN
# 2018-04-25       NaN            NaN             NaN          NaN         NaN
# 2018-04-26       NaN            NaN             NaN          NaN         NaN
# 2018-04-27       NaN            NaN             NaN          NaN         NaN
# 2018-04-30       NaN            NaN             NaN          NaN         NaN
# 2018-05-02       NaN            NaN             NaN          NaN         NaN
# 2018-05-03       NaN            NaN             NaN          NaN         NaN
# 2018-05-04       NaN            NaN             NaN          NaN         NaN
# 2018-05-07       NaN            NaN             NaN          NaN         NaN
# 2018-05-08       NaN            NaN             NaN          NaN         NaN
# 2018-05-09       NaN            NaN             NaN          NaN         NaN
# 2018-05-10       NaN            NaN             NaN          NaN         NaN
# 2018-05-11       NaN            NaN             NaN          NaN         NaN
# 2018-05-14       NaN            NaN             NaN          NaN         NaN
# 2018-05-15       NaN            NaN             NaN          NaN         NaN
# 2018-05-16       NaN            NaN             NaN          NaN         NaN
#
#                ...       lower30     ave40   upper40   lower40     ave50  \
# Date           ...
# 2013-04-04     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-05     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-08     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-09     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-10     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-11     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-12     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-15     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-16     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-17     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-18     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-22     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-23     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-25     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-26     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-29     ...           NaN       NaN       NaN       NaN       NaN
# 2013-04-30     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-02     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-03     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-06     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-07     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-08     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-09     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-10     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-13     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-14     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-15     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-16     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-17     ...           NaN       NaN       NaN       NaN       NaN
# 2013-05-20     ...       547.819       NaN       NaN       NaN       NaN
# ...            ...           ...       ...       ...       ...       ...
# 2018-04-04     ...      1139.665  1146.651  1169.687  1123.615  1149.978
# 2018-04-05     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-06     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-09     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-10     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-11     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-12     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-13     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-16     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-17     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-18     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-19     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-20     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-23     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-24     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-25     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-26     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-27     ...           NaN       NaN       NaN       NaN       NaN
# 2018-04-30     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-02     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-03     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-04     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-07     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-08     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-09     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-10     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-11     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-14     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-15     ...           NaN       NaN       NaN       NaN       NaN
# 2018-05-16     ...           NaN       NaN       NaN       NaN       NaN
#
#              upper50   lower50         %K         %D         CCI
# Date
# 2013-04-04       NaN       NaN        NaN        NaN         NaN
# 2013-04-05       NaN       NaN        NaN        NaN         NaN
# 2013-04-08       NaN       NaN        NaN        NaN         NaN
# 2013-04-09       NaN       NaN        NaN        NaN         NaN
# 2013-04-10       NaN       NaN        NaN        NaN         NaN
# 2013-04-11       NaN       NaN        NaN        NaN         NaN
# 2013-04-12       NaN       NaN        NaN        NaN         NaN
# 2013-04-15       NaN       NaN        NaN        NaN         NaN
# 2013-04-16       NaN       NaN        NaN        NaN         NaN
# 2013-04-17       NaN       NaN        NaN        NaN         NaN
# 2013-04-18       NaN       NaN        NaN        NaN         NaN
# 2013-04-22       NaN       NaN        NaN        NaN         NaN
# 2013-04-23       NaN       NaN        NaN        NaN         NaN
# 2013-04-25       NaN       NaN   3.180570        NaN         NaN
# 2013-04-26       NaN       NaN   1.295867        NaN         NaN
# 2013-04-29       NaN       NaN   5.776420   3.417619         NaN
# 2013-04-30       NaN       NaN   6.596584   4.556290         NaN
# 2013-05-02       NaN       NaN  13.433823   8.602276         NaN
# 2013-05-03       NaN       NaN  16.268408  12.099605         NaN
# 2013-05-06       NaN       NaN  35.326134  21.676122         NaN
# 2013-05-07       NaN       NaN  95.204706  48.933083         NaN
# 2013-05-08       NaN       NaN  84.870076  71.800305         NaN
# 2013-05-09       NaN       NaN  90.412322  90.162368         NaN
# 2013-05-10       NaN       NaN  93.242211  89.508203         NaN
# 2013-05-13       NaN       NaN  77.185978  86.946837         NaN
# 2013-05-14       NaN       NaN  82.438191  84.288793         NaN
# 2013-05-15       NaN       NaN  87.662312  82.428827         NaN
# 2013-05-16       NaN       NaN  73.668390  81.256297         NaN
# 2013-05-17       NaN       NaN  83.292438  81.541047         NaN
# 2013-05-20       NaN       NaN  92.046685  83.002505  -15.456890
# ...              ...       ...        ...        ...         ...
# 2018-04-04  1172.743  1127.213   5.948941  17.394649 -109.738817
# 2018-04-05       NaN       NaN        NaN        NaN         NaN
# 2018-04-06       NaN       NaN        NaN        NaN         NaN
# 2018-04-09       NaN       NaN        NaN        NaN         NaN
# 2018-04-10       NaN       NaN        NaN        NaN         NaN
# 2018-04-11       NaN       NaN        NaN        NaN         NaN
# 2018-04-12       NaN       NaN        NaN        NaN         NaN
# 2018-04-13       NaN       NaN        NaN        NaN         NaN
# 2018-04-16       NaN       NaN        NaN        NaN         NaN
# 2018-04-17       NaN       NaN        NaN        NaN         NaN
# 2018-04-18       NaN       NaN        NaN        NaN         NaN
# 2018-04-19       NaN       NaN        NaN        NaN         NaN
# 2018-04-20       NaN       NaN        NaN        NaN         NaN
# 2018-04-23       NaN       NaN        NaN        NaN         NaN
# 2018-04-24       NaN       NaN        NaN        NaN         NaN
# 2018-04-25       NaN       NaN        NaN        NaN         NaN
# 2018-04-26       NaN       NaN        NaN        NaN         NaN
# 2018-04-27       NaN       NaN        NaN        NaN         NaN
# 2018-04-30       NaN       NaN        NaN        NaN         NaN
# 2018-05-02       NaN       NaN        NaN        NaN         NaN
# 2018-05-03       NaN       NaN        NaN        NaN         NaN
# 2018-05-04       NaN       NaN        NaN        NaN         NaN
# 2018-05-07       NaN       NaN        NaN        NaN         NaN
# 2018-05-08       NaN       NaN        NaN        NaN         NaN
# 2018-05-09       NaN       NaN        NaN        NaN         NaN
# 2018-05-10       NaN       NaN        NaN        NaN         NaN
# 2018-05-11       NaN       NaN        NaN        NaN         NaN
# 2018-05-14       NaN       NaN        NaN        NaN         NaN
# 2018-05-15       NaN       NaN        NaN        NaN         NaN
# 2018-05-16       NaN       NaN        NaN        NaN         NaN
#
# [1261 rows x 23 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(cci30.loc[start_date:end_date, :].index, cci30.loc[start_date:end_date, 'CCI'], label = 'For 30 days')
ax.plot(cci40.loc[start_date:end_date, :].index, cci40.loc[start_date:end_date, 'CCI'], label = 'For 40 days')
ax.plot(cci50.loc[start_date:end_date, :].index, cci50.loc[start_date:end_date, 'CCI'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Chakin Volatility Indicator (30,40,50)

# %%
def chaikin_oscillator(data, periods_short=3, periods_long=30, high_col='High',
                       low_col='Low', close_col='Close', vol_col='Volume'):
    ac = pd.Series([])

    for index, row in data.iterrows():
        if row[high_col] != row[low_col]:
            val = ((row[close_col] - row[low_col]) - (row[high_col] - row[close_col])) / (row[high_col] - row[low_col]) * row[vol_col]
        else:
            val = 0
        ac.set_value(index, val)

    ema_long = ac.ewm(ignore_na=False, min_periods=0, com=periods_long, adjust=True).mean()
    ema_short = ac.ewm(ignore_na=False, min_periods=0, com=periods_short, adjust=True).mean()
    data['ch_osc'] = ema_short - ema_long

    return data

# %%
ch30=chaikin_oscillator(df,3,30)
ch40=chaikin_oscillator(df,3,40)
ch50=chaikin_oscillator(df,3,50)

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(
# 2013-05-10  0.000118       0.000040        0.003014   592.888000  624.549988
# 2013-05-13  0.000137      -0.000065        0.003014   584.900024  625.286987
# 2013-05-14  0.000143       0.000055        0.003014   587.513000  632.088013
# 2013-05-15  0.000108       0.000032        0.003014   590.112000  701.049988
# 2013-05-16  0.000201      -0.000089        0.003014   583.150024  685.674988
# 2013-05-17  0.000146       0.000064        0.003014   587.937988  682.200012
# 2013-05-20  0.000166       0.000111        0.003014   593.013000  687.713013
# ...              ...            ...             ...          ...         ...
# 2018-04-04  0.000219      -0.000173        0.000000  1124.199951         NaN
# 2018-04-05       NaN            NaN             NaN          NaN         NaN
# 2018-04-06       NaN            NaN             NaN          NaN         NaN
# 2018-04-09       NaN            NaN             NaN          NaN         NaN
# 2018-04-10       NaN            NaN             NaN          NaN         NaN
# 2018-04-11       NaN            NaN             NaN          NaN         NaN
# 2018-04-12       NaN            NaN             NaN          NaN         NaN
# 2018-04-13       NaN            NaN             NaN          NaN         NaN
# 2018-04-16       NaN            NaN             NaN          NaN         NaN
# 2018-04-17       NaN            NaN             NaN          NaN         NaN
# 2018-04-18       NaN            NaN             NaN          NaN         NaN
# 2018-04-19       NaN            NaN             NaN          NaN         NaN
# 2018-04-20       NaN            NaN             NaN          NaN         NaN
# 2018-04-23       NaN            NaN             NaN          NaN         NaN
# 2018-04-24       NaN            NaN             NaN          NaN         NaN
# 2018-04-25       NaN            NaN             NaN          NaN         NaN
# 2018-04-26       NaN            NaN             NaN          NaN         NaN
# 2018-04-27       NaN            NaN             NaN          NaN         NaN
# 2018-04-30       NaN            NaN             NaN          NaN         NaN
# 2018-05-02       NaN            NaN             NaN          NaN         NaN
# 2018-05-03       NaN            NaN             NaN          NaN         NaN
# 2018-05-04       NaN            NaN             NaN          NaN         NaN
# 2018-05-07       NaN            NaN             NaN          NaN         NaN
# 2018-05-08       NaN            NaN             NaN          NaN         NaN
# 2018-05-09       NaN            NaN             NaN          NaN         NaN
# 2018-05-10       NaN            NaN             NaN          NaN         NaN
# 2018-05-11       NaN            NaN             NaN          NaN         NaN
# 2018-05-14       NaN            NaN             NaN          NaN         NaN
# 2018-05-15       NaN            NaN             NaN          NaN         NaN
# 2018-05-16       NaN            NaN             NaN          NaN         NaN
#
#               ...        ave40   upper40   lower40     ave50   upper50  \
# Date          ...
# 2013-04-04    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-05    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-08    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-09    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-10    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-11    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-12    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-15    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-16    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-17    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-18    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-22    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-23    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-25    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-26    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-29    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-30    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-02    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-03    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-06    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-07    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-08    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-09    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-10    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-13    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-14    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-15    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-16    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-17    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-20    ...          NaN       NaN       NaN       NaN       NaN
# ...           ...          ...       ...       ...       ...       ...
# 2018-04-04    ...     1146.651  1169.687  1123.615  1149.978  1172.743
# 2018-04-05    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-06    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-09    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-10    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-11    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-12    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-13    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-16    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-17    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-18    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-19    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-20    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-23    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-24    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-25    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-26    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-27    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-30    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-02    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-03    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-04    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-07    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-08    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-09    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-10    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-11    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-14    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-15    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-16    ...          NaN       NaN       NaN       NaN       NaN
#
#              lower50         %K         %D        ch_osc       ROC
# Date
# 2013-04-04       NaN        NaN        NaN  0.000000e+00       NaN
# 2013-04-05       NaN        NaN        NaN  1.462488e+05       NaN
# 2013-04-08       NaN        NaN        NaN  1.177100e+05       NaN
# 2013-04-09       NaN        NaN        NaN -1.810622e+05       NaN
# 2013-04-10       NaN        NaN        NaN  3.661795e+05       NaN
# 2013-04-11       NaN        NaN        NaN  1.133948e+06       NaN
# 2013-04-12       NaN        NaN        NaN -4.814589e+06       NaN
# 2013-04-15       NaN        NaN        NaN  1.128706e+06       NaN
# 2013-04-16       NaN        NaN        NaN  5.947715e+05       NaN
# 2013-04-17       NaN        NaN        NaN  9.236166e+05       NaN
# 2013-04-18       NaN        NaN        NaN  6.877393e+05       NaN
# 2013-04-22       NaN        NaN        NaN  3.210197e+05       NaN
# 2013-04-23       NaN        NaN        NaN  8.508696e+05       NaN
# 2013-04-25       NaN   3.180570        NaN  4.248988e+04       NaN
# 2013-04-26       NaN   1.295867        NaN -4.343156e+04       NaN
# 2013-04-29       NaN   5.776420   3.417619  6.665624e+05       NaN
# 2013-04-30       NaN   6.596584   4.556290  1.101558e+06       NaN
# 2013-05-02       NaN  13.433823   8.602276  1.859854e+06       NaN
# 2013-05-03       NaN  16.268408  12.099605  1.896538e+06       NaN
# 2013-05-06       NaN  35.326134  21.676122  2.062323e+06       NaN
# 2013-05-07       NaN  95.204706  48.933083  2.124358e+06       NaN
# 2013-05-08       NaN  84.870076  71.800305  1.458403e+06       NaN
# 2013-05-09       NaN  90.412322  90.162368  1.344236e+06       NaN
# 2013-05-10       NaN  93.242211  89.508203  1.170147e+06       NaN
# 2013-05-13       NaN  77.185978  86.946837  8.075996e+05       NaN
# 2013-05-14       NaN  82.438191  84.288793  6.411092e+05       NaN
# 2013-05-07  0.000130      -0.000005        0.003014   587.200012  617.000000
# 2013-05-08  0.000179      -0.000061        0.003014   587.661987  614.049988
# 2013-05-09  0.000080       0.000040        0.003014   590.349976  617.036987
# 2013-05-10  0.000118       0.000040        0.003014   592.888000  624.549988
# 2013-05-13  0.000137      -0.000065        0.003014   584.900024  625.286987
# 2013-05-14  0.000143       0.000055        0.003014   587.513000  632.088013
# 2013-05-15  0.000108       0.000032        0.003014   590.112000  701.049988
# 2013-05-16  0.000201      -0.000089        0.003014   583.150024  685.674988
# 2013-05-17  0.000146       0.000064        0.003014   587.937988  682.200012
# 2013-05-20  0.000166       0.000111        0.003014   593.013000  687.713013
# ...              ...            ...             ...          ...         ...
# 2018-04-04  0.000219      -0.000173        0.000000  1124.199951         NaN
# 2018-04-05       NaN            NaN             NaN          NaN         NaN
# 2018-04-06       NaN            NaN             NaN          NaN         NaN
# 2018-04-09       NaN            NaN             NaN          NaN         NaN
# 2018-04-10       NaN            NaN             NaN          NaN         NaN
# 2018-04-11       NaN            NaN             NaN          NaN         NaN
# 2018-04-12       NaN            NaN             NaN          NaN         NaN
# 2018-04-13       NaN            NaN             NaN          NaN         NaN
# 2018-04-16       NaN            NaN             NaN          NaN         NaN
# 2018-04-17       NaN            NaN             NaN          NaN         NaN
# 2018-04-18       NaN            NaN             NaN          NaN         NaN
# 2018-04-19       NaN            NaN             NaN          NaN         NaN
# 2018-04-20       NaN            NaN             NaN          NaN         NaN
# 2018-04-23       NaN            NaN             NaN          NaN         NaN
# 2018-04-24       NaN            NaN             NaN          NaN         NaN
# 2018-04-25       NaN            NaN             NaN          NaN         NaN
# 2018-04-26       NaN            NaN             NaN          NaN         NaN
# 2018-04-27       NaN            NaN             NaN          NaN         NaN
# 2018-04-30       NaN            NaN             NaN          NaN         NaN
# 2018-05-02       NaN            NaN             NaN          NaN         NaN
# 2018-05-03       NaN            NaN             NaN          NaN         NaN
# 2018-05-04       NaN            NaN             NaN          NaN         NaN
# 2018-05-07       NaN            NaN             NaN          NaN         NaN
# 2018-05-08       NaN            NaN             NaN          NaN         NaN
# 2018-05-09       NaN            NaN             NaN          NaN         NaN
# 2018-05-10       NaN            NaN             NaN          NaN         NaN
# 2018-05-11       NaN            NaN             NaN          NaN         NaN
# 2018-05-14       NaN            NaN             NaN          NaN         NaN
# 2018-05-15       NaN            NaN             NaN          NaN         NaN
# 2018-05-16       NaN            NaN             NaN          NaN         NaN
#
#               ...        ave40   upper40   lower40     ave50   upper50  \
# Date          ...
# 2013-04-04    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-05    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-08    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-09    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-10    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-11    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-12    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-15    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-16    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-17    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-18    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-22    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-23    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-25    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-26    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-29    ...          NaN       NaN       NaN       NaN       NaN
# 2013-04-30    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-02    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-03    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-06    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-07    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-08    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-09    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-10    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-13    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-14    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-15    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-16    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-17    ...          NaN       NaN       NaN       NaN       NaN
# 2013-05-20    ...          NaN       NaN       NaN       NaN       NaN
# ...           ...          ...       ...       ...       ...       ...
# 2018-04-04    ...     1146.651  1169.687  1123.615  1149.978  1172.743
# 2018-04-05    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-06    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-09    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-10    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-11    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-12    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-13    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-16    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-17    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-18    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-19    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-20    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-23    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-24    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-25    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-26    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-27    ...          NaN       NaN       NaN       NaN       NaN
# 2018-04-30    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-02    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-03    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-04    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-07    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-08    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-09    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-10    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-11    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-14    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-15    ...          NaN       NaN       NaN       NaN       NaN
# 2018-05-16    ...          NaN       NaN       NaN       NaN       NaN
#
#              lower50         %K         %D        ch_osc       ROC
# Date
# 2013-04-04       NaN        NaN        NaN  0.000000e+00       NaN
# 2013-04-05       NaN        NaN        NaN  1.462488e+05       NaN
# 2013-04-08       NaN        NaN        NaN  1.177100e+05       NaN
# 2013-04-09       NaN        NaN        NaN -1.810622e+05       NaN
# 2013-04-10       NaN        NaN        NaN  3.661795e+05       NaN
# 2013-04-11       NaN        NaN        NaN  1.133948e+06       NaN
# 2013-04-12       NaN        NaN        NaN -4.814589e+06       NaN
# 2013-04-15       NaN        NaN        NaN  1.128706e+06       NaN
# 2013-04-16       NaN        NaN        NaN  5.947715e+05       NaN
# 2013-04-17       NaN        NaN        NaN  9.236166e+05       NaN
# 2013-04-18       NaN        NaN        NaN  6.877393e+05       NaN
# 2013-04-22       NaN        NaN        NaN  3.210197e+05       NaN
# 2013-04-23       NaN        NaN        NaN  8.508696e+05       NaN
# 2013-04-25       NaN   3.180570        NaN  4.248988e+04       NaN
# 2013-04-26       NaN   1.295867        NaN -4.343156e+04       NaN
# 2013-04-29       NaN   5.776420   3.417619  6.665624e+05       NaN
# 2013-04-30       NaN   6.596584   4.556290  1.101558e+06       NaN
# 2013-05-02       NaN  13.433823   8.602276  1.859854e+06       NaN
# 2013-05-03       NaN  16.268408  12.099605  1.896538e+06       NaN
# 2013-05-06       NaN  35.326134  21.676122  2.062323e+06       NaN
# 2013-05-07       NaN  95.204706  48.933083  2.124358e+06       NaN
# 2013-05-08       NaN  84.870076  71.800305  1.458403e+06       NaN
# 2013-05-09       NaN  90.412322  90.162368  1.344236e+06       NaN
# 2013-05-10       NaN  93.242211  89.508203  1.170147e+06       NaN
# 2013-05-13       NaN  77.185978  86.946837  8.075996e+05       NaN
# 2013-05-14       NaN  82.438191  84.288793  6.411092e+05       NaN
# 2013-05-15       NaN  87.662312  82.428827  6.516694e+05       NaN
# 2013-05-16       NaN  73.668390  81.256297  5.037390e+05       NaN
# 2013-05-17       NaN  83.292438  81.541047  5.034962e+05       NaN
# 2013-05-20       NaN  92.046685  83.002505  9.041460e+05       NaN
# ...              ...        ...        ...           ...       ...
# 2018-04-04  1127.213   5.948941  17.394649 -5.605287e+05 -0.513278
# 2018-04-05       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-06       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-09       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-10       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-11       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-12       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-13       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-16       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-17       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-18       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-19       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-20       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-23       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-24       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-25       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-26       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-27       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-04-30       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-02       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-03       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-04       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-07       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-08       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-09       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-10       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-11       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-14       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-15       NaN        NaN        NaN -5.605287e+05       NaN
# 2018-05-16       NaN        NaN        NaN -5.605287e+05       NaN
#
# [1261 rows x 24 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(roc30.loc[start_date:end_date, :].index, roc30.loc[start_date:end_date, 'ROC'], label = 'For 30 days')
ax.plot(roc40.loc[start_date:end_date, :].index, roc40.loc[start_date:end_date, 'ROC'], label = 'For 40 days')
ax.plot(roc50.loc[start_date:end_date, :].index, roc50.loc[start_date:end_date, 'ROC'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')
