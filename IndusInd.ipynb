dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
df1['Date']=pd.to_datetime(df1['Date'])

# %%
df1.isnull().sum()
# Out:
# Date         0
# Open         2
# High         2
# Low          2
# Close        2
# Adj Close    2
# Volume       2
# dtype: int64

# %%
df1.fillna(df1.mean(),inplace=True)

# %%
close_zero=df1.iloc[-1].Close

# %%
df1['HL_PCT'] = (df1['High'] - df1['Low'])/(df1['Low']*100)

# %%
df1['PCT_CHNG_OpCl'] = (df1['Close'] - df1['Open'])/(df1['Open']*100)

# %%
df1['PCT_CHNG_CLOSE'] = (df1['Close'] - df1['Adj Close'])/(df1['Adj Close']*100)

# %%
df1.index=df1['Date']

# %%
df1.head()
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2013-04-04 2013-04-04  418.200012  418.200012  402.049988  405.149994
# 2013-04-05 2013-04-05  404.100006  405.299988  398.149994  400.850006
# 2013-04-08 2013-04-08  400.600006  406.799988  392.600006  393.500000
# 2013-04-09 2013-04-09  397.899994  402.299988  388.500000  390.250000
# 2013-04-10 2013-04-10  390.950012  393.149994  383.049988  387.149994
#
#              Adj Close     Volume    HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE
# Date
# 2013-04-04  393.355682  2162736.0  0.000402      -0.000312          0.0003
# 2013-04-05  389.180817  1357287.0  0.000180      -0.000080          0.0003
# 2013-04-08  382.044769  1898773.0  0.000362      -0.000177          0.0003
# 2013-04-09  378.889404  1325954.0  0.000355      -0.000192          0.0003
# 2013-04-10  375.879639  2785331.0  0.000264      -0.000097          0.0003

# %%
df=df1[['Open','High','Low','Adj Close','Volume','HL_PCT','PCT_CHNG_OpCl','PCT_CHNG_CLOSE','Close']]

# %% [markdown]
# ## Prediction for 30th Day

# %%
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
import datetime
# Out:
# C:\Users\Debadri\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df['Close'].plot(figsize=(15,6), color="green")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.tail()
# Out:
#                    Open         High          Low    Adj Close     Volume  \
# Date
# 2018-03-27  1772.000000  1796.000000  1758.800049  1788.199951   852040.0
# 2018-03-28  1772.150024  1807.000000  1772.150024  1796.750000  2380088.0
# 2018-04-02  1796.750000  1809.900024  1787.500000  1804.599976   663945.0
# 2018-04-03  1795.000000  1841.199951  1795.000000  1829.699951  1152587.0
# 2018-04-04  1830.000000  1839.449951  1792.599976  1799.349976   732382.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE        Close
# Date
# 2018-03-27  0.000212       0.000091             0.0  1788.199951
# 2018-03-28  0.000197       0.000139             0.0  1796.750000
# 2018-04-02  0.000125       0.000044             0.0  1804.599976
# 2018-04-03  0.000257       0.000193             0.0  1829.699951
# 2018-04-04  0.000261      -0.000167             0.0  1799.349976

# %%
forecast_col = 'Close'

forecast_out = int(42)
# We will drop 12 columns because there are 12 holidays

# %%
df['label'] = df[forecast_col].shift(-forecast_out)
print(df.head(2))
# Out:
#                   Open        High         Low   Adj Close     Volume  \
# Date
# 2013-04-04  418.200012  418.200012  402.049988  393.355682  2162736.0
# 2013-04-05  404.100006  405.299988  398.149994  389.180817  1357287.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close       label
# Date
# 2013-04-04  0.000402      -0.000312          0.0003  405.149994  509.700012
# 2013-04-05  0.000180      -0.000080          0.0003  400.850006  507.149994

# %%
X = np.array(df.drop(['label'], 1))

# %%
X = preprocessing.scale(X)

# %%
X_forecast_out = X[-forecast_out:]
X = X[:-forecast_out]

# %%
y = np.array(df['label'])
y = y[:-forecast_out]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
clf = LinearRegression()
clf.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("Accurac
# 2013-04-11 00:00:00  401.200012  488.799988          NaN
# 2013-04-12 00:00:00  400.549988  482.100006          NaN
# 2013-04-15 00:00:00  401.950012  486.100006          NaN
# 2013-04-16 00:00:00  417.250000  477.600006          NaN
# 2013-04-17 00:00:00  419.600006  478.450012          NaN
# 2013-04-18 00:00:00  450.350006  449.250000          NaN
# 2013-04-22 00:00:00  466.399994  464.299988          NaN
# 2013-04-23 00:00:00  461.149994  453.700012          NaN
# 2013-04-25 00:00:00  467.850006  471.700012          NaN
# 2013-04-26 00:00:00  458.149994  455.200012          NaN
# 2013-04-29 00:00:00  477.700012  455.649994          NaN
# 2013-04-30 00:00:00  467.750000  467.450012          NaN
# 2013-05-02 00:00:00  472.799988  471.950012          NaN
# 2013-05-03 00:00:00  468.049988  476.450012          NaN
# 2013-05-06 00:00:00  474.500000  467.250000          NaN
# 2013-05-07 00:00:00  484.899994  472.299988          NaN
# 2013-05-08 00:00:00  493.200012  475.049988          NaN
# 2013-05-09 00:00:00  488.899994  492.200012          NaN
# 2013-05-10 00:00:00  505.649994  503.500000          NaN
# 2013-05-13 00:00:00  493.149994  495.950012          NaN
# 2013-05-14 00:00:00  490.299988  510.700012          NaN
# 2013-05-15 00:00:00  514.049988  502.850006          NaN
# 2013-05-16 00:00:00  524.549988  506.350006          NaN
# 2013-05-17 00:00:00  511.100006  466.399994          NaN
# 2013-05-20 00:00:00  501.799988  453.899994          NaN
# ...                         ...         ...          ...
# 2018-04-17 05:30:00         NaN         NaN  1664.577803
# 2018-04-18 05:30:00         NaN         NaN  1667.215874
# 2018-04-19 05:30:00         NaN         NaN  1633.756010
# 2018-04-20 05:30:00         NaN         NaN  1653.718326
# 2018-04-21 05:30:00         NaN         NaN  1681.354757
# 2018-04-22 05:30:00         NaN         NaN  1712.546061
# 2018-04-23 05:30:00         NaN         NaN  1722.853852
# 2018-04-24 05:30:00         NaN         NaN  1714.716896
# 2018-04-25 05:30:00         NaN         NaN  1729.683900
# 2018-04-26 05:30:00         NaN         NaN  1724.226203
# 2018-04-27 05:30:00         NaN         NaN  1742.768984
# 2018-04-28 05:30:00         NaN         NaN  1735.487248
# 2018-04-29 05:30:00         NaN         NaN  1724.950490
# 2018-04-30 05:30:00         NaN         NaN  1731.859791
# 2018-05-01 05:30:00         NaN         NaN  1759.952645
# 2018-05-02 05:30:00         NaN         NaN  1757.525600
# 2018-05-03 05:30:00         NaN         NaN  1761.095100
# 2018-05-04 05:30:00         NaN         NaN  1770.733953
# 2018-05-05 05:30:00         NaN         NaN  1754.022341
# 2018-05-06 05:30:00         NaN         NaN  1753.400420
# 2018-05-07 05:30:00         NaN         NaN  1746.922448
# 2018-05-08 05:30:00         NaN         NaN  1762.120079
# 2018-05-09 05:30:00         NaN         NaN  1779.700379
# 2018-05-10 05:30:00         NaN         NaN  1772.677404
# 2018-05-11 05:30:00         NaN         NaN  1787.884561
# 2018-05-12 05:30:00         NaN         NaN  1804.746858
# 2018-05-13 05:30:00         NaN         NaN  1813.771864
# 2018-05-14 05:30:00         NaN         NaN  1827.464940
# 2018-05-15 05:30:00         NaN         NaN  1838.808232
# 2018-05-16 05:30:00         NaN         NaN  1817.043330
#
# [1274 rows x 11 columns]

# %%
pred=df[-42:]

# %%
df=df[:-42]

# %%
pred
# Out:
#                      Open  High  Low  Adj Close  Volume  HL_PCT  \
# Date
# 2018-04-05 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-06 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-07 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-08 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-09 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-10 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-11 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-12 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-13 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-14 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-15 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04-16 05:30:00   NaN   NaN  NaN        NaN     NaN     NaN
# 2018-04
# 2018-05-08 05:30:00            NaN             NaN    NaN    NaN  1762.120079
# 2018-05-09 05:30:00            NaN             NaN    NaN    NaN  1779.700379
# 2018-05-10 05:30:00            NaN             NaN    NaN    NaN  1772.677404
# 2018-05-11 05:30:00            NaN             NaN    NaN    NaN  1787.884561
# 2018-05-12 05:30:00            NaN             NaN    NaN    NaN  1804.746858
# 2018-05-13 05:30:00            NaN             NaN    NaN    NaN  1813.771864
# 2018-05-14 05:30:00            NaN             NaN    NaN    NaN  1827.464940
# 2018-05-15 05:30:00            NaN             NaN    NaN    NaN  1838.808232
# 2018-05-16 05:30:00            NaN             NaN    NaN    NaN  1817.043330

# %%
pred=pred.reset_index()

# %%
pred['Date']=pred['Date'].dt.date

# %%
pred.head(1)
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#    PCT_CHNG_CLOSE  Close  label     forecast
# 0             NaN    NaN    NaN  1774.221108

# %%
holidays=['2018-04-07','2018-04-08','2018-04-14','2018-04-15','2018-04-21','2018-04-22','2018-04-28','2018-04-29','2018-05-01','2018-05-05','2018-05-06','2018-05-12','2018-05-13']

# %%
pred['Date']=pred['Date'].apply(str)

# %%
for i in holidays:
    pred = pred.drop(pred[pred.Date==i].index)

# %%
pred['Date']=pd.to_datetime(pred['Date'])

# %%
pred.drop('forecast',axis=1,inplace=True)

# %%
pred.shape
# Out:
# (29, 11)

# %%
pred['forecast']=forecast_prediction[:29]

# %%
pred
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 1  2018-04-06   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 4  2018-04-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 5  2018-04-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 6  2018-04-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 7  2018-04-12   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 8  2018-04-13   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 11 2018-04-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 12 2018-04-17   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 13 2018-04-18   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 14 2018-04-19   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 15 2018-04-20   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 18 2018-04-23   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 19 2018-04-24   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 20 2018-04-25   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 21 2018-04-26   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 22 2018-04-27   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 25 2018-04-30   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 27 2018-05-02   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 28 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 29 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 32 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 33 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 34 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 35 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 36 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 39 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 40 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 41 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#     PCT_CHNG_CLOSE  Close  label     forecast
# 0              NaN    NaN    NaN  1774.221108
# 1              NaN    NaN    NaN  1785.054122
# 4              NaN    NaN    NaN  1774.588442
# 5              NaN    NaN    NaN  1729.518810
# 6              NaN    NaN    NaN  1703.429814
# 7              NaN    NaN    NaN  1691.308177
# 8              NaN    NaN    NaN  1710.133094
# 11             NaN    NaN    NaN  1689.211217
# 12             NaN    NaN    NaN  1708.670940
# 13             NaN    NaN    NaN  1728.267185
# 14             NaN    NaN    NaN  1717.022140
# 15             NaN    NaN    NaN  1690.306139
# 18             NaN    NaN    NaN  1664.577803
# 19             NaN    NaN    NaN  1667.215874
# 20             NaN    NaN    NaN  1633.756010
# 21             NaN    NaN    NaN  1653.718326
# 22             NaN    NaN    NaN  1681.354757
# 25             NaN    NaN    NaN  1712.546061
# 27             NaN    NaN    NaN  1722.853852
# 28             NaN    NaN    NaN  1714.716896
# 29             NaN    NaN    NaN  1729.683900
# 32             NaN    NaN    NaN  1724.226203
# 33             NaN    NaN    NaN  1742.768984
# 34             NaN    NaN    NaN  1735.487248
# 35             NaN    NaN    NaN  1724.950490
# 36             NaN    NaN    NaN  1731.859791
# 39             NaN    NaN    NaN  1759.952645
# 40             NaN    NaN    NaN  1757.525600
# 41             NaN    NaN    NaN  1761.095100

# %%
pred.index=pred['Date']
pred.drop('Date',axis=1,inplace=True)

# %%
df=df.append(pred)

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.xlim(xmin=datetime.date(2018, 4, 4))
plt.ylim(ymin=-100)
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.iloc[-1]
# Out:
# Open                    NaN
# High                    NaN
# Low                     NaN
# Adj Close               NaN
# Volume                  NaN
# HL_PCT                  NaN
# PCT_CHNG_OpCl           NaN
# PCT_CHNG_CLOSE          NaN
# Close                   NaN
# label                   NaN
# forecast          1761.0951
# Name: 2018-05-16 00:00:00, dtype: float64

# %%
close_last=df.iloc[-1].forecast

# %%
pred_return=close_last-close_zero
print("Predicted Return: Rs.",pred_return)
# Out:
# Predicted Return: Rs. -38.25487561316254

# %% [markdown]
# ## Simple Moving Average (30,40,50)

# %%
# For 30 days
short_rolling = df.rolling(window=30).mean()
short_rolling.head(30)
# Out:
#                   Open        High         Low   Adj Close        Volume  \
# Date
# 2013-04-04         NaN         NaN         NaN         NaN           NaN
# 2013-04-05         NaN         NaN         NaN         NaN           NaN
# 2013-04-08         NaN         NaN         NaN         NaN           NaN
# 2013-04-09         NaN         NaN         NaN         NaN           NaN
# 2013-04-10         NaN         NaN         NaN         NaN           NaN
# 2013-04-11         NaN         NaN         NaN         NaN           NaN
# 2013-04-12         NaN         NaN         NaN         NaN           NaN
# 2013-04-15         NaN         NaN         NaN         NaN           NaN
# 2013-04-16         NaN         NaN         NaN         NaN           NaN
# 2013-04-17         NaN         NaN         NaN         NaN           NaN
# 2013-04-18         NaN         NaN         NaN         NaN           NaN
# 2013-04-22         NaN         NaN         NaN         NaN           NaN
# 2013-04-23         NaN         NaN         NaN         NaN           NaN
# 2013-04-25         NaN         NaN         NaN         NaN           NaN
# 2013-04-26         NaN         NaN         NaN         NaN           NaN
# 2013-04-29         NaN         NaN         NaN         NaN           NaN
# 2013-04-30         NaN         NaN         NaN         NaN           NaN
# 2013-05-02         NaN         NaN         NaN         NaN           NaN
# 2013-05-03         NaN         NaN         NaN         NaN           NaN
# 2013-05-06         NaN         NaN         NaN         NaN           NaN
# 2013-05-07         NaN         NaN         NaN         NaN           NaN
# 2013-05-08         NaN         NaN         NaN         NaN           NaN
# 2013-05-09         NaN         NaN         NaN         NaN           NaN
# 2013-05-10         NaN         NaN         NaN         NaN           NaN
# 2013-05-13         NaN         NaN         NaN         NaN           NaN
# 2013-05-14         NaN         NaN         NaN         NaN           NaN
# 2013-05-15         NaN         NaN         NaN         NaN           NaN
# 2013-05-16         NaN         NaN         NaN         NaN           NaN
# 2013-05-17         NaN         NaN         NaN         NaN           NaN
# 2013-05-20  454.493337  463.686666  446.850002  443.040875  2.104061e+06
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close      label  \
# Date
# 2013-04-04       NaN            NaN             NaN         NaN        NaN
# 2013-04-05       NaN            NaN             NaN         NaN        NaN
# 2013-04-08       NaN            NaN             NaN         NaN        NaN
# 2013-04-09       NaN            NaN             NaN         NaN        NaN
# 2013-04-10       NaN            NaN             NaN         NaN        NaN
# 2013-04-11       NaN            NaN             NaN         NaN        NaN
# 2013-04-12       NaN            NaN             NaN         NaN        NaN
# 2013-04-15       NaN            NaN             NaN         NaN        NaN
# 2013-04-16       NaN            NaN             NaN         NaN        NaN
# 2013-04-17       NaN            NaN             NaN         NaN        NaN
# 2013-04-18       NaN            NaN             NaN         NaN        NaN
# 2013-04-22       NaN            NaN             NaN         NaN        NaN
# 2013-04-23       NaN            NaN             NaN         NaN        NaN
# 2013-04-25       NaN            NaN             NaN         NaN        NaN
# 2013-04-26       NaN            NaN             NaN         NaN        NaN
# 2013-04-29       NaN            NaN             NaN         NaN        NaN
# 2013-04-30       NaN            NaN             NaN         NaN        NaN
# 2013-05-02       NaN            NaN             NaN         NaN        NaN
# 2013-05-03       NaN            NaN             NaN         NaN        NaN
# 2013-05-06       NaN            NaN             NaN         NaN        NaN
# 2013-05-07       NaN            NaN             NaN         NaN        NaN
# 2013-05-08       NaN            NaN             NaN         NaN        NaN
# 2013-05-09       NaN            NaN             NaN         NaN        NaN
# 2013-05-10       NaN            NaN             NaN         NaN        NaN
# 2013-05-13       NaN            NaN             NaN         NaN        NaN
# 2013-05-14       NaN            NaN             NaN         NaN        NaN
# 2013-05-15       NaN            NaN             NaN         NaN        NaN
# 2013-05-16       NaN            NaN             NaN         NaN        NaN
# 2013-05-17       NaN            NaN             NaN         NaN        NaN
# 2013-05-20  0.000377       0.000041          0.0003  456.324998  480.23167
#
#             forecast
# Date
# 2013-04-04       NaN
# 2013-04-05       NaN
# 2013-04-08       NaN
# 2013-04-09       NaN
# 2013-04-10       NaN
# 2013-04-11       NaN
# 2013-04-12       NaN
# 2013-04-15       NaN
# 2013-04-16       NaN
# 2013-04-17       NaN
# 2013-04-18       NaN
# 2013-04-22       NaN
# 2013-04-23       NaN
# 2013-04-25       NaN
# 2013-04-26       NaN
# 2013-04-29       NaN
# 2013-04-30       NaN
# 2013-05-02       NaN
# 2013-05-03       NaN
# 2013-05-06       NaN
# 2013-05-07       NaN
# 2013-05-08       NaN
# 2013-05-09       NaN
# 2013-05-10       NaN
# 2013-05-13       NaN
# 2013-05-14       NaN
# 2013-05-15       NaN
# 2013-05-16       NaN
# 2013-05-17       NaN
# 2013-05-20       NaN

# %%
# For 40 days
med_rolling = df.rolling(window=40).mean()
med_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
# For 50 days
long_rolling = df.rolling(window=50).mean()
long_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
start_date = '2013-04-29'
end_date = '2018-04-04'

fig, ax = plt.subplots(figsize=(16,9))

ax.plot(long_rolling.loc[start_date:end_date, :].index, long_rolling.loc[start_date:end_date, 'Close'], label = '50-days SMA')
ax.plot(med_rolling.loc[start_date:end_date, :].index, med_rolling.loc[start_date:end_date, 'Close'], label = '40-days SMA')
ax.plot(short_rolling.loc[start_date:end_date, :].index, short_rolling.loc[start_date:end_date, 'Close'], label = '30-days SMA')


ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Exponential Moving Average (30,40,50)

# %%
ema_short = df.ewm(span=30, adjust=False).mean()
ema_med = df.ewm(span=40, adjust=False).mean()
ema_long = df.ewm(span=50, adjust=False).mean()

fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ema_short.loc[start_date:end_date, :].index, ema_short.loc[start_date:end_date, 'Close'], label = 'Span 30-days EMA')
ax.plot(ema_med.loc[start_date:end_date, :].index, ema_med.loc[start_date:end_date, 'Close'], label = 'Span 40-days EMA')
ax.plot(ema_long.loc[start_date:end_date, :].index, ema_long.loc[start_date:end_date, 'Close'], label = 'Span 50-days EMA')

ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Aroon Oscillator (30,40,50)

# %%
from pandas.stats import moments
from pandas import DataFrame

# %%
def aroon(s, n):
    up = 100 * moments.rolling_apply(s.High, n + 1, lambda x: x.argmax()) / n
    dn = 100 * moments.rolling_apply(s.Low, n + 1, lambda x: x.argmin()) / n

    return DataFrame(dict(up=up, down=dn))

# %%
ao30=aroon(df,30)
ao40=aroon(df,40)
ao50=aroon(df,50)

# %%
ao30
# Out:
#                  down         up
# Date
# 2013-04-04        NaN        NaN
# 2013-04-05        NaN        NaN
# 2013-04-08        NaN        NaN
# 2013-04-09        NaN        NaN
# 2013-04-10        NaN        NaN
# 2013-04-11        NaN        NaN
# 2013-04-12        NaN        NaN
# 2013-04-15        NaN        NaN
# 2013-04-16        NaN        NaN
# 2013-04-17        NaN        NaN
# 2013-04-18        NaN        NaN
# 2013-04-22        NaN        NaN
# 2013-04-23        NaN        NaN
# 2013-04-25        NaN        NaN
# 2013-04-26        NaN        NaN
# 2013-04-29        NaN        NaN
# 2013-04-30        NaN        NaN
# 2013-05-02        NaN        NaN
# 2013-05-03        NaN        NaN
# 2013-05-06        NaN        NaN
# 2013-05-07        NaN        NaN
# 2013-05-08        NaN        NaN
# 2013-05-09        NaN        NaN
# 2013-05-10        NaN        NaN
# 2013-05-13        NaN        NaN
# 2013-05-14        NaN        NaN
# 2013-05-15        NaN        NaN
# 2013-05-16        NaN        NaN
# 2013-05-17        NaN        NaN
# 2013-05-20        NaN        NaN
# ...               ...        ...
# 2018-04-04  13.333333  96.666667
# 2018-04-05        NaN        NaN
# 2018-04-06        NaN        NaN
# 2018-04-09        NaN        NaN
# 2018-04-10        NaN        NaN
# 2018-04-11        NaN        NaN
# 2018-04-12        NaN        NaN
# 2018-04-13        NaN        NaN
# 2018-04-16        NaN        NaN
# 2018-04-17        NaN        NaN
# 2018-04-18        NaN        NaN
# 2018-04-19        NaN        NaN
# 2018-04-20        NaN        NaN
# 2018-04-23        NaN        NaN
# 2018-04-24        NaN        NaN
# 2018-04-25        NaN        NaN
# 2018-04-26        NaN        NaN
# 2018-04-27        NaN        NaN
# 2018-04-30        NaN        NaN
# 2018-05-02        NaN        NaN
# 2018-05-03        NaN        NaN
# 2018-05-04        NaN        NaN
# 2018-05-07        NaN        NaN
# 2018-05-08        NaN        NaN
# 2018-05-09        NaN        NaN
# 2018-05-10        NaN        NaN
# 2018-05-11        NaN        NaN
# 2018-05-14        NaN        NaN
# 2018-05-15        NaN        NaN
# 2018-05-16        NaN        NaN
#
# [1261 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 30-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 30-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 40-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 40-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'down'], label = ' Down 50-days Aroon Oscillator')
ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'up'], label = 'Up 50-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %% [markdown]
# ## MACD Signal

# %%
def ema(s, n, wilder=False):
    span = n if not wilder else 2*n - 1
    return moments.ewma(s, span=span)


def macd(s, nfast=12, nslow=26, nsig=9, percent=True):
    fast, slow = ema(s, nfast), ema(s, nslow)

    if percent:
        macd = 100*(fast / slow - 1)
    else:
        macd = fast - slow

    sig = ema(macd, nsig)
    hist = macd - sig

    return DataFrame(dict(macd=macd, signal=sig, hist=hist,
                          fast=fast, slow=slow))

# %%
m=macd(df['Close'])

# %%
m.head(1)
# Out:
#                   fast  hist  macd  signal        slow
# Date
# 2013-04-04  405.149994   0.0   0.0     0.0  405.149994

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(m.loc[start_date:end_date, :].index, m.loc[start_date:end_date, 'macd'], label = 'MACD')

ax.legend(loc='best')
ax.set_ylabel('Change ')
# Out:
# Text(0,0.5,'Change ')

# %% [markdown]
# ## Relative Strength Index (RSI)

# %%
def rsi(s, n=14):
    diff = s.diff()
    which_dn = diff < 0

    up, dn = diff, diff*0
    up[which_dn], dn[which_dn] = 0, -up[which_dn]

    emaup = ema(up, n, wilder=True)
    emadn = ema(dn, n, wilder=True)

    return 100 * emaup/(emaup + emadn)

# %%
sf=rsi(df['Close'],50)

# %%
sfd=pd.DataFrame({'Date':sf.index, 'RSI':sf.values})

# %%
sfd.index=sfd['Date']

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(sfd.loc[start_date:end_date, :].index, sfd.loc[start_date:end_date, 'RSI'], label = 'RSI')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Bollinger Bands (30,40,50)

# %%
price=df["Close"]

def bbands(price, length=30, numsd=2):
    """ returns average, upper band, and lower band"""
    ave = pd.stats.moments.rolling_mean(price,length)
    sd = pd.stats.moments.rolling_std(price,length)
    upband = ave + (sd*numsd)
    dnband = ave - (sd*numsd)
    return np.round(ave,3), np.round(upband,3), np.round(dnband,3)

df['ave30'], df['upper30'], df['lower30'] = bbands(df.Close, length=30, numsd=1)
df['ave40'], df['upper40'], df['lower40'] = bbands(df.Close, length=40, numsd=1)
df['ave50'], df['upper50'], df['lower50'] = bbands(df.Close, length=50, numsd=1)

# %%
# For 30 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave30'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower30'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper30'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 40 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave40'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower40'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper40'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 50 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave50'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower50'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper50'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Stochastic Oscillator

# %%
def STOK(close, low, high, n): 
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 return STOK

def STOD(close, low, high, n):
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 STOD = pd.rolling_mean(STOK, 3)
 return STOD

# %%
df['%K'] = STOK(df['Close'], df['Low'], df['High'], 14)
df['%D'] = STOD(df['Close'], df['Low'], df['High'], 14)

# %%
df.plot(y=['Close'], figsize = (20, 5))
df.plot(y=['%K', '%D'], figsize = (20, 5))

# %% [markdown]
# ## Chande Oscillator

# %%
def avg_true_range(df): 
  ind = range(0,len(df))
  indexlist = list(ind)
  df.index = indexlist

  for index, row in df.iterrows():
    if index != 0:
      tr1 = row["High"] - row["Low"]
      tr2 = abs(row["High"] - df.iloc[index-1]["Close"])
      tr3 = abs(row["Low"] - df.iloc[index-1]["Close"])

      true_range = max(tr1, tr2, tr3)
      df.set_value(index,"True Range", true_range)

  df["Avg TR"] = df["True Range"].rolling(min_periods=14, window=14, center=False).mean()
  return df

# %%
def chandelier_exit(df):

  df_tr = avg_true_range(df)

  df_tr['rolling_high']= df_tr["High"]
  df_tr['rolling_low'] = df_tr["Low"]

  df_tr['chandelier_long'] = df_tr['rolling_high'] - df_tr["Avg TR"] * 3
  df_tr['chandelier_short'] = df_tr['rolling_low'] - df_tr["Avg TR"] * 3
  fig, ax = plt.subplots(figsize=(15,9))

  ax.plot(df_tr['Date'], df_tr['chandelier_long'], label = 'Chand Long')

# %%
ch=chandelier_exit(df1)

# %% [markdown]
# ## Commodity Channel Index (30,40,50)

# %%
def CCI(data, ndays): 
 TP = (data['High'] + data['Low'] + data['Close']) / 3 
 CCI = pd.Series((TP - pd.rolling_mean(TP, ndays)) / (0.015 * pd.rolling_std(TP, ndays)),
 name = 'CCI')
 data=data.join(CCI)
 return data

# %%
cci30=CCI(df,30)
cci40=CCI(df,40)
cci50=CCI(df,50)

# %%
cci30
# Out:
#                    Open         High          Low    Adj Close     Volume  \
# Date
# 2013-04-04
# 2013-04-17  0.000329      -0.000073          0.0003   419.600006  478.450012
# 2013-04-18  0.000930       0.000647          0.0003   450.350006  449.250000
# 2013-04-22  0.000479       0.000356          0.0003   466.399994  464.299988
# 2013-04-23  0.000375      -0.000136          0.0003   461.149994  453.700012
# 2013-04-25  0.000381       0.000145          0.0003   467.850006  471.700012
# 2013-04-26  0.000319      -0.000199          0.0003   458.149994  455.200012
# 2013-04-29  0.000791       0.000442          0.0003   477.700012  455.649994
# 2013-04-30  0.000298      -0.000235          0.0003   467.750000  467.450012
# 2013-05-02  0.000252       0.000108          0.0003   472.799988  471.950012
# 2013-05-03  0.000405      -0.000109          0.0003   468.049988  476.450012
# 2013-05-06  0.000436       0.000193          0.0003   474.500000  467.250000
# 2013-05-07  0.000456       0.000176          0.0003   484.899994  472.299988
# 2013-05-08  0.000228       0.000180          0.0003   493.200012  475.049988
# 2013-05-09  0.000155      -0.000103          0.0003   488.899994  492.200012
# 2013-05-10  0.000421       0.000340          0.0003   505.649994  503.500000
# 2013-05-13  0.000350      -0.000291          0.0003   493.149994  495.950012
# 2013-05-14  0.000202      -0.000065          0.0003   490.299988  510.700012
# 2013-05-15  0.000496       0.000381          0.0003   514.049988  502.850006
# 2013-05-16  0.000354       0.000260          0.0003   524.549988  506.350006
# 2013-05-17  0.000364      -0.000246          0.0003   511.100006  466.399994
# 2013-05-20  0.000400      -0.000218          0.0003   501.799988  453.899994
# ...              ...            ...             ...          ...         ...
# 2018-04-04  0.000261      -0.000167          0.0000  1799.349976         NaN
# 2018-04-05       NaN            NaN             NaN          NaN         NaN
# 2018-04-06       NaN            NaN             NaN          NaN         NaN
# 2018-04-09       NaN            NaN             NaN          NaN         NaN
# 2018-04-10       NaN            NaN             NaN          NaN         NaN
# 2018-04-11       NaN            NaN             NaN          NaN         NaN
# 2018-04-12       NaN            NaN             NaN          NaN         NaN
# 2018-04-13       NaN            NaN             NaN          NaN         NaN
# 2018-04-16       NaN            NaN             NaN          NaN         NaN
# 2018-04-17       NaN            NaN             NaN          NaN         NaN
# 2018-04-18       NaN            NaN             NaN          NaN         NaN
# 2018-04-19       NaN            NaN             NaN          NaN         NaN
# 2018-04-20       NaN            NaN             NaN          NaN         NaN
# 2018-04-23       NaN            NaN             NaN          NaN         NaN
# 2018-04-24       NaN            NaN             NaN          NaN         NaN
# 2018-04-25       NaN            NaN             NaN          NaN         NaN
# 2018-04-26       NaN            NaN             NaN          NaN         NaN
# 2018-04-27       NaN            NaN             NaN          NaN         NaN
# 2018-04-30       NaN            NaN             NaN          NaN         NaN
# 2018-05-02       NaN            NaN             NaN          NaN         NaN
# 2018-05-03       NaN            NaN             NaN          NaN         NaN
# 2018-05-04       NaN            NaN             NaN          NaN         NaN
# 2018-05-07       NaN            NaN             NaN          NaN         NaN
# 2018-05-08       NaN            NaN             NaN          NaN         NaN
# 2018-05-09       NaN            NaN             NaN          NaN         NaN
# 2018-05-10       NaN            NaN             NaN          NaN         NaN
# 2018-05-11       NaN            NaN             NaN          NaN         NaN
# 2018-05-14       NaN            NaN             NaN          NaN         NaN
# 2018-05-15       NaN            NaN             NaN          NaN         NaN
# 2018-05-16       NaN            NaN             NaN          NaN         NaN
#
#                ...       lower30    ave40   upper40   lower40     ave50  \
# Date           ...
# 2013-04-04     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-05     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-08     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-09     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-10     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-11     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-12     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-15     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-16     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-17     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-18     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-22     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-23     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-25     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-26     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-29     ...           NaN      NaN       NaN       NaN       NaN
# 2013-04-30     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-02     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-03     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-06     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-07     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-08     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-09     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-10     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-13     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-14     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-15     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-16     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-17     ...           NaN      NaN       NaN       NaN       NaN
# 2013-05-20     ...       413.319      NaN       NaN       NaN       NaN
# ...            ...           ...      ...       ...       ...       ...
# 2018-04-04     ...      1658.724  1708.67  1761.996  1655.344  1711.841
# 2018-04-05     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-06     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-09     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-10     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-11     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-12     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-13     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-16     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-17     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-18     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-19     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-20     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-23     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-24     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-25     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-26     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-27     ...           NaN      NaN       NaN       NaN       NaN
# 2018-04-30     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-02     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-03     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-04     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-07     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-08     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-09     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-10     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-11     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-14     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-15     ...           NaN      NaN       NaN       NaN       NaN
# 2018-05-16     ...           NaN      NaN       NaN       NaN       NaN
#
#              upper50   lower50         %K         %D         CCI
# Date
# 2013-04-04       NaN       NaN        NaN        NaN         NaN
# 2013-04-05       NaN       NaN        NaN        NaN         NaN
# 2013-04-08       NaN       NaN        NaN        NaN         NaN
# 2013-04-09       NaN       NaN        NaN        NaN         NaN
# 2013-04-10       NaN       NaN        NaN        NaN         NaN
# 2013-04-11       NaN       NaN        NaN        NaN         NaN
# 2013-04-12       NaN       NaN        NaN        NaN         NaN
# 2013-04-15       NaN       NaN        NaN        NaN         NaN
# 2013-04-16       NaN       NaN        NaN        NaN         NaN
# 2013-04-17       NaN       NaN        NaN        NaN         NaN
# 2013-04-18       NaN       NaN        NaN        NaN         NaN
# 2013-04-22       NaN       NaN        NaN        NaN         NaN
# 2013-04-23       NaN       NaN        NaN        NaN         NaN
# 2013-04-25       NaN       NaN  88.842334        NaN         NaN
# 2013-04-26       NaN       NaN  78.679934        NaN         NaN
# 2013-04-29       NaN       NaN  93.573902  87.032056         NaN
# 2013-04-30       NaN       NaN  83.737016  85.330284         NaN
# 2013-05-02       NaN       NaN  88.729588  88.680169         NaN
# 2013-05-03       NaN       NaN  83.124324  85.196976         NaN
# 2013-05-06       NaN       NaN  89.281755  87.045222         NaN
# 2013-05-07       NaN       NaN  89.698890  87.368323         NaN
# 2013-05-08       NaN       NaN  98.032800  92.337815         NaN
# 2013-05-09       NaN       NaN  92.802353  93.511348         NaN
# 2013-05-10       NaN       NaN  95.828812  95.554655         NaN
# 2013-05-13       NaN       NaN  73.108537  87.246567         NaN
# 2013-05-14       NaN       NaN  68.421027  79.119459         NaN
# 2013-05-15       NaN       NaN  96.386412  79.305325         NaN
# 2013-05-16       NaN       NaN  96.501271  87.102903         NaN
# 2013-05-17       NaN       NaN  79.389330  90.759004         NaN
# 2013-05-20       NaN       NaN  63.906579  79.932393   80.675959
# ...              ...       ...        ...        ...         ...
# 2018-04-04  1762.273  1661.409  69.913744  85.576585  113.560649
# 2018-04-05       NaN       NaN        NaN        NaN         NaN
# 2018-04-06       NaN       NaN        NaN        NaN         NaN
# 2018-04-09       NaN       NaN        NaN        NaN         NaN
# 2018-04-10       NaN       NaN        NaN        NaN         NaN
# 2018-04-11       NaN       NaN        NaN        NaN         NaN
# 2018-04-12       NaN       NaN        NaN        NaN         NaN
# 2018-04-13       NaN       NaN        NaN        NaN         NaN
# 2018-04-16       NaN       NaN        NaN        NaN         NaN
# 2018-04-17       NaN       NaN        NaN        NaN         NaN
# 2018-04-18       NaN       NaN        NaN        NaN         NaN
# 2018-04-19       NaN       NaN        NaN        NaN         NaN
# 2018-04-20       NaN       NaN        NaN        NaN         NaN
# 2018-04-23       NaN       NaN        NaN        NaN         NaN
# 2018-04-24       NaN       NaN        NaN        NaN         NaN
# 2018-04-25       NaN       NaN        NaN        NaN         NaN
# 2018-04-26       NaN       NaN        NaN        NaN         NaN
# 2018-04-27       NaN       NaN        NaN        NaN         NaN
# 2018-04-30       NaN       NaN        NaN        NaN         NaN
# 2018-05-02       NaN       NaN        NaN        NaN         NaN
# 2018-05-03       NaN       NaN        NaN        NaN         NaN
# 2018-05-04       NaN       NaN        NaN        NaN         NaN
# 2018-05-07       NaN       NaN        NaN        NaN         NaN
# 2018-05-08       NaN       NaN        NaN        NaN         NaN
# 2018-05-09       NaN       NaN        NaN        NaN         NaN
# 2018-05-10       NaN       NaN        NaN        NaN         NaN
# 2018-05-11       NaN       NaN        NaN        NaN         NaN
# 2018-05-14       NaN       NaN        NaN        NaN         NaN
# 2018-05-15       NaN       NaN        NaN        NaN         NaN
# 2018-05-16       NaN       NaN        NaN        NaN         NaN
#
# [1261 rows x 23 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(cci30.loc[start_date:end_date, :].index, cci30.loc[start_date:end_date, 'CCI'], label = 'For 30 days')
ax.plot(cci40.loc[start_date:end_date, :].index, cci40.loc[start_date:end_date, 'CCI'], label = 'For 40 days')
ax.plot(cci50.loc[start_date:end_date, :].index, cci50.loc[start_date:end_date, 'CCI'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Chakin Volatility Indicator (30,40,50)

# %%
def chaikin_oscillator(data, periods_short=3, periods_long=30, high_col='High',
                       low_col='Low', close_col='Close', vol_col='Volume'):
    ac = pd.Series([])

    for index, row in data.iterrows():
        if row[high_col] != row[low_col]:
            val = ((row[close_col] - row[low_col]) - (row[high_col] - row[close_col])) / (row[high_col] - row[low_col]) * row[vol_col]
        else:
            val = 0
        ac.set_value(index, val)

    ema_long = ac.ewm(ignore_na=False, min_periods=0, com=periods_long, adjust=True).mean()
    ema_short = ac.ewm(ignore_na=False, min_periods=0, com=periods_short, adjust=True).mean()
    data['ch_osc'] = ema_short - ema_long

    return data

# %%
ch30=chaikin_oscillator(df,3,30)
ch40=chaikin_oscillator(df,3,40)
ch50=chaikin_oscillator(df,3,50)

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ch30.loc[start_date:end_date, :].index, ch30.loc[start_date:end_date, 'ch_osc'], label = 'For 30 days')
ax.plot(ch40.loc[start_date:end_date, :].index, ch40.loc[start_date:end_date, 'ch_osc'], label = 'For 40 days')
ax.plot(ch50.loc[start_date:end_date, :].index, ch50.loc[start_date:end_date, 'ch_osc'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')

#overlapped each other
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Rate of Price Change (30,40,50)

# %%
def ROC(data,n):
 N = data['Close'].diff(n)
 D = data['Close'].shift(n)
 ROC = pd.Series(N/D,name='ROC')
 data = data.join(ROC)
 return data

# %%
roc30=ROC(df,30)
roc40=ROC(df,40)
roc50=ROC(df,50)

# %%
roc30
# Out:
#                    Open         High          Low    Adj Close     Volume  \
# Date
# 2013-04-04   418.200012   418.200012   402.049988   393.355682  2162736.0
# 2013-04-05   404.100006   405.299988   398.149994   389.180817  1357287.0
# 2013-04-08   400.600006   406.799988   392.600006   382.044769  1898773.0
# 2013-04-09   397.899994   402.299988   388.500000   378.889404  1325954.0
# 2013-04-10   390.950012   393.149994   383.049988   375.879639  2785331.0
# 2013-04-11   392.000000   404.149994   388.500000   389.520630  2565069.0
# 2013-04-12   398.000000   403.899994   393.700012   388.889557  2765801.0
# 2013-04-15   404.200012   408.500000   400.000000   390.248779  1300962.0
# 2013-04-16   404.850006   421.899994   403.500000   405.103394  2561442.0
# 2013-04-17   422.700012   423.750000   410.250000   407.384979  1071016.0
# 2013-04-18   423.000000   456.000000   417.200012   437.239807  5512207.0
# 2013-04-22   450.350006   471.899994   450.350006   452.822540  4233365.0
# 2013-04-23   467.500000   467.500000   450.600006   447.725403  2117529.0
# 2013-04-25   461.149994   478.500000   460.950012   454.230408  3011657.0
# 2013-04-26   467.450012   467.450012   453.000000   444.812714  2336599.0
# 2013-04-29   457.500000   484.200012   448.700012   463.793671  2814078.0
# 2013-04-30   479.000000   480.000000   466.100006   454.133301  1179396.0
# 2013-05-02   467.750000   476.700012   465.000000   459.036255  1157355.0
# 2013-05-03   473.200012   476.399994   457.850006   454.424500  1386740.0
# 2013-05-06   465.500000   476.549988   456.649994   460.686798  1621140.0
# 2013-05-07   476.500000   494.649994   473.100006   470.783966  2141462.0
# 2013-05-08   484.500000   495.000000   483.950012   478.842377  2039165.0
...         NaN       NaN       NaN       NaN       NaN
# 2013-05-20    ...         NaN       NaN       NaN       NaN       NaN
# ...           ...         ...       ...       ...       ...       ...
# 2018-04-04    ...     1708.67  1761.996  1655.344  1711.841  1762.273
# 2018-04-05    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-06    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-09    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-10    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-11    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-12    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-13    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-16    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-17    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-18    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-19    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-20    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-23    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-24    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-25    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-26    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-27    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-30    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-02    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-03    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-04    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-07    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-08    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-09    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-10    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-11    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-14    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-15    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-16    ...         NaN       NaN       NaN       NaN       NaN
#
#              lower50         %K         %D         ch_osc       ROC
# Date
# 2013-04-04       NaN        NaN        NaN       0.000000       NaN
# 2013-04-05       NaN        NaN        NaN   66495.465181       NaN
# 2013-04-08       NaN        NaN        NaN  -39080.613889       NaN
# 2013-04-09       NaN        NaN        NaN  -11786.538804       NaN
# 2013-04-10       NaN        NaN        NaN   58544.222148       NaN
# 2013-04-11       NaN        NaN        NaN  371435.311018       NaN
# 2013-04-12       NaN        NaN        NaN  464904.187984       NaN
# 2013-04-15       NaN        NaN        NaN  276611.625185       NaN
# 2013-04-16       NaN        NaN        NaN  444401.977486       NaN
# 2013-04-17       NaN        NaN        NaN  414970.294851       NaN
# 2013-04-18       NaN        NaN        NaN  949936.417028       NaN
# 2013-04-22       NaN        NaN        NaN  996624.370070       NaN
# 2013-04-23       NaN        NaN        NaN  750651.820093       NaN
# 2013-04-25       NaN  88.842334        NaN  365208.472191       NaN
# 2013-04-26       NaN  78.679934        NaN   85518.688319       NaN
# 2013-04-29       NaN  93.573902  87.032056  330522.510914       NaN
# 2013-04-30       NaN  83.737016  85.330284    6914.577005       NaN
# 2013-05-02       NaN  88.729588  88.680169   17053.776304       NaN
# 2013-05-03       NaN  83.124324  85.196976  -22635.223147       NaN
# 2013-05-06       NaN  89.281755  87.045222  168683.940855       NaN
# 2013-05-07       NaN  89.698890  87.368323   93806.051677       NaN
# 2013-05-08       NaN  98.032800  92.337815  267553.384426       NaN
# 2013-05-09       NaN  92.802353  93.511348  -71859.518533       NaN
# 2013-05-10       NaN  95.828812  95.554655  199772.159398       NaN
# 2013-05-13       NaN  73.108537  87.246567 -218990.659753       NaN
# 2013-05-14       NaN  68.421027  79.119459 -282365.976347       NaN
# 2013-05-15       NaN  96.386412  79.305325   68306.764838       NaN
# 2013-05-16       NaN  96.501271  87.102903  253969.074491       NaN
# 2013-05-17       NaN  79.389330  90.759004  -57542.279299       NaN
# 2013-05-20       NaN  63.906579  79.932393 -310156.440783       NaN
# ...              ...        ...        ...            ...       ...
# 2018-04-04  1661.409  69.913744  85.576585  144891.774289  0.084665
# 2018-04-05       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-06       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-09       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-10       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-11       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-12       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-13       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-16       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-17       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-18       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-19       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-20       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-23       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-24       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-25       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-26       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-27       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-30       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-02       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-03       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-04       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-07       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-08       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-09       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-10       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-11       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-14       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-15       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-16       NaN        NaN        NaN  144891.774289       NaN
#
# [1261 rows x 24 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(roc30.loc[start_date:end_date, :].index, roc30.loc[start_date:end_date, 'ROC'], label = 'For 30 days')
ax.plot(roc40.loc[start_date:end_date, :].index, roc40.loc[start_date:end_date, 'ROC'], label = 'For 40 days')
ax.plot(roc50.loc[start_date:end_date, :].index, roc50.loc[start_date:end_date, 'ROC'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Rate of Volume Change (30,40,50)

# %%
def ROC(data,n):
 N = data['Volume'].diff(n)
 D = data['Volume'].shift(n)
 ROC = pd.Series(N/D,name='ROC')
 data = data.join(ROC)
 return data

# %%
roc30=ROC(df,30)
roc40=ROC(df,40)
roc50=ROC(df,50)

# %%
roc30
# Out:
#                    Open         High          Low    Adj Close     Volume  \
# Date
# 
...         NaN       NaN       NaN       NaN       NaN
# 2013-05-17    ...         NaN       NaN       NaN       NaN       NaN
# 2013-05-20    ...         NaN       NaN       NaN       NaN       NaN
# ...           ...         ...       ...       ...       ...       ...
# 2018-04-04    ...     1708.67  1761.996  1655.344  1711.841  1762.273
# 2018-04-05    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-06    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-09    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-10    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-11    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-12    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-13    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-16    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-17    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-18    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-19    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-20    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-23    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-24    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-25    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-26    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-27    ...         NaN       NaN       NaN       NaN       NaN
# 2018-04-30    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-02    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-03    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-04    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-07    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-08    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-09    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-10    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-11    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-14    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-15    ...         NaN       NaN       NaN       NaN       NaN
# 2018-05-16    ...         NaN       NaN       NaN       NaN       NaN
#
#              lower50         %K         %D         ch_osc       ROC
# Date
# 2013-04-04       NaN        NaN        NaN       0.000000       NaN
# 2013-04-05       NaN        NaN        NaN   66495.465181       NaN
# 2013-04-08       NaN        NaN        NaN  -39080.613889       NaN
# 2013-04-09       NaN        NaN        NaN  -11786.538804       NaN
# 2013-04-10       NaN        NaN        NaN   58544.222148       NaN
# 2013-04-11       NaN        NaN        NaN  371435.311018       NaN
# 2013-04-12       NaN        NaN        NaN  464904.187984       NaN
# 2013-04-15       NaN        NaN        NaN  276611.625185       NaN
# 2013-04-16       NaN        NaN        NaN  444401.977486       NaN
# 2013-04-17       NaN        NaN        NaN  414970.294851       NaN
# 2013-04-18       NaN        NaN        NaN  949936.417028       NaN
# 2013-04-22       NaN        NaN        NaN  996624.370070       NaN
# 2013-04-23       NaN        NaN        NaN  750651.820093       NaN
# 2013-04-25       NaN  88.842334        NaN  365208.472191       NaN
# 2013-04-26       NaN  78.679934        NaN   85518.688319       NaN
# 2013-04-29       NaN  93.573902  87.032056  330522.510914       NaN
# 2013-04-30       NaN  83.737016  85.330284    6914.577005       NaN
# 2013-05-02       NaN  88.729588  88.680169   17053.776304       NaN
# 2013-05-03       NaN  83.124324  85.196976  -22635.223147       NaN
# 2013-05-06       NaN  89.281755  87.045222  168683.940855       NaN
# 2013-05-07       NaN  89.698890  87.368323   93806.051677       NaN
# 2013-05-08       NaN  98.032800  92.337815  267553.384426       NaN
# 2013-05-09       NaN  92.802353  93.511348  -71859.518533       NaN
# 2013-05-10       NaN  95.828812  95.554655  199772.159398       NaN
# 2013-05-13       NaN  73.108537  87.246567 -218990.659753       NaN
# 2013-05-14       NaN  68.421027  79.119459 -282365.976347       NaN
# 2013-05-15       NaN  96.386412  79.305325   68306.764838       NaN
# 2013-05-16       NaN  96.501271  87.102903  253969.074491       NaN
# 2013-05-17       NaN  79.389330  90.759004  -57542.279299       NaN
# 2013-05-20       NaN  63.906579  79.932393 -310156.440783       NaN
# ...              ...        ...        ...            ...       ...
# 2018-04-04  1661.409  69.913744  85.576585  144891.774289 -0.326958
# 2018-04-05       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-06       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-09       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-10       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-11       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-12       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-13       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-16       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-17       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-18       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-19       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-20       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-23       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-24       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-25       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-26       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-27       NaN        NaN        NaN  144891.774289       NaN
# 2018-04-30       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-02       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-03       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-04       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-07       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-08       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-09       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-10       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-11       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-14       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-15       NaN        NaN        NaN  144891.774289       NaN
# 2018-05-16       NaN        NaN        NaN  144891.774289       NaN
#
# [1261 rows x 24 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(roc30.loc[start_date:end_date, :].index, roc30.loc[start_date:end_date, 'ROC'], label = 'For 30 days')
ax.plot(roc40.loc[start_date:end_date, :].index, roc40.loc[start_date:end_date, 'ROC'], label = 'For 40 days')
ax.plot(roc50.loc[start_date:end_date, :].index, roc50.loc[start_date:end_date, 'ROC'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')
