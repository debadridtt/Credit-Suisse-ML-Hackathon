dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
df1['Date']=pd.to_datetime(df1['Date'])

# %%
df1.isnull().sum()
# Out:
# Date         0
# Open         2
# High         2
# Low          2
# Close        2
# Adj Close    2
# Volume       2
# dtype: int64

# %%
df1.fillna(df1.mean(),inplace=True)

# %%
close_zero=df1.iloc[-1].Close

# %%
df1['HL_PCT'] = (df1['High'] - df1['Low'])/(df1['Low']*100)

# %%
df1['PCT_CHNG_OpCl'] = (df1['Close'] - df1['Open'])/(df1['Open']*100)

# %%
df1['PCT_CHNG_CLOSE'] = (df1['Close'] - df1['Adj Close'])/(df1['Adj Close']*100)

# %%
df1.index=df1['Date']

# %%
df1.head()
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2013-04-04 2013-04-04  185.227005  186.000000  182.291000  183.417999
# 2013-04-05 2013-04-05  183.417999  183.417999  179.091003  181.481995
# 2013-04-08 2013-04-08  180.854996  182.744995  179.509003  179.835999
# 2013-04-09 2013-04-09  181.190994  185.408997  178.764008  180.009003
# 2013-04-10 2013-04-10  181.373001  183.145004  178.490997  182.600006
#
#              Adj Close      Volume    HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE
# Date
# 2013-04-04  131.441833  18866172.0  0.000203      -0.000098        0.003954
# 2013-04-05  130.054443  28818724.0  0.000242      -0.000106        0.003954
# 2013-04-08  128.874863  12105429.0  0.000180      -0.000056        0.003954
# 2013-04-09  128.998840  20901188.0  0.000372      -0.000065        0.003954
# 2013-04-10  130.855637  22694012.0  0.000261       0.000068        0.003954

# %%
df=df1[['Open','High','Low','Adj Close','Volume','HL_PCT','PCT_CHNG_OpCl','PCT_CHNG_CLOSE','Close']]

# %% [markdown]
# ## Prediction for 30th Day

# %%
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
import datetime
# Out:
# C:\Users\Debadri\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df['Close'].plot(figsize=(15,6), color="green")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.tail()
# Out:
#                   Open        High         Low   Adj Close      Volume  \
# Date
# 2018-03-27  284.500000  287.299988  281.399994  283.899994  22377328.0
# 2018-03-28  283.000000  283.299988  277.100006  278.350006  27172599.0
# 2018-04-02  278.350006  278.350006  258.799988  261.850006  73359584.0
# 2018-04-03  261.399994  271.500000  261.399994  270.049988  40773239.0
# 2018-04-04  267.250000  273.299988  265.500000  268.649994  33486876.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close
# Date
# 2018-03-27  0.000210      -0.000021             0.0  283.899994
# 2018-03-28  0.000224      -0.000164             0.0  278.350006
# 2018-04-02  0.000755      -0.000593             0.0  261.850006
# 2018-04-03  0.000386       0.000331             0.0  270.049988
# 2018-04-04  0.000294       0.000052             0.0  268.649994

# %%
forecast_col = 'Close'

forecast_out = int(42)
# We will drop 12 columns because there are 12 holidays

# %%
df['label'] = df[forecast_col].shift(-forecast_out)
print(df.head(2))
# Out:
#                   Open        High         Low   Adj Close      Volume  \
# Date
# 2013-04-04  185.227005  186.000000  182.291000  131.441833  18866172.0
# 2013-04-05  183.417999  183.417999  179.091003  130.054443  28818724.0
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close       label
# Date
# 2013-04-04  0.000203      -0.000098        0.003954  183.417999  209.927002
# 2013-04-05  0.000242      -0.000106        0.003954  181.481995  207.582001

# %%
X = np.array(df.drop(['label'], 1))

# %%
X = preprocessing.scale(X)

# %%
X_forecast_out = X[-forecast_out:]
X = X[:-forecast_out]

# %%
y = np.array(df['label'])
y = y[:-forecast_out]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
clf = LinearRegression()
clf.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("Accuracy of our prediction model",clf.score(X_test, y_test)*100,"%")
# Out:
# Accuracy of our prediction model 67.93122432792215 %

# %%
# Taking first 30 values since 12 days are holidays

forecast_prediction = clf.predict(X_forecast_out)
print(forecast_prediction[:30])
# Out:
# [333.67099354 332.84991051 324.95767988 322.29386101 294.81998367
#  324.5261373  321.25623456 318.5406477  318.93831055 310.37399641
#  317.21079918 307.93433109 306.47768894 312.57457359 313.88706077
#  315.18359611 314.96856293 319.86888453 314.77140718 310.60425216
#  301.76004098 299.30935565 290.73226574 290.14116429 291.68230636
#  290.51090956 293.82019847 299.69731346 296.0267866  301.36613169]

# %%
df['forecast'] = np.nan
last_date = df.iloc[-1].name
last_unix = last_date.timestamp()
one_day = 86400
next_unix = last_unix + one_day

for i in forecast_prediction:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += 86400
    df.loc[next_date] = [np.nan for _ in range(len(df.columns)-1)]+[i]

# %%
df
# Out:
#                            Open        High         Low   Adj Close  \
# Date
# 2013-04-04 00:00:00  185.227005  186.000000  182.291000  131.441833
# 2013-04-05 00:00:00  183.417999  183.417999  179.091003  130.054443
# 2013-04-08 00:00:00  180.854996  182.744995  179.509003  128.874863
# 2013-04-09 00:00:00  181.190994  185.408997  178.764008  128.998840
# 2013-04-10 00:00:00  181.373001  183.145004  178.490997  130.855637
# 2013-04-11 00:00:00  186.345001  190.727005  186.227005  135.533035
# 2013-04-12 00:00:00  187.473007  191.072998  186.600006  136.204514
# 2013-04-15 00:00:00  188.636002  194.345001  187.544998  136.432419
# 2013-04-16 00:00:00  190.000000  197.272995  189.891006  140.575928
# 2013-04-17 00:00:00  196.563995  202.100006  196.563995  143.018890
# 2013-04-18 00:00:00  196.727005  204.945007  196.727005  146.275955
# 2013-04-22 00:00:00  204.117996  210.854996  202.990997  149.637634
# 2013-04-23 00:00:00  209.091003  211.800003  204.481995  151.311691
# 2013-04-25 00:00:00  211.145004  216.000000  211.145004  153.403503
# 2013-04-26 00:00:00  213.182007  216.145004  204.544998  149.123108
# 2013-04-29 00:00:00  209.108994  210.908997  206.091003  150.256805
# 2013-04-30 00:00:00  210.455002  213.091003  207.654999  151.618393
# 2013-05-02 00:00:00  211.572998  215.817993  210.908997  152.666824
# 2013-05-03 00:00:00  212.300003  212.727005  203.981995  147.226898
# 2013-05-06 00:00:00  205.000000  208.908997  201.682007  148.882309
# 2013-05-07 00:00:00  207.817993  213.091003  207.636002  151.657104
# 2013-05-08 00:00:00  212.727005  213.781998  208.291000  150.875244
# 2013-05-09 00:00:00  210.908997  211.845001  207.964005  150.185135
# 2013-05-10 00:00:00  209.636002  212.709000  209.154999  151.839828
# 2013-05-13 00:00:00  211.091003  213.908997  208.227005  149.683487
# 2013-05-14 00:00:00  209.636002  212.100006  207.617996  149.507202
# 2013-05-15 00:00:00  209.626999  217.964005  209.455002  155.214417
# 2013-05-16 00:00:00  215.455002  221.636002  215.417999  157.331329
# 2013-05-17 00:00:00  219.108994  224.891006  218.735992  160.321793
# 2013-05-20 00:00:00  223.445007  224.436005  218.835999  157.631577
# ...                         ...         ...         ...         ...
# 2018-04-17 05:30:00         NaN         NaN         NaN         NaN
# 2018-04-18 05:30:00         NaN         NaN         NaN         NaN
# 2018-04-19 05:30:00         NaN         NaN         NaN         NaN
# 2018-04-20 05:30:00         NaN         NaN         NaN         NaN
# 2018-04
05:30:00         NaN       NaN            NaN             NaN
# 2018-05-15 05:30:00         NaN       NaN            NaN             NaN
# 2018-05-16 05:30:00         NaN       NaN            NaN             NaN
#
#                           Close       label    forecast
# Date
# 2013-04-04 00:00:00  183.417999  209.927002         NaN
# 2013-04-05 00:00:00  181.481995  207.582001         NaN
# 2013-04-08 00:00:00  179.835999  203.235992         NaN
# 2013-04-09 00:00:00  180.009003  195.727005         NaN
# 2013-04-10 00:00:00  182.600006  196.591003         NaN
# 2013-04-11 00:00:00  189.126999  194.335999         NaN
# 2013-04-12 00:00:00  190.063995  200.391006         NaN
# 2013-04-15 00:00:00  190.382004  200.264008         NaN
# 2013-04-16 00:00:00  196.164001  198.354996         NaN
# 2013-04-17 00:00:00  199.572998  197.582001         NaN
# 2013-04-18 00:00:00  204.117996  190.209000         NaN
# 2013-04-22 00:00:00  208.809006  189.973007         NaN
# 2013-04-23 00:00:00  211.145004  190.755005         NaN
# 2013-04-25 00:00:00  214.063995  187.791000         NaN
# 2013-04-26 00:00:00  208.091003  186.572998         NaN
# 2013-04-29 00:00:00  209.673004  187.373001         NaN
# 2013-04-30 00:00:00  211.572998  194.682007         NaN
# 2013-05-02 00:00:00  213.035995  194.164001         NaN
# 2013-05-03 00:00:00  205.445007  196.199997         NaN
# 2013-05-06 00:00:00  207.755005  193.455002         NaN
# 2013-05-07 00:00:00  211.626999  193.399994         NaN
# 2013-05-08 00:00:00  210.535995  191.190994         NaN
# 2013-05-09 00:00:00  209.572998  186.899994         NaN
# 2013-05-10 00:00:00  211.882004  188.063995         NaN
# 2013-05-13 00:00:00  208.873001  188.826996         NaN
# 2013-05-14 00:00:00  208.626999  192.354996         NaN
# 2013-05-15 00:00:00  216.591003  192.800003         NaN
# 2013-05-16 00:00:00  219.544998  192.917999         NaN
# 2013-05-17 00:00:00  223.718002  182.445007         NaN
# 2013-05-20 00:00:00  219.964005  178.227005         NaN
# ...                         ...         ...         ...
# 2018-04-17 05:30:00         NaN         NaN  306.477689
# 2018-04-18 05:30:00         NaN         NaN  312.574574
# 2018-04-19 05:30:00         NaN         NaN  313.887061
# 2018-04-20 05:30:00         NaN         NaN  315.183596
# 2018-04-21 05:30:00         NaN         NaN  314.968563
# 2018-04-22 05:30:00         NaN         NaN  319.868885
# 2018-04-23 05:30:00         NaN         NaN  314.771407
# 2018-04-24 05:30:00         NaN         NaN  310.604252
# 2018-04-25 05:30:00         NaN         NaN  301.760041
# 2018-04-26 05:30:00         NaN         NaN  299.309356
# 2018-04-27 05:30:00         NaN         NaN  290.732266
# 2018-04-28 05:30:00         NaN         NaN  290.141164
# 2018-04-29 05:30:00         NaN         NaN  291.682306
# 2018-04-30 05:30:00         NaN         NaN  290.510910
# 2018-05-01 05:30:00         NaN         NaN  293.820198
# 2018-05-02 05:30:00         NaN         NaN  299.697313
# 2018-05-03 05:30:00         NaN         NaN  296.026787
# 2018-05-04 05:30:00         NaN         NaN  301.366132
# 2018-05-05 05:30:00         NaN         NaN  302.639098
# 2018-05-06 05:30:00         NaN         NaN  291.305550
# 2018-05-07 05:30:00         NaN         NaN  291.259847
# 2018-05-08 05:30:00         NaN         NaN  288.873333
# 2018-05-09 05:30:00         NaN         NaN  285.103363
# 2018-05-10 05:30:00         NaN         NaN  283.613442
# 2018-05-04 05:30:00            NaN             NaN    NaN    NaN  301.366132
# 2018-05-05 05:30:00            NaN             NaN    NaN    NaN  302.639098
# 2018-05-06 05:30:00            NaN             NaN    NaN    NaN  291.305550
# 2018-05-07 05:30:00            NaN             NaN    NaN    NaN  291.259847
# 2018-05-08 05:30:00            NaN             NaN    NaN    NaN  288.873333
# 2018-05-09 05:30:00            NaN             NaN    NaN    NaN  285.103363
# 2018-05-10 05:30:00            NaN             NaN    NaN    NaN  283.613442
# 2018-05-11 05:30:00            NaN             NaN    NaN    NaN  282.767185
# 2018-05-12 05:30:00            NaN             NaN    NaN    NaN  287.176028
# 2018-05-13 05:30:00            NaN             NaN    NaN    NaN  284.219034
# 2018-05-14 05:30:00            NaN             NaN    NaN    NaN  271.631263
# 2018-05-15 05:30:00            NaN             NaN    NaN    NaN  273.367126
# 2018-05-16 05:30:00            NaN             NaN    NaN    NaN  275.490106

# %%
pred=pred.reset_index()

# %%
pred['Date']=pred['Date'].dt.date

# %%
pred.head(1)
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#    PCT_CHNG_CLOSE  Close  label    forecast
# 0             NaN    NaN    NaN  333.670994

# %%
holidays=['2018-04-07','2018-04-08','2018-04-14','2018-04-15','2018-04-21','2018-04-22','2018-04-28','2018-04-29','2018-05-01','2018-05-05','2018-05-06','2018-05-12','2018-05-13']

# %%
pred['Date']=pred['Date'].apply(str)

# %%
for i in holidays:
    pred = pred.drop(pred[pred.Date==i].index)

# %%
pred['Date']=pd.to_datetime(pred['Date'])

# %%
pred.drop('forecast',axis=1,inplace=True)

# %%
pred.shape
# Out:
# (29, 11)

# %%
pred['forecast']=forecast_prediction[:29]

# %%
pred
# Out:
#          Date  Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# 0  2018-04-05   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 1  2018-04-06   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 4  2018-04-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 5  2018-04-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 6  2018-04-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 7  2018-04-12   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 8  2018-04-13   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 11 2018-04-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 12 2018-04-17   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 13 2018-04-18   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 14 2018-04-19   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 15 2018-04-20   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 18 2018-04-23   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 19 2018-04-24   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 20 2018-04-25   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 21 2018-04-26   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 22 2018-04-27   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 25 2018-04-30   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 27 2018-05-02   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 28 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 29 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 32 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 33 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 34 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 35 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 36 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 39 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 40 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 41 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#     PCT_CHNG_CLOSE  Close  label    forecast
# 0              NaN    NaN    NaN  333.670994
# 1              NaN    NaN    NaN  332.849911
# 4              NaN    NaN    NaN  324.957680
# 5              NaN    NaN    NaN  322.293861
# 6              NaN    NaN    NaN  294.819984
# 7              NaN    NaN    NaN  324.526137
# 8              NaN    NaN    NaN  321.256235
# 11             NaN    NaN    NaN  318.540648
# 12             NaN    NaN    NaN  318.938311
# 13             NaN    NaN    NaN  310.373996
# 14             NaN    NaN    NaN  317.210799
# 15             NaN    NaN    NaN  307.934331
# 18             NaN    NaN    NaN  306.477689
# 19             NaN    NaN    NaN  312.574574
# 20             NaN    NaN    NaN  313.887061
# 21             NaN    NaN    NaN  315.183596
# 22             NaN    NaN    NaN  314.968563
# 25             NaN    NaN    NaN  319.868885
# 27             NaN    NaN    NaN  314.771407
# 28             NaN    NaN    NaN  310.604252
# 29             NaN    NaN    NaN  301.760041
# 32             NaN    NaN    NaN  299.309356
# 33             NaN    NaN    NaN  290.732266
# 34             NaN    NaN    NaN  290.141164
# 35             NaN    NaN    NaN  291.682306
# 36             NaN    NaN    NaN  290.510910
# 39             NaN    NaN    NaN  293.820198
# 40             NaN    NaN    NaN  299.697313
# 41             NaN    NaN    NaN  296.026787

# %%
pred.index=pred['Date']
pred.drop('Date',axis=1,inplace=True)

# %%
df=df.append(pred)

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df['Close'].plot(figsize=(15,6), color="green")
df['forecast'].plot(figsize=(15,6), color="orange")
plt.xlim(xmin=datetime.date(2018, 4, 4))
plt.ylim(ymin=-100)
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df.iloc[-1]
# Out:
# Open                     NaN
# High                     NaN
# Low                      NaN
# Adj Close                NaN
# Volume                   NaN
# HL_PCT                   NaN
# PCT_CHNG_OpCl            NaN
# PCT_CHNG_CLOSE           NaN
# Close                    NaN
# label                    NaN
# forecast          296.026787
# Name: 2018-05-16 00:00:00, dtype: float64

# %%
close_last=df.iloc[-1].forecast

# %%
pred_return=close_last-close_zero
print("Predicted Return: Rs.",pred_return)
# Out:
# Predicted Return: Rs. 27.376792602861997

# %% [markdown]
# ## Simple Moving Average (30,40,50)

# %%
# For 30 days
short_rolling = df.rolling(window=30).mean()
short_rolling.head(30)
# Out:
#                   Open        High         Low   Adj Close        Volume  \
# Date
# 2013-04-04         NaN         NaN         NaN         NaN           NaN
# 2013-04-05         NaN         NaN         NaN         NaN           NaN
# 2013-04-08         NaN         NaN         NaN         NaN           NaN
# 2013-04-09         NaN         NaN         NaN         NaN           NaN
# 2013-04-10         NaN         NaN         NaN         NaN           NaN
# 2013-04-11         NaN         NaN         NaN         NaN           NaN
# 2013-04-12         NaN         NaN         NaN         NaN           NaN
# 2013-04-15         NaN         NaN         NaN         NaN           NaN
# 2013-04-16         NaN         NaN         NaN         NaN           NaN
# 2013-04-17         NaN         NaN         NaN         NaN           NaN
# 2013-04-18         NaN         NaN         NaN         NaN           NaN
# 2013-04-22         NaN         NaN         NaN         NaN           NaN
# 2013-04-23         NaN         NaN         NaN         NaN           NaN
# 2013-04-25         NaN         NaN         NaN         NaN           NaN
# 2013-04-26         NaN         NaN         NaN         NaN           NaN
# 2013-04-29         NaN         NaN         NaN         NaN           NaN
# 2013-04-30         NaN         NaN         NaN         NaN           NaN
# 2013-05-02         NaN         NaN         NaN         NaN           NaN
# 2013-05-03         NaN         NaN         NaN         NaN           NaN
# 2013-05-06         NaN         NaN         NaN         NaN           NaN
# 2013-05-07         NaN         NaN         NaN         NaN           NaN
# 2013-05-08         NaN         NaN         NaN         NaN           NaN
# 2013-05-09         NaN         NaN         NaN         NaN           NaN
# 2013-05-10         NaN         NaN         NaN         NaN           NaN
# 2013-05-13         NaN         NaN         NaN         NaN           NaN
# 2013-05-14         NaN         NaN         NaN         NaN           NaN
# 2013-05-15         NaN         NaN         NaN         NaN           NaN
# 2013-05-16         NaN         NaN         NaN         NaN           NaN
# 2013-05-17         NaN         NaN         NaN         NaN           NaN
# 2013-05-20  202.441167  206.126568  200.217267  145.888021  1.922886e+07
#
#               HL_PCT  PCT_CHNG_OpCl  PCT_CHNG_CLOSE       Close       label  \
# Date
# 2013-04-04       NaN            NaN             NaN         NaN         NaN
# 2013-04-05       NaN            NaN             NaN         NaN         NaN
# 2013-04-08       NaN            NaN             NaN         NaN         NaN
# 2013-04-09       NaN            NaN             NaN         NaN         NaN
# 2013-04-10       NaN            NaN             NaN         NaN         NaN
# 2013-04-11       NaN            NaN             NaN         NaN         NaN
# 2013-04-12       NaN            NaN             NaN         NaN         NaN
# 2013-04-15       NaN            NaN             NaN         NaN         NaN
# 2013-04-16       NaN            NaN             NaN         NaN         NaN
# 2013-04-17       NaN            NaN             NaN         NaN         NaN
# 2013-04-18       NaN            NaN             NaN         NaN         NaN
# 2013-04-22       NaN            NaN             NaN         NaN         NaN
# 2013-04-23       NaN            NaN             NaN         NaN         NaN
# 2013-04-25       NaN            NaN             NaN         NaN         NaN
# 2013-04-26       NaN            NaN             NaN         NaN         NaN
# 2013-04-29       NaN            NaN             NaN         NaN         NaN
# 2013-04-30       NaN            NaN             NaN         NaN         NaN
# 2013-05-02       NaN            NaN             NaN         NaN         NaN
# 2013-05-03       NaN            NaN             NaN         NaN         NaN
# 2013-05-06       NaN            NaN             NaN         NaN         NaN
# 2013-05-07       NaN            NaN             NaN         NaN         NaN
# 2013-05-08       NaN            NaN             NaN         NaN         NaN
# 2013-05-09       NaN            NaN             NaN         NaN         NaN
# 2013-05-10       NaN            NaN             NaN         NaN         NaN
# 2013-05-13       NaN            NaN             NaN         NaN         NaN
# 2013-05-14       NaN            NaN             NaN         NaN         NaN
# 2013-05-15       NaN            NaN             NaN         NaN         NaN
# 2013-05-16       NaN            NaN             NaN         NaN         NaN
# 2013-05-17       NaN            NaN             NaN         NaN         NaN
# 2013-05-20  0.000295       0.000057        0.003954  203.576667  193.409767
#
#             forecast
# Date
# 2013-04-04       NaN
# 2013-04-05       NaN
# 2013-04-08       NaN
# 2013-04-09       NaN
# 2013-04-10       NaN
# 2013-04-11       NaN
# 2013-04-12       NaN
# 2013-04-15       NaN
# 2013-04-16       NaN
# 2013-04-17       NaN
# 2013-04-18       NaN
# 2013-04-22       NaN
# 2013-04-23       NaN
# 2013-04-25       NaN
# 2013-04-26       NaN
# 2013-04-29       NaN
# 2013-04-30       NaN
# 2013-05-02       NaN
# 2013-05-03       NaN
# 2013-05-06       NaN
# 2013-05-07       NaN
# 2013-05-08       NaN
# 2013-05-09       NaN
# 2013-05-10       NaN
# 2013-05-13       NaN
# 2013-05-14       NaN
# 2013-05-15       NaN
# 2013-05-16       NaN
# 2013-05-17       NaN
# 2013-05-20       NaN

# %%
# For 40 days
med_rolling = df.rolling(window=40).mean()
med_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
# For 50 days
long_rolling = df.rolling(window=50).mean()
long_rolling.tail(10)
# Out:
#             Open  High  Low  Adj Close  Volume  HL_PCT  PCT_CHNG_OpCl  \
# Date
# 2018-05-03   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-04   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-07   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-08   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-09   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-10   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-11   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-14   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-15   NaN   NaN  NaN        NaN     NaN     NaN            NaN
# 2018-05-16   NaN   NaN  NaN        NaN     NaN     NaN            NaN
#
#             PCT_CHNG_CLOSE  Close  label  forecast
# Date
# 2018-05-03             NaN    NaN    NaN       NaN
# 2018-05-04             NaN    NaN    NaN       NaN
# 2018-05-07             NaN    NaN    NaN       NaN
# 2018-05-08             NaN    NaN    NaN       NaN
# 2018-05-09             NaN    NaN    NaN       NaN
# 2018-05-10             NaN    NaN    NaN       NaN
# 2018-05-11             NaN    NaN    NaN       NaN
# 2018-05-14             NaN    NaN    NaN       NaN
# 2018-05-15             NaN    NaN    NaN       NaN
# 2018-05-16             NaN    NaN    NaN       NaN

# %%
start_date = '2013-04-29'
end_date = '2018-04-04'

fig, ax = plt.subplots(figsize=(16,9))

ax.plot(long_rolling.loc[start_date:end_date, :].index, long_rolling.loc[start_date:end_date, 'Close'], label = '50-days SMA')
ax.plot(med_rolling.loc[start_date:end_date, :].index, med_rolling.loc[start_date:end_date, 'Close'], label = '40-days SMA')
ax.plot(short_rolling.loc[start_date:end_date, :].index, short_rolling.loc[start_date:end_date, 'Close'], label = '30-days SMA')


ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Exponential Moving Average (30,40,50)

# %%
ema_short = df.ewm(span=30, adjust=False).mean()
ema_med = df.ewm(span=40, adjust=False).mean()
ema_long = df.ewm(span=50, adjust=False).mean()

fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ema_short.loc[start_date:end_date, :].index, ema_short.loc[start_date:end_date, 'Close'], label = 'Span 30-days EMA')
ax.plot(ema_med.loc[start_date:end_date, :].index, ema_med.loc[start_date:end_date, 'Close'], label = 'Span 40-days EMA')
ax.plot(ema_long.loc[start_date:end_date, :].index, ema_long.loc[start_date:end_date, 'Close'], label = 'Span 50-days EMA')

ax.legend(loc='best')
ax.set_ylabel('Price in Rs.')
# Out:
# Text(0,0.5,'Price in Rs.')

# %% [markdown]
# ## Aroon Oscillator (30,40,50)

# %%
from pandas.stats import moments
from pandas import DataFrame

# %%
def aroon(s, n):
    up = 100 * moments.rolling_apply(s.High, n + 1, lambda x: x.argmax()) / n
    dn = 100 * moments.rolling_apply(s.Low, n + 1, lambda x: x.argmin()) / n

    return DataFrame(dict(up=up, down=dn))

# %%
ao30=aroon(df,30)
ao40=aroon(df,40)
ao50=aroon(df,50)

# %%
ao30
# Out:
#                  down   up
# Date
# 2013-04-04        NaN  NaN
# 2013-04-05        NaN  NaN
# 2013-04-08        NaN  NaN
# 2013-04-09        NaN  NaN
# 2013-04-10        NaN  NaN
# 2013-04-11        NaN  NaN
# 2013-04-12        NaN  NaN
# 2013-04-15        NaN  NaN
# 2013-04-16        NaN  NaN
# 2013-04-17        NaN  NaN
# 2013-04-18        NaN  NaN
# 2013-04-22        NaN  NaN
# 2013-04-23        NaN  NaN
# 2013-04-25        NaN  NaN
# 2013-04-26        NaN  NaN
# 2013-04-29        NaN  NaN
# 2013-04-30        NaN  NaN
# 2013-05-02        NaN  NaN
# 2013-05-03        NaN  NaN
# 2013-05-06        NaN  NaN
# 2013-05-07        NaN  NaN
# 2013-05-08        NaN  NaN
# 2013-05-09        NaN  NaN
# 2013-05-10        NaN  NaN
# 2013-05-13        NaN  NaN
# 2013-05-14        NaN  NaN
# 2013-05-15        NaN  NaN
# 2013-05-16        NaN  NaN
# 2013-05-17        NaN  NaN
# 2013-05-20        NaN  NaN
# ...               ...  ...
# 2018-04-04  93.333333  0.0
# 2018-04-05        NaN  NaN
# 2018-04-06        NaN  NaN
# 2018-04-09        NaN  NaN
# 2018-04-10        NaN  NaN
# 2018-04-11        NaN  NaN
# 2018-04-12        NaN  NaN
# 2018-04-13        NaN  NaN
# 2018-04-16        NaN  NaN
# 2018-04-17        NaN  NaN
# 2018-04-18        NaN  NaN
# 2018-04-19        NaN  NaN
# 2018-04-20        NaN  NaN
# 2018-04-23        NaN  NaN
# 2018-04-24        NaN  NaN
# 2018-04-25        NaN  NaN
# 2018-04-26        NaN  NaN
# 2018-04-27        NaN  NaN
# 2018-04-30        NaN  NaN
# 2018-05-02        NaN  NaN
# 2018-05-03        NaN  NaN
# 2018-05-04        NaN  NaN
# 2018-05-07        NaN  NaN
# 2018-05-08        NaN  NaN
# 2018-05-09        NaN  NaN
# 2018-05-10        NaN  NaN
# 2018-05-11        NaN  NaN
# 2018-05-14        NaN  NaN
# 2018-05-15        NaN  NaN
# 2018-05-16        NaN  NaN
#
# [1261 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 30-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 30-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'down'], label = ' Down 40-days Aroon Oscillator')
ax.plot(ao30.loc[start_date:end_date, :].index, ao30.loc[start_date:end_date, 'up'], label = 'Up 40-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'down'], label = ' Down 50-days Aroon Oscillator')
ax.plot(ao50.loc[start_date:end_date, :].index, ao50.loc[start_date:end_date, 'up'], label = 'Up 50-days Aroon Oscillator')


ax.legend(loc='best')
ax.set_ylabel('Change in Price in Rs.')
# Out:
# Text(0,0.5,'Change in Price in Rs.')

# %% [markdown]
# ## MACD Signal

# %%
def ema(s, n, wilder=False):
    span = n if not wilder else 2*n - 1
    return moments.ewma(s, span=span)


def macd(s, nfast=12, nslow=26, nsig=9, percent=True):
    fast, slow = ema(s, nfast), ema(s, nslow)

    if percent:
        macd = 100*(fast / slow - 1)
    else:
        macd = fast - slow

    sig = ema(macd, nsig)
    hist = macd - sig

    return DataFrame(dict(macd=macd, signal=sig, hist=hist,
                          fast=fast, slow=slow))

# %%
m=macd(df['Close'])

# %%
m.head(1)
# Out:
#                   fast  hist  macd  signal        slow
# Date
# 2013-04-04  183.417999   0.0   0.0     0.0  183.417999

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(m.loc[start_date:end_date, :].index, m.loc[start_date:end_date, 'macd'], label = 'MACD')

ax.legend(loc='best')
ax.set_ylabel('Change ')
# Out:
# Text(0,0.5,'Change ')

# %% [markdown]
# ## Relative Strength Index (RSI)

# %%
def rsi(s, n=14):
    diff = s.diff()
    which_dn = diff < 0

    up, dn = diff, diff*0
    up[which_dn], dn[which_dn] = 0, -up[which_dn]

    emaup = ema(up, n, wilder=True)
    emadn = ema(dn, n, wilder=True)

    return 100 * emaup/(emaup + emadn)

# %%
sf=rsi(df['Close'],50)

# %%
sfd=pd.DataFrame({'Date':sf.index, 'RSI':sf.values})

# %%
sfd.index=sfd['Date']

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(sfd.loc[start_date:end_date, :].index, sfd.loc[start_date:end_date, 'RSI'], label = 'RSI')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Bollinger Bands (30,40,50)

# %%
price=df["Close"]

def bbands(price, length=30, numsd=2):
    """ returns average, upper band, and lower band"""
    ave = pd.stats.moments.rolling_mean(price,length)
    sd = pd.stats.moments.rolling_std(price,length)
    upband = ave + (sd*numsd)
    dnband = ave - (sd*numsd)
    return np.round(ave,3), np.round(upband,3), np.round(dnband,3)

df['ave30'], df['upper30'], df['lower30'] = bbands(df.Close, length=30, numsd=1)
df['ave40'], df['upper40'], df['lower40'] = bbands(df.Close, length=40, numsd=1)
df['ave50'], df['upper50'], df['lower50'] = bbands(df.Close, length=50, numsd=1)

# %%
# For 30 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave30'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower30'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper30'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 40 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave40'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower40'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper40'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %%
# For 50 days
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'ave50'], label = 'Average')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'lower50'], label = 'Lower Band')
ax.plot(df.loc[start_date:end_date, :].index, df.loc[start_date:end_date, 'upper50'], label = 'Upper Band')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Stochastic Oscillator

# %%
def STOK(close, low, high, n): 
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 return STOK

def STOD(close, low, high, n):
 STOK = ((close - pd.rolling_min(low, n)) / (pd.rolling_max(high, n) - pd.rolling_min(low, n))) * 100
 STOD = pd.rolling_mean(STOK, 3)
 return STOD

# %%
df['%K'] = STOK(df['Close'], df['Low'], df['High'], 14)
df['%D'] = STOD(df['Close'], df['Low'], df['High'], 14)

# %%
df.plot(y=['Close'], figsize = (20, 5))
df.plot(y=['%K', '%D'], figsize = (20, 5))

# %% [markdown]
# ## Chande Oscillator

# %%
def avg_true_range(df): 
  ind = range(0,len(df))
  indexlist = list(ind)
  df.index = indexlist

  for index, row in df.iterrows():
    if index != 0:
      tr1 = row["High"] - row["Low"]
      tr2 = abs(row["High"] - df.iloc[index-1]["Close"])
      tr3 = abs(row["Low"] - df.iloc[index-1]["Close"])

      true_range = max(tr1, tr2, tr3)
      df.set_value(index,"True Range", true_range)

  df["Avg TR"] = df["True Range"].rolling(min_periods=14, window=14, center=False).mean()
  return df

# %%
def chandelier_exit(df):

  df_tr = avg_true_range(df)

  df_tr['rolling_high']= df_tr["High"]
  df_tr['rolling_low'] = df_tr["Low"]

  df_tr['chandelier_long'] = df_tr['rolling_high'] - df_tr["Avg TR"] * 3
  df_tr['chandelier_short'] = df_tr['rolling_low'] - df_tr["Avg TR"] * 3
  fig, ax = plt.subplots(figsize=(15,9))

  ax.plot(df_tr['Date'], df_tr['chandelier_long'], label = 'Chand Long')

# %%
ch=chandelier_exit(df1)

# %% [markdown]
# ## Commodity Channel Index (30,40,50)

# %%
def CCI(data, ndays): 
 TP = (data['High'] + data['Low'] + data['Close']) / 3 
 CCI = pd.Series((TP - pd.rolling_mean(TP, ndays)) / (0.015 * pd.rolling_std(TP, ndays)),
 name = 'CCI')
 data=data.join(CCI)
 return data

# %%
cci30=CCI(df,30)
cci40=CCI(df,40)
cci50=CCI(df,50)

# %%
cci30
# Out:
#                   Open        High         Low   Adj Close      Volume  \
# Date
# 2013-04-04
# 2013-05-02  0.000233       0.000069        0.003954  213.035995  194.164001
# 2013-05-03  0.000429      -0.000323        0.003954  205.445007  196.199997
# 2013-05-06  0.000358       0.000134        0.003954  207.755005  193.455002
# 2013-05-07  0.000263       0.000183        0.003954  211.626999  193.399994
# 2013-05-08  0.000264      -0.000103        0.003954  210.535995  191.190994
# 2013-05-09  0.000187      -0.000063        0.003954  209.572998  186.899994
# 2013-05-10  0.000170       0.000107        0.003954  211.882004  188.063995
# 2013-05-13  0.000273      -0.000105        0.003954  208.873001  188.826996
# 2013-05-14  0.000216      -0.000048        0.003954  208.626999  192.354996
# 2013-05-15  0.000406       0.000332        0.003954  216.591003  192.800003
# 2013-05-16  0.000289       0.000190        0.003954  219.544998  192.917999
# 2013-05-17  0.000281       0.000210        0.003954  223.718002  182.445007
# 2013-05-20  0.000256      -0.000156        0.003954  219.964005  178.227005
# ...              ...            ...             ...         ...         ...
# 2018-04-04  0.000294       0.000052        0.000000  268.649994         NaN
# 2018-04-05       NaN            NaN             NaN         NaN         NaN
# 2018-04-06       NaN            NaN             NaN         NaN         NaN
# 2018-04-09       NaN            NaN             NaN         NaN         NaN
# 2018-04-10       NaN            NaN             NaN         NaN         NaN
# 2018-04-11       NaN            NaN             NaN         NaN         NaN
# 2018-04-12       NaN            NaN             NaN         NaN         NaN
# 2018-04-13       NaN            NaN             NaN         NaN         NaN
# 2018-04-16       NaN            NaN             NaN         NaN         NaN
# 2018-04-17       NaN            NaN             NaN         NaN         NaN
# 2018-04-18       NaN            NaN             NaN         NaN         NaN
# 2018-04-19       NaN            NaN             NaN         NaN         NaN
# 2018-04-20       NaN            NaN             NaN         NaN         NaN
# 2018-04-23       NaN            NaN             NaN         NaN         NaN
# 2018-04-24       NaN            NaN             NaN         NaN         NaN
# 2018-04-25       NaN            NaN             NaN         NaN         NaN
# 2018-04-26       NaN            NaN             NaN         NaN         NaN
# 2018-04-27       NaN            NaN             NaN         NaN         NaN
# 2018-04-30       NaN            NaN             NaN         NaN         NaN
# 2018-05-02       NaN            NaN             NaN         NaN         NaN
# 2018-05-03       NaN            NaN             NaN         NaN         NaN
# 2018-05-04       NaN            NaN             NaN         NaN         NaN
# 2018-05-07       NaN            NaN             NaN         NaN         NaN
# 2018-05-08       NaN            NaN             NaN         NaN         NaN
# 2018-05-09       NaN            NaN             NaN         NaN         NaN
# 2018-05-10       NaN            NaN             NaN         NaN         NaN
# 2018-05-11       NaN            NaN             NaN         NaN         NaN
# 2018-05-14       NaN            NaN             NaN         NaN         NaN
# 2018-05-15       NaN            NaN             NaN         NaN         NaN
# 2018-05-16       NaN            NaN             NaN         NaN         NaN
#
#                ...      lower30    ave40  upper40  lower40    ave50  upper50  \
# Date           ...
# 2013-04-04     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-05     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-08     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-09     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-10     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-11     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-12     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-15     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-16     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-17     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-18     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-22     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-23     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-25     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-26     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-29     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-30     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-02     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-03     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-06     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-07     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-08     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-09     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-10     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-13     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-14     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-15     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-16     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-17     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-20     ...      190.595      NaN      NaN      NaN      NaN      NaN
# ...            ...          ...      ...      ...      ...      ...      ...
# 2018-04-04     ...      280.028  305.315   325.77   284.86  314.995  341.842
# 2018-04-05     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-06     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-09     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-10     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-11     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-12     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-13     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-16     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-17     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-18     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-19     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-20     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-23     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-24     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-25     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-26     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-27     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-30     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-02     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-03     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-04     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-07     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-08     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-09     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-10     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-11     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-14     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-15     ...          NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-16     ...          NaN      NaN      NaN      NaN      NaN      NaN
#
#             lower50         %K         %D         CCI
# Date
# 2013-04-04      NaN        NaN        NaN         NaN
# 2013-04-05      NaN        NaN        NaN         NaN
# 2013-04-08      NaN        NaN        NaN         NaN
# 2013-04-09      NaN        NaN        NaN         NaN
# 2013-04-10      NaN        NaN        NaN         NaN
# 2013-04-11      NaN        NaN        NaN         NaN
# 2013-04-12      NaN        NaN        NaN         NaN
# 2013-04-15      NaN        NaN        NaN         NaN
# 2013-04-16      NaN        NaN        NaN         NaN
# 2013-04-17      NaN        NaN        NaN         NaN
# 2013-04-18      NaN        NaN        NaN         NaN
# 2013-04-22      NaN        NaN        NaN         NaN
# 2013-04-23      NaN        NaN        NaN         NaN
# 2013-04-25      NaN  94.838559        NaN         NaN
# 2013-04-26      NaN  78.610508        NaN         NaN
# 2013-04-29      NaN  82.811922  85.420330         NaN
# 2013-04-30      NaN  87.857850  83.093427         NaN
# 2013-05-02      NaN  91.743219  87.470997         NaN
# 2013-05-03      NaN  64.235586  81.278885         NaN
# 2013-05-06      NaN  71.602642  75.860482         NaN
# 2013-05-07      NaN  84.202783  73.347004         NaN
# 2013-05-08      NaN  78.635601  78.147008         NaN
# 2013-05-09      NaN  66.436837  76.425073         NaN
# 2013-05-10      NaN  78.046142  74.372860         NaN
# 2013-05-13      NaN  49.719944  64.734307         NaN
# 2013-05-14      NaN  48.019038  58.595041         NaN
# 2013-05-15      NaN  91.567362  63.102114         NaN
# 2013-05-16      NaN  89.520875  76.369092         NaN
# 2013-05-17      NaN  94.945909  92.011382         NaN
# 2013-05-20      NaN  78.771161  87.745982   92.436233
# ...             ...        ...        ...         ...
# 2018-04-04  288.148  20.246662  16.546771 -111.368957
# 2018-04-05      NaN        NaN        NaN         NaN
# 2018-04-06      NaN        NaN        NaN         NaN
# 2018-04-09      NaN        NaN        NaN         NaN
# 2018-04-10      NaN        NaN        NaN         NaN
# 2018-04-11      NaN        NaN        NaN         NaN
# 2018-04-12      NaN        NaN        NaN         NaN
# 2018-04-13      NaN        NaN        NaN         NaN
# 2018-04-16      NaN        NaN        NaN         NaN
# 2018-04-17      NaN        NaN        NaN         NaN
# 2018-04-18      NaN        NaN        NaN         NaN
# 2018-04-19      NaN        NaN        NaN         NaN
# 2018-04-20      NaN        NaN        NaN         NaN
# 2018-04-23      NaN        NaN        NaN         NaN
# 2018-04-24      NaN        NaN        NaN         NaN
# 2018-04-25      NaN        NaN        NaN         NaN
# 2018-04-26      NaN        NaN        NaN         NaN
# 2018-04-27      NaN        NaN        NaN         NaN
# 2018-04-30      NaN        NaN        NaN         NaN
# 2018-05-02      NaN        NaN        NaN         NaN
# 2018-05-03      NaN        NaN        NaN         NaN
# 2018-05-04      NaN        NaN        NaN         NaN
# 2018-05-07      NaN        NaN        NaN         NaN
# 2018-05-08      NaN        NaN        NaN         NaN
# 2018-05-09      NaN        NaN        NaN         NaN
# 2018-05-10      NaN        NaN        NaN         NaN
# 2018-05-11      NaN        NaN        NaN         NaN
# 2018-05-14      NaN        NaN        NaN         NaN
# 2018-05-15      NaN        NaN        NaN         NaN
# 2018-05-16      NaN        NaN        NaN         NaN
#
# [1261 rows x 23 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(cci30.loc[start_date:end_date, :].index, cci30.loc[start_date:end_date, 'CCI'], label = 'For 30 days')
ax.plot(cci40.loc[start_date:end_date, :].index, cci40.loc[start_date:end_date, 'CCI'], label = 'For 40 days')
ax.plot(cci50.loc[start_date:end_date, :].index, cci50.loc[start_date:end_date, 'CCI'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Chakin Volatility Indicator (30,40,50)

# %%
def chaikin_oscillator(data, periods_short=3, periods_long=30, high_col='High',
                       low_col='Low', close_col='Close', vol_col='Volume'):
    ac = pd.Series([])

    for index, row in data.iterrows():
        if row[high_col] != row[low_col]:
            val = ((row[close_col] - row[low_col]) - (row[high_col] - row[close_col])) / (row[high_col] - row[low_col]) * row[vol_col]
        else:
            val = 0
        ac.set_value(index, val)

    ema_long = ac.ewm(ignore_na=False, min_periods=0, com=periods_long, adjust=True).mean()
    ema_short = ac.ewm(ignore_na=False, min_periods=0, com=periods_short, adjust=True).mean()
    data['ch_osc'] = ema_short - ema_long

    return data

# %%
ch30=chaikin_oscillator(df,3,30)
ch40=chaikin_oscillator(df,3,40)
ch50=chaikin_oscillator(df,3,50)

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot
# 2013-05-03  64.235586  81.278885 -4.283337e+06       NaN
# 2013-05-06  71.602642  75.860482 -2.032926e+06       NaN
# 2013-05-07  84.202783  73.347004 -7.536082e+05       NaN
# 2013-05-08  78.635601  78.147008 -1.751758e+06       NaN
# 2013-05-09  66.436837  76.425073 -2.265859e+06       NaN
# 2013-05-10  78.046142  74.372860 -1.179956e+06       NaN
# 2013-05-13  49.719944  64.734307 -3.151757e+06       NaN
# 2013-05-14  48.019038  58.595041 -4.162733e+06       NaN
# 2013-05-15  91.567362  63.102114 -8.587537e+05       NaN
# 2013-05-16  89.520875  76.369092 -1.013912e+05       NaN
# 2013-05-17  94.945909  92.011382  1.291611e+06       NaN
# 2013-05-20  78.771161  87.745982 -1.544263e+06       NaN
# ...               ...        ...           ...       ...
# 2018-04-04  20.246662  16.546771 -3.936196e+06 -0.163214
# 2018-04-05        NaN        NaN -3.936196e+06       NaN
# 2018-04-06        NaN        NaN -3.936196e+06       NaN
# 2018-04-09        NaN        NaN -3.936196e+06       NaN
# 2018-04-10        NaN        NaN -3.936196e+06       NaN
# 2018-04-11        NaN        NaN -3.936196e+06       NaN
# 2018-04-12        NaN        NaN -3.936196e+06       NaN
# 2018-04-13        NaN        NaN -3.936196e+06       NaN
# 2018-04-16        NaN        NaN -3.936196e+06       NaN
# 2018-04-17        NaN        NaN -3.936196e+06       NaN
# 2018-04-18        NaN        NaN -3.936196e+06       NaN
# 2018-04-19        NaN        NaN -3.936196e+06       NaN
# 2018-04-20        NaN        NaN -3.936196e+06       NaN
# 2018-04-23        NaN        NaN -3.936196e+06       NaN
# 2018-04-24        NaN        NaN -3.936196e+06       NaN
# 2018-04-25        NaN        NaN -3.936196e+06       NaN
# 2018-04-26        NaN        NaN -3.936196e+06       NaN
# 2018-04-27        NaN        NaN -3.936196e+06       NaN
# 2018-04-30        NaN        NaN -3.936196e+06       NaN
# 2018-05-02        NaN        NaN -3.936196e+06       NaN
# 2018-05-03        NaN        NaN -3.936196e+06       NaN
# 2018-05-04        NaN        NaN -3.936196e+06       NaN
# 2018-05-07        NaN        NaN -3.936196e+06       NaN
# 2018-05-08        NaN        NaN -3.936196e+06       NaN
# 2018-05-09        NaN        NaN -3.936196e+06       NaN
# 2018-05-10        NaN        NaN -3.936196e+06       NaN
# 2018-05-11        NaN        NaN -3.936196e+06       NaN
# 2018-05-14        NaN        NaN -3.936196e+06       NaN
# 2018-05-15        NaN        NaN -3.936196e+06       NaN
# 2018-05-16        NaN        NaN -3.936196e+06       NaN
#
# [1261 rows x 24 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(roc30.loc[start_date:end_date, :].index, roc30.loc[start_date:end_date, 'ROC'], label = 'For 30 days')
ax.plot(roc40.loc[start_date:end_date, :].index, roc40.loc[start_date:end_date, 'ROC'], label = 'For 40 days')
ax.plot(roc50.loc[start_date:end_date, :].index, roc50.loc[start_date:end_date, 'ROC'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')

# %% [markdown]
# ## Rate of Volume Change (30,40,50)

# %%
def ROC(data,n):
 N = data['Volume'].diff(n)
 D = data['Volume'].shift(n)
 ROC = pd.Series(N/D,name='ROC')
 data = data.join(ROC)
 return data

# %%
roc30=ROC(df,30)
roc40=ROC(df,40)
roc50=ROC(df,50)

# %%
roc30
# Out:
#                   Open        High         Low   Adj Close      Volume  \
# Date
# 2013-04-04  185.227005  186.000000  182.291000  131.441833  18866172.0
# 2013-04-05  183.417999  183.417999  179.091003  130.054443  28818724.0
# 2018-04-16       NaN            NaN             NaN         NaN         NaN
# 2018-04-17       NaN            NaN             NaN         NaN         NaN
# 2018-04-18       NaN            NaN             NaN         NaN         NaN
# 2018-04-19       NaN            NaN             NaN         NaN         NaN
# 2018-04-20       NaN            NaN             NaN         NaN         NaN
# 2018-04-23       NaN            NaN             NaN         NaN         NaN
# 2018-04-24       NaN            NaN             NaN         NaN         NaN
# 2018-04-25       NaN            NaN             NaN         NaN         NaN
# 2018-04-26       NaN            NaN             NaN         NaN         NaN
# 2018-04-27       NaN            NaN             NaN         NaN         NaN
# 2018-04-30       NaN            NaN             NaN         NaN         NaN
# 2018-05-02       NaN            NaN             NaN         NaN         NaN
# 2018-05-03       NaN            NaN             NaN         NaN         NaN
# 2018-05-04       NaN            NaN             NaN         NaN         NaN
# 2018-05-07       NaN            NaN             NaN         NaN         NaN
# 2018-05-08       NaN            NaN             NaN         NaN         NaN
# 2018-05-09       NaN            NaN             NaN         NaN         NaN
# 2018-05-10       NaN            NaN             NaN         NaN         NaN
# 2018-05-11       NaN            NaN             NaN         NaN         NaN
# 2018-05-14       NaN            NaN             NaN         NaN         NaN
# 2018-05-15       NaN            NaN             NaN         NaN         NaN
# 2018-05-16       NaN            NaN             NaN         NaN         NaN
#
#               ...       ave40  upper40  lower40    ave50  upper50  lower50  \
# Date          ...
# 2013-04-04    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-05    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-08    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-09    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-10    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-11    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-12    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-15    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-16    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-17    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-18    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-22    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-23    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-25    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-26    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-29    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-04-30    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-02    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-03    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-06    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-07    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-08    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-09    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-10    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-13    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-14    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-15    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-16    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-17    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2013-05-20    ...         NaN      NaN      NaN      NaN      NaN      NaN
# ...           ...         ...      ...      ...      ...      ...      ...
# 2018-04-04    ...     305.315   325.77   284.86  314.995  341.842  288.148
# 2018-04-05    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-06    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-09    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-10    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-11    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-12    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-13    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-16    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-17    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-18    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-19    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-20    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-23    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-24    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-25    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-26    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-27    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-04-30    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-02    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-03    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-04    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-07    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-08    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-09    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-10    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-11    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-14    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-15    ...         NaN      NaN      NaN      NaN      NaN      NaN
# 2018-05-16    ...         NaN      NaN      NaN      NaN      NaN      NaN
#
#                    %K         %D        ch_osc       ROC
# Date
# 2013-04-04        NaN        NaN  0.000000e+00       NaN
# 2013-04-05        NaN        NaN  6.934541e+05       NaN
# 2013-04-08        NaN        NaN -3.023274e+05       NaN
# 2013-04-09        NaN        NaN -1.098512e+06       NaN
# 2013-04-10        NaN        NaN  2.163727e+06       NaN
# 2013-04-11        NaN        NaN  2.864838e+06       NaN
# 2013-04-12        NaN        NaN  2.872601e+06       NaN
# 2013-04-15        NaN        NaN  1.437861e+06       NaN
# 2013-04-16        NaN        NaN  4.323028e+06       NaN
# 2013-04-17        NaN        NaN  3.076477e+06       NaN
# 2013-04-18        NaN        NaN  4.501473e+06       NaN
# 2013-04-22        NaN        NaN  4.202480e+06       NaN
# 2013-04-23        NaN        NaN  5.443528e+06       NaN
# 2013-04-25  94.838559        NaN  4.224157e+06       NaN
# 2013-04-26  78.610508        NaN -5.906125e+05       NaN
# 2013-04-29  82.811922  85.420330 -1.763858e+05       NaN
# 2013-04-30  87.857850  83.093427  3.594281e+05       NaN
# 2013-05-02  91.743219  87.470997 -9.868376e+05       NaN
# 2013-05-03  64.235586  81.278885 -4.283337e+06       NaN
# 2013-05-06  71.602642  75.860482 -2.032926e+06       NaN
# 2013-05-07  84.202783  73.347004 -7.536082e+05       NaN
# 2013-05-08  78.635601  78.147008 -1.751758e+06       NaN
# 2013-05-09  66.436837  76.425073 -2.265859e+06       NaN
# 2013-05-10  78.046142  74.372860 -1.179956e+06       NaN
# 2013-05-13  49.719944  64.734307 -3.151757e+06       NaN
# 2013-05-14  48.019038  58.595041 -4.162733e+06       NaN
# 2013-05-15  91.567362  63.102114 -8.587537e+05       NaN
# 2013-05-16  89.520875  76.369092 -1.013912e+05       NaN
# 2013-05-17  94.945909  92.011382  1.291611e+06       NaN
# 2013-05-20  78.771161  87.745982 -1.544263e+06       NaN
# ...               ...        ...           ...       ...
# 2018-04-04  20.246662  16.546771 -3.936196e+06  0.904179
# 2018-04-05        NaN        NaN -3.936196e+06       NaN
# 2018-04-06        NaN        NaN -3.936196e+06       NaN
# 2018-04-09        NaN        NaN -3.936196e+06       NaN
# 2018-04-10        NaN        NaN -3.936196e+06       NaN
# 2018-04-11        NaN        NaN -3.936196e+06       NaN
# 2018-04-12        NaN        NaN -3.936196e+06       NaN
# 2018-04-13        NaN        NaN -3.936196e+06       NaN
# 2018-04-16        NaN        NaN -3.936196e+06       NaN
# 2018-04-17        NaN        NaN -3.936196e+06       NaN
# 2018-04-18        NaN        NaN -3.936196e+06       NaN
# 2018-04-19        NaN        NaN -3.936196e+06       NaN
# 2018-04-20        NaN        NaN -3.936196e+06       NaN
# 2018-04-23        NaN        NaN -3.936196e+06       NaN
# 2018-04-24        NaN        NaN -3.936196e+06       NaN
# 2018-04-25        NaN        NaN -3.936196e+06       NaN
# 2018-04-26        NaN        NaN -3.936196e+06       NaN
# 2018-04-27        NaN        NaN -3.936196e+06       NaN
# 2018-04-30        NaN        NaN -3.936196e+06       NaN
# 2018-05-02        NaN        NaN -3.936196e+06       NaN
# 2018-05-03        NaN        NaN -3.936196e+06       NaN
# 2018-05-04        NaN        NaN -3.936196e+06       NaN
# 2018-05-07        NaN        NaN -3.936196e+06       NaN
# 2018-05-08        NaN        NaN -3.936196e+06       NaN
# 2018-05-09        NaN        NaN -3.936196e+06       NaN
# 2018-05-10        NaN        NaN -3.936196e+06       NaN
# 2018-05-11        NaN        NaN -3.936196e+06       NaN
# 2018-05-14        NaN        NaN -3.936196e+06       NaN
# 2018-05-15        NaN        NaN -3.936196e+06       NaN
# 2018-05-16        NaN        NaN -3.936196e+06       NaN
#
# [1261 rows x 24 columns]

# %%
fig, ax = plt.subplots(figsize=(15,9))

ax.plot(roc30.loc[start_date:end_date, :].index, roc30.loc[start_date:end_date, 'ROC'], label = 'For 30 days')
ax.plot(roc40.loc[start_date:end_date, :].index, roc40.loc[start_date:end_date, 'ROC'], label = 'For 40 days')
ax.plot(roc50.loc[start_date:end_date, :].index, roc50.loc[start_date:end_date, 'ROC'], label = 'For 50 days')

ax.legend(loc='best')
ax.set_ylabel('Change')
# Out:
# Text(0,0.5,'Change')
